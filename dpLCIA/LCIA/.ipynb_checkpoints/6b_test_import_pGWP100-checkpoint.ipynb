# %%
import brightway2
import numpy as np
import pandas as pd
import os
import sys

# %%
bw2data.projects.set_current('your project')

# %%
fp = '../pGWP100_bw2package/pgwp100_N18_3SSP_3MY_2CO2approach.141b447f0e14c9d70ddfb10cb23578d6.bw2package'
brightway2.BW2Package.import_file(fp)
# Out:
# [Brightway2 Method: Climate Change prospective GWP100: SSP119: 2030: pGWP100 with fixed AGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP119: 2030: pGWP100 with dpAGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP119: 2040: pGWP100 with fixed AGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP119: 2040: pGWP100 with dpAGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP119: 2050: pGWP100 with fixed AGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP119: 2050: pGWP100 with dpAGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP245: 2030: pGWP100 with fixed AGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP245: 2030: pGWP100 with dpAGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP245: 2040: pGWP100 with fixed AGWPCO2,
#  Brightway2 Method: Climate Change prospective GWP100: SSP245: 2040: pGWP100 with dpAGWPCO2,
# ...

# %% [markdown]
# A total of 18 new pGWP100 should be ready:
#
# ![image.png](attachment:8b3f4d4a-49e2-4fb9-94f5-6380618dc5ab.png)
