# %% [markdown]
# ### pretreatment on IMAGE data:
# - biomass, coal, gas, oil,  wind aggregated
# - solor, hydro, nuclear, bat storage, geothermal kept separate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append("../utils")
from premise_elec_plot import *   # data pretreatment & plot

# %%
# not available under timex 
#import premise
#from premise import geomap

# %% [raw]
# image_loc = premise.geomap.Geomap("image")
# print(image_loc.iam_regions)
# len(image_loc.iam_regions)
# #print(image_loc.iam_to_ecoinvent_location("CHN"))
# #print(image_loc.iam_to_ecoinvent_location("ME"))

# %% [markdown]
# #### plot

# %%
scenario_paths = {
    "SSP1-VLLO": "../Install_EI_PREMISE_BGDB/export/scenario_report/image/scenario_report_IMAGE - SSP1-VLLO_22-11-2025.xlsx",
    "SSP2-M":    "../Install_EI_PREMISE_BGDB/export/scenario_report/image/scenario_report_IMAGE - SSP2-M_22-11-2025.xlsx",
    "SSP5-H":    "../Install_EI_PREMISE_BGDB/export/scenario_report/image/scenario_report_IMAGE - SSP5-H_22-11-2025.xlsx",
}

# %%
df = extract_region_block_general("../set_up/Install_EI_PREMISE_BGDB/export/scenario_report/image/scenario_report_IMAGE - SSP1-VLLO_22-11-2025.xlsx", "CHN")
#df

# %%
### aggregate biomass / coal / gas ... 
aggregate_groups(df)
# Out:
# 28       Hydro  Wind (all)  Solar (all)  Biomass (all)  Gas (all)   Nuclear  \
# Year
# 2005  1.302912    0.005641     0.000061       0.029858   0.147402  0.331344
# 2010  1.264860    0.031406     0.000918       0.032933   0.186779  0.326369
# 2015  1.375758    0.097070     0.010422       0.033325   0.232700  0.366512
# 2020  1.391422    0.128740     0.017244       0.036558   0.260352  0.353502
# 2025  1.344295    0.160231     0.060578       0.048465   0.377310  0.304787
# 2030  1.277151    0.190112     0.119261       0.042178   0.275922  0.250791
# 2035  1.248536    0.357413     0.313030       0.048149   0.120221  0.193108
# 2040  1.096321    0.679810     0.435073       0.185309   0.116576  0.095056
# 2045  0.776422    0.828383     0.519414       0.276817   0.389854  0.020189
# 2050  0.492409    1.013759     0.640648       0.443166   0.380537  0.000668
# 2060  0.368939    1.218651     0.861476       0.687659   0.274853  0.000000
# ...

# %%
# CAN
plot_region_mix("CAN", scenario_paths, mode="EJ", up_to_year = 2060)
plot_region_mix("CAN", scenario_paths, mode="percent", up_to_year = 2060)
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors

# %%
# CHN
plot_region_mix("CHN", scenario_paths, mode="EJ",  up_to_year = 2060)
plot_region_mix("CHN", scenario_paths, mode="percent", up_to_year = 2060)
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors

# %%
plot_region_mix("World", scenario_paths, mode="EJ",  up_to_year = 2060)
plot_region_mix("World", scenario_paths, mode="percent",  up_to_year = 2060)
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_7548/2120500490.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap(palette).colors
