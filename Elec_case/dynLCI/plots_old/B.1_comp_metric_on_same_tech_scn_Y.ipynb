# %%
import bw2data, bw2io, bw2calc
import numpy as np
import os
import re
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
pd.set_option("display.max_colwidth", 120)

# %%
wind  = pd.read_excel("dp-LCI_output/staticLCI_(p)GWP100/wind_CN_US_staticLCI_threeGWP100.xlsx")
#hydro = pd.read_excel("dp-LCI_output/staticLCI_(p)GWP100/hydro_run-of-river_CN_US_staticLCI_threeGWP100.xlsx")
hydro = pd.read_excel("dp-LCI_output/staticLCI_(p)GWP100/hydro_reservoir_CN-asRoW_US-asQC_staticLCI_threeGWP100.xlsx")
pv    = pd.read_excel("dp-LCI_output/staticLCI_(p)GWP100/PV_CN_US_staticLCI_threeGWP100.xlsx")

# %%
def add_diff_columns(df):
    df = df.copy()

    df["diff%_pGWP-fixedCO2"] = (
        (df["pGWP100_fixedCO2"] - df["gwp100"]) / df["gwp100"] * 100
    ).round(0).astype(int)

    df["diff%_pGWP-dpCO2"] = (
        (df["pGWP100_dpCO2"] - df["gwp100"]) / df["gwp100"] * 100
    ).round(0).astype(int)

    return df

# %%
hydro = add_diff_columns(hydro)
wind  = add_diff_columns(wind)
pv    = add_diff_columns(pv)

# %%
hydro["diff%_pGWP-fixedCO2"] = (
    (hydro["pGWP100_fixedCO2"] - hydro["gwp100"]) / hydro["gwp100"] * 100
).round(0).astype(int)

hydro["diff%_pGWP-dpCO2"] = (
    (hydro["pGWP100_dpCO2"] - hydro["gwp100"]) / hydro["gwp100"] * 100
).round(0).astype(int)


hydro
# Out:
#                                                             Activity  \
# 0   market for electricity, hydro, high voltage, US, SSP1-VLLO, 2030
# 1   market for electricity, hydro, high voltage, US, SSP1-VLLO, 2040
# 2   market for electricity, hydro, high voltage, US, SSP1-VLLO, 2050
# 3      market for electricity, hydro, high voltage, US, SSP2-M, 2030
# 4      market for electricity, hydro, high voltage, US, SSP2-M, 2040
# 5      market for electricity, hydro, high voltage, US, SSP2-M, 2050
# 6      market for electricity, hydro, high voltage, US, SSP5-H, 2030
# 7      market for electricity, hydro, high voltage, US, SSP5-H, 2040
# 8      market for electricity, hydro, high voltage, US, SSP5-H, 2050
# 9   market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2030
# 10  market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2040
# 11  market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2050
# 12     market for electricity, hydro, high voltage, CN, SSP2-M, 2030
# 13     market for electricity, hydro, high voltage, CN, SSP2-M, 2040
# 14     market for electricity, hydro, high voltage, CN, SSP2-M, 2050
# 15     market for electricity, hydro, high voltage, CN, SSP5-H, 2030
# 16     market for electricity, hydro, high voltage, CN, SSP5-H, 2040
# 17     market for electricity, hydro, high voltage, CN, SSP5-H, 2050
#
#       gwp100  pGWP100_fixedCO2  pGWP100_dpCO2  diff%_pGWP-fixedCO2  \
# 0   0.015721          0.017909       0.015650                   14
# 1   0.015028          0.016988       0.015003                   13
# 2   0.013658          0.015535       0.013646                   14
# 3   0.015746          0.017505       0.015649                   11
# 4   0.015562          0.016343       0.015522                    5
# 5   0.015461          0.015388       0.015462                    0
# 6   0.015801          0.017236       0.015666                    9
# 7   0.015678          0.015613       0.015559                    0
# 8   0.015582          0.014036       0.015528                  -10
# 9   0.050523          0.057266       0.050021                   13
# 10  0.048724          0.055041       0.048587                   13
# 11  0.047437          0.053979       0.047402                   14
# 12  0.050624          0.055848       0.049911                   10
# 13  0.050167          0.052563       0.049909                    5
# 14  0.049844          0.049701       0.049930                    0
# 15  0.050766          0.054737       0.049735                    8
# 16  0.050595          0.049859       0.049681                   -1
# 17  0.050388          0.045198       0.050006                  -10
#
#     diff%_pGWP-dpCO2
# 0                  0
# 1                  0
# 2                  0
# 3                 -1
# 4                  0
# 5                  0
# 6                 -1
# 7                 -1
# 8                  0
# 9                 -1
# 10                 0
# 11                 0
# 12                -1
# 13                -1
# 14                 0
# 15                -2
# 16                -2
# 17                -1

# %%
def highlight_threshold(val):
    if pd.isna(val):
        return ""
    if abs(val) >= 10:
        return "background-color: #ff6b6b; color: black;"   # red
    elif abs(val) >= 5:
        return "background-color: #f4b084; color: black;"   # yellow
    else:
        return ""

# %%
hydro.style.applymap(
        highlight_threshold,
        subset=["diff%_pGWP-fixedCO2", "diff%_pGWP-dpCO2"]
    ).set_properties(
        subset=["Activity"],
        **{"white-space": "nowrap"}
    )
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_1921/4045844554.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   hydro.style.applymap(
# <style type="text/css">
# #T_c272f_row0_col0, #T_c272f_row1_col0, #T_c272f_row2_col0, #T_c272f_row3_col0, #T_c272f_row4_col0, #T_c272f_row5_col0, #T_c272f_row6_col0, #T_c272f_row7_col0, #T_c272f_row8_col0, #T_c272f_row9_col0, #T_c272f_row10_col0, #T_c272f_row11_col0, #T_c272f_row12_col0, #T_c272f_row13_col0, #T_c272f_row14_col0, #T_c272f_row15_col0, #T_c272f_row16_col0, #T_c272f_row17_col0 {
#   white-space: nowrap;
# }
# #T_c272f_row0_col4, #T_c272f_row1_col4, #T_c272f_row2_col4, #T_c272f_row3_col4, #T_c272f_row8_col4, #T_c272f_row9_col4, #T_c272f_row10_col4, #T_c272f_row11_col4, #T_c272f_row12_col4, #T_c272f_row17_col4 {
#   background-color: #ff6b6b;
#   color: black;
# }
# #T_c272f_row4_col4, #T_c272f_row6_col4, #T_c272f_row13_col4, #T_c272f_row15_col4 {
#   background-color: #f4b084;
#   color: black;
# }
# </style>
# <table id="T_c272f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c272f_level0_col0" class="col_heading level0 col0" >Activity</th>
#       <th id="T_c272f_level0_col1" class="col_heading level0 col1" >gwp100</th>
#       <th id="T_c272f_level0_col2" class="col_heading level0 col2" >pGWP100_fixedCO2</th>
#       <th id="T_c272f_level0_col3" class="col_heading level0 col3" >pGWP100_dpCO2</th>
#       <th id="T_c272f_level0_col4" class="col_heading level0 col4" >diff%_pGWP-fixedCO2</th>
#       <th id="T_c272f_level0_col5" class="col_heading level0 col5" >diff%_pGWP-dpCO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c272f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c272f_row0_col0" class="data row0 col0" >market for electricity, hydro, high voltage, US, SSP1-VLLO, 2030</td>
#       <td id="T_c272f_row0_col1" class="data row0 col1" >0.015721</td>
#       <td id="T_c272f_row0_col2" class="data row0 col2" >0.017909</td>
#       <td id="T_c272f_row0_col3" class="data row0 col3" >0.015650</td>
#       <td id="T_c272f_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_c272f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c272f_row1_col0" class="data row1 col0" >market for electricity, hydro, high voltage, US, SSP1-VLLO, 2040</td>
#       <td id="T_c272f_row1_col1" class="data row1 col1" >0.015028</td>
#       <td id="T_c272f_row1_col2" class="data row1 col2" >0.016988</td>
#       <td id="T_c272f_row1_col3" class="data row1 col3" >0.015003</td>
#       <td id="T_c272f_row1_col4" class="data row1 col4" >13</td>
#       <td id="T_c272f_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c272f_row2_col0" class="data row2 col0" >market for electricity, hydro, high voltage, US, SSP1-VLLO, 2050</td>
#       <td id="T_c272f_row2_col1" class="data row2 col1" >0.013658</td>
#       <td id="T_c272f_row2_col2" class="data row2 col2" >0.015535</td>
#       <td id="T_c272f_row2_col3" class="data row2 col3" >0.013646</td>
#       <td id="T_c272f_row2_col4" class="data row2 col4" >14</td>
#       <td id="T_c272f_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c272f_row3_col0" class="data row3 col0" >market for electricity, hydro, high voltage, US, SSP2-M, 2030</td>
#       <td id="T_c272f_row3_col1" class="data row3 col1" >0.015746</td>
#       <td id="T_c272f_row3_col2" class="data row3 col2" >0.017505</td>
#       <td id="T_c272f_row3_col3" class="data row3 col3" >0.015649</td>
#       <td id="T_c272f_row3_col4" class="data row3 col4" >11</td>
#       <td id="T_c272f_row3_col5" class="data row3 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c272f_row4_col0" class="data row4 col0" >market for electricity, hydro, high voltage, US, SSP2-M, 2040</td>
#       <td id="T_c272f_row4_col1" class="data row4 col1" >0.015562</td>
#       <td id="T_c272f_row4_col2" class="data row4 col2" >0.016343</td>
#       <td id="T_c272f_row4_col3" class="data row4 col3" >0.015522</td>
#       <td id="T_c272f_row4_col4" class="data row4 col4" >5</td>
#       <td id="T_c272f_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c272f_row5_col0" class="data row5 col0" >market for electricity, hydro, high voltage, US, SSP2-M, 2050</td>
#       <td id="T_c272f_row5_col1" class="data row5 col1" >0.015461</td>
#       <td id="T_c272f_row5_col2" class="data row5 col2" >0.015388</td>
#       <td id="T_c272f_row5_col3" class="data row5 col3" >0.015462</td>
#       <td id="T_c272f_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_c272f_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c272f_row6_col0" class="data row6 col0" >market for electricity, hydro, high voltage, US, SSP5-H, 2030</td>
#       <td id="T_c272f_row6_col1" class="data row6 col1" >0.015801</td>
#       <td id="T_c272f_row6_col2" class="data row6 col2" >0.017236</td>
#       <td id="T_c272f_row6_col3" class="data row6 col3" >0.015666</td>
#       <td id="T_c272f_row6_col4" class="data row6 col4" >9</td>
#       <td id="T_c272f_row6_col5" class="data row6 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c272f_row7_col0" class="data row7 col0" >market for electricity, hydro, high voltage, US, SSP5-H, 2040</td>
#       <td id="T_c272f_row7_col1" class="data row7 col1" >0.015678</td>
#       <td id="T_c272f_row7_col2" class="data row7 col2" >0.015613</td>
#       <td id="T_c272f_row7_col3" class="data row7 col3" >0.015559</td>
#       <td id="T_c272f_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_c272f_row7_col5" class="data row7 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c272f_row8_col0" class="data row8 col0" >market for electricity, hydro, high voltage, US, SSP5-H, 2050</td>
#       <td id="T_c272f_row8_col1" class="data row8 col1" >0.015582</td>
#       <td id="T_c272f_row8_col2" class="data row8 col2" >0.014036</td>
#       <td id="T_c272f_row8_col3" class="data row8 col3" >0.015528</td>
#       <td id="T_c272f_row8_col4" class="data row8 col4" >-10</td>
#       <td id="T_c272f_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c272f_row9_col0" class="data row9 col0" >market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2030</td>
#       <td id="T_c272f_row9_col1" class="data row9 col1" >0.050523</td>
#       <td id="T_c272f_row9_col2" class="data row9 col2" >0.057266</td>
#       <td id="T_c272f_row9_col3" class="data row9 col3" >0.050021</td>
#       <td id="T_c272f_row9_col4" class="data row9 col4" >13</td>
#       <td id="T_c272f_row9_col5" class="data row9 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c272f_row10_col0" class="data row10 col0" >market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2040</td>
#       <td id="T_c272f_row10_col1" class="data row10 col1" >0.048724</td>
#       <td id="T_c272f_row10_col2" class="data row10 col2" >0.055041</td>
#       <td id="T_c272f_row10_col3" class="data row10 col3" >0.048587</td>
#       <td id="T_c272f_row10_col4" class="data row10 col4" >13</td>
#       <td id="T_c272f_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c272f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c272f_row11_col0" class="data row11 col0" >market for electricity, hydro, high voltage, CN, SSP1-VLLO, 2050</td>
#       <td id="T_c272f_row11_col1" class="data row11 col1" >0.047437</td>
#       <td id="T_c272f_row11_col2" class="data row11 col2" >0.053979</td>

# %%
wind.style.applymap(
        highlight_threshold,
        subset=["diff%_pGWP-fixedCO2", "diff%_pGWP-dpCO2"]
    ).set_properties(
        subset=["Activity"],
        **{"white-space": "nowrap"}
    )
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_1921/583887840.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   wind.style.applymap(
# <style type="text/css">
# #T_c9888_row0_col0, #T_c9888_row1_col0, #T_c9888_row2_col0, #T_c9888_row3_col0, #T_c9888_row4_col0, #T_c9888_row5_col0, #T_c9888_row6_col0, #T_c9888_row7_col0, #T_c9888_row8_col0, #T_c9888_row9_col0, #T_c9888_row10_col0, #T_c9888_row11_col0, #T_c9888_row12_col0, #T_c9888_row13_col0, #T_c9888_row14_col0, #T_c9888_row15_col0, #T_c9888_row16_col0, #T_c9888_row17_col0 {
#   white-space: nowrap;
# }
# #T_c9888_row0_col4, #T_c9888_row1_col4, #T_c9888_row2_col4, #T_c9888_row3_col4, #T_c9888_row8_col4, #T_c9888_row9_col4, #T_c9888_row10_col4, #T_c9888_row11_col4, #T_c9888_row12_col4, #T_c9888_row17_col4 {
#   background-color: #ff6b6b;
#   color: black;
# }
# #T_c9888_row6_col4, #T_c9888_row15_col4 {
#   background-color: #f4b084;
#   color: black;
# }
# </style>
# <table id="T_c9888">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9888_level0_col0" class="col_heading level0 col0" >Activity</th>
#       <th id="T_c9888_level0_col1" class="col_heading level0 col1" >gwp100</th>
#       <th id="T_c9888_level0_col2" class="col_heading level0 col2" >pGWP100_fixedCO2</th>
#       <th id="T_c9888_level0_col3" class="col_heading level0 col3" >pGWP100_dpCO2</th>
#       <th id="T_c9888_level0_col4" class="col_heading level0 col4" >diff%_pGWP-fixedCO2</th>
#       <th id="T_c9888_level0_col5" class="col_heading level0 col5" >diff%_pGWP-dpCO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9888_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9888_row0_col0" class="data row0 col0" >market for electricity, wind, high voltage, CN-NM, SSP1-VLLO, 2030</td>
#       <td id="T_c9888_row0_col1" class="data row0 col1" >0.036905</td>
#       <td id="T_c9888_row0_col2" class="data row0 col2" >0.041520</td>
#       <td id="T_c9888_row0_col3" class="data row0 col3" >0.036365</td>
#       <td id="T_c9888_row0_col4" class="data row0 col4" >13</td>
#       <td id="T_c9888_row0_col5" class="data row0 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9888_row1_col0" class="data row1 col0" >market for electricity, wind, high voltage, CN-NM, SSP1-VLLO, 2040</td>
#       <td id="T_c9888_row1_col1" class="data row1 col1" >0.023273</td>
#       <td id="T_c9888_row1_col2" class="data row1 col2" >0.025947</td>
#       <td id="T_c9888_row1_col3" class="data row1 col3" >0.022983</td>
#       <td id="T_c9888_row1_col4" class="data row1 col4" >11</td>
#       <td id="T_c9888_row1_col5" class="data row1 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c9888_row2_col0" class="data row2 col0" >market for electricity, wind, high voltage, CN-NM, SSP1-VLLO, 2050</td>
#       <td id="T_c9888_row2_col1" class="data row2 col1" >0.017832</td>
#       <td id="T_c9888_row2_col2" class="data row2 col2" >0.019952</td>
#       <td id="T_c9888_row2_col3" class="data row2 col3" >0.017591</td>
#       <td id="T_c9888_row2_col4" class="data row2 col4" >12</td>
#       <td id="T_c9888_row2_col5" class="data row2 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c9888_row3_col0" class="data row3 col0" >market for electricity, wind, high voltage, CN-NM, SSP2-M, 2030</td>
#       <td id="T_c9888_row3_col1" class="data row3 col1" >0.037723</td>
#       <td id="T_c9888_row3_col2" class="data row3 col2" >0.041415</td>
#       <td id="T_c9888_row3_col3" class="data row3 col3" >0.037095</td>
#       <td id="T_c9888_row3_col4" class="data row3 col4" >10</td>
#       <td id="T_c9888_row3_col5" class="data row3 col5" >-2</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c9888_row4_col0" class="data row4 col0" >market for electricity, wind, high voltage, CN-NM, SSP2-M, 2040</td>
#       <td id="T_c9888_row4_col1" class="data row4 col1" >0.034046</td>
#       <td id="T_c9888_row4_col2" class="data row4 col2" >0.035403</td>
#       <td id="T_c9888_row4_col3" class="data row4 col3" >0.033654</td>
#       <td id="T_c9888_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_c9888_row4_col5" class="data row4 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c9888_row5_col0" class="data row5 col0" >market for electricity, wind, high voltage, CN-NM, SSP2-M, 2050</td>
#       <td id="T_c9888_row5_col1" class="data row5 col1" >0.031185</td>
#       <td id="T_c9888_row5_col2" class="data row5 col2" >0.030810</td>
#       <td id="T_c9888_row5_col3" class="data row5 col3" >0.030951</td>
#       <td id="T_c9888_row5_col4" class="data row5 col4" >-1</td>
#       <td id="T_c9888_row5_col5" class="data row5 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c9888_row6_col0" class="data row6 col0" >market for electricity, wind, high voltage, CN-NM, SSP5-H, 2030</td>
#       <td id="T_c9888_row6_col1" class="data row6 col1" >0.038734</td>
#       <td id="T_c9888_row6_col2" class="data row6 col2" >0.041703</td>
#       <td id="T_c9888_row6_col3" class="data row6 col3" >0.037964</td>
#       <td id="T_c9888_row6_col4" class="data row6 col4" >8</td>
#       <td id="T_c9888_row6_col5" class="data row6 col5" >-2</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c9888_row7_col0" class="data row7 col0" >market for electricity, wind, high voltage, CN-NM, SSP5-H, 2040</td>
#       <td id="T_c9888_row7_col1" class="data row7 col1" >0.036708</td>
#       <td id="T_c9888_row7_col2" class="data row7 col2" >0.036168</td>
#       <td id="T_c9888_row7_col3" class="data row7 col3" >0.036044</td>
#       <td id="T_c9888_row7_col4" class="data row7 col4" >-1</td>
#       <td id="T_c9888_row7_col5" class="data row7 col5" >-2</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c9888_row8_col0" class="data row8 col0" >market for electricity, wind, high voltage, CN-NM, SSP5-H, 2050</td>
#       <td id="T_c9888_row8_col1" class="data row8 col1" >0.034395</td>
#       <td id="T_c9888_row8_col2" class="data row8 col2" >0.030785</td>
#       <td id="T_c9888_row8_col3" class="data row8 col3" >0.033988</td>
#       <td id="T_c9888_row8_col4" class="data row8 col4" >-10</td>
#       <td id="T_c9888_row8_col5" class="data row8 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c9888_row9_col0" class="data row9 col0" >market for electricity, wind, high voltage, US-TRE, SSP1-VLLO, 2030</td>
#       <td id="T_c9888_row9_col1" class="data row9 col1" >0.020637</td>
#       <td id="T_c9888_row9_col2" class="data row9 col2" >0.023218</td>
#       <td id="T_c9888_row9_col3" class="data row9 col3" >0.020336</td>
#       <td id="T_c9888_row9_col4" class="data row9 col4" >13</td>
#       <td id="T_c9888_row9_col5" class="data row9 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c9888_row10_col0" class="data row10 col0" >market for electricity, wind, high voltage, US-TRE, SSP1-VLLO, 2040</td>
#       <td id="T_c9888_row10_col1" class="data row10 col1" >0.013015</td>
#       <td id="T_c9888_row10_col2" class="data row10 col2" >0.014510</td>
#       <td id="T_c9888_row10_col3" class="data row10 col3" >0.012852</td>
#       <td id="T_c9888_row10_col4" class="data row10 col4" >11</td>
#       <td id="T_c9888_row10_col5" class="data row10 col5" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c9888_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c9888_row11_col0" class="data row11 col0" >market for electricity, wind, high voltage, US-TRE, SSP1-VLLO, 2050</td>
#       <td id="T_c9888_row11_col1" class="data row11 col1" >0.009972</td>
#       <td id="T_c9888_row11_col2" class="data row11 col2" >0.011157</td>

# %%
pv.style.applymap(
        highlight_threshold,
        subset=["diff%_pGWP-fixedCO2", "diff%_pGWP-dpCO2"]
    ).set_properties(
        subset=["Activity"],
        **{"white-space": "nowrap"}
    )
# Out:
# /var/folders/9p/gvkl7h6551515cs56m93ldgr0000gn/T/ipykernel_1921/2627738615.py:1: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   pv.style.applymap(
# <style type="text/css">
# #T_f2568_row0_col0, #T_f2568_row1_col0, #T_f2568_row2_col0, #T_f2568_row3_col0, #T_f2568_row4_col0, #T_f2568_row5_col0, #T_f2568_row6_col0, #T_f2568_row7_col0, #T_f2568_row8_col0, #T_f2568_row9_col0, #T_f2568_row10_col0, #T_f2568_row11_col0, #T_f2568_row12_col0, #T_f2568_row13_col0, #T_f2568_row14_col0, #T_f2568_row15_col0, #T_f2568_row16_col0, #T_f2568_row17_col0 {
#   white-space: nowrap;
# }
# #T_f2568_row0_col4, #T_f2568_row8_col4, #T_f2568_row9_col4, #T_f2568_row17_col4 {
#   background-color: #ff6b6b;
#   color: black;
# }
# #T_f2568_row1_col4, #T_f2568_row1_col5, #T_f2568_row2_col4, #T_f2568_row2_col5, #T_f2568_row3_col4, #T_f2568_row6_col4, #T_f2568_row10_col4, #T_f2568_row10_col5, #T_f2568_row11_col4, #T_f2568_row11_col5, #T_f2568_row12_col4, #T_f2568_row15_col4 {
#   background-color: #f4b084;
#   color: black;
# }
# </style>
# <table id="T_f2568">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2568_level0_col0" class="col_heading level0 col0" >Activity</th>
#       <th id="T_f2568_level0_col1" class="col_heading level0 col1" >gwp100</th>
#       <th id="T_f2568_level0_col2" class="col_heading level0 col2" >pGWP100_fixedCO2</th>
#       <th id="T_f2568_level0_col3" class="col_heading level0 col3" >pGWP100_dpCO2</th>
#       <th id="T_f2568_level0_col4" class="col_heading level0 col4" >diff%_pGWP-fixedCO2</th>
#       <th id="T_f2568_level0_col5" class="col_heading level0 col5" >diff%_pGWP-dpCO2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2568_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2568_row0_col0" class="data row0 col0" >market for electricity, PV, low voltage, CN, SSP1-VLLO, 2030</td>
#       <td id="T_f2568_row0_col1" class="data row0 col1" >0.032003</td>
#       <td id="T_f2568_row0_col2" class="data row0 col2" >0.035375</td>
#       <td id="T_f2568_row0_col3" class="data row0 col3" >0.030962</td>
#       <td id="T_f2568_row0_col4" class="data row0 col4" >11</td>
#       <td id="T_f2568_row0_col5" class="data row0 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2568_row1_col0" class="data row1 col0" >market for electricity, PV, low voltage, CN, SSP1-VLLO, 2040</td>
#       <td id="T_f2568_row1_col1" class="data row1 col1" >0.013980</td>
#       <td id="T_f2568_row1_col2" class="data row1 col2" >0.014993</td>
#       <td id="T_f2568_row1_col3" class="data row1 col3" >0.013287</td>
#       <td id="T_f2568_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_f2568_row1_col5" class="data row1 col5" >-5</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2568_row2_col0" class="data row2 col0" >market for electricity, PV, low voltage, CN, SSP1-VLLO, 2050</td>
#       <td id="T_f2568_row2_col1" class="data row2 col1" >0.010065</td>
#       <td id="T_f2568_row2_col2" class="data row2 col2" >0.010716</td>
#       <td id="T_f2568_row2_col3" class="data row2 col3" >0.009459</td>
#       <td id="T_f2568_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_f2568_row2_col5" class="data row2 col5" >-6</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2568_row3_col0" class="data row3 col0" >market for electricity, PV, low voltage, CN, SSP2-M, 2030</td>
#       <td id="T_f2568_row3_col1" class="data row3 col1" >0.032911</td>
#       <td id="T_f2568_row3_col2" class="data row3 col2" >0.035515</td>
#       <td id="T_f2568_row3_col3" class="data row3 col3" >0.031793</td>
#       <td id="T_f2568_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_f2568_row3_col5" class="data row3 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2568_row4_col0" class="data row4 col0" >market for electricity, PV, low voltage, CN, SSP2-M, 2040</td>
#       <td id="T_f2568_row4_col1" class="data row4 col1" >0.025688</td>
#       <td id="T_f2568_row4_col2" class="data row4 col2" >0.026174</td>
#       <td id="T_f2568_row4_col3" class="data row4 col3" >0.024876</td>
#       <td id="T_f2568_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_f2568_row4_col5" class="data row4 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f2568_row5_col0" class="data row5 col0" >market for electricity, PV, low voltage, CN, SSP2-M, 2050</td>
#       <td id="T_f2568_row5_col1" class="data row5 col1" >0.020241</td>
#       <td id="T_f2568_row5_col2" class="data row5 col2" >0.019521</td>
#       <td id="T_f2568_row5_col3" class="data row5 col3" >0.019611</td>
#       <td id="T_f2568_row5_col4" class="data row5 col4" >-4</td>
#       <td id="T_f2568_row5_col5" class="data row5 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f2568_row6_col0" class="data row6 col0" >market for electricity, PV, low voltage, CN, SSP5-H, 2030</td>
#       <td id="T_f2568_row6_col1" class="data row6 col1" >0.034533</td>
#       <td id="T_f2568_row6_col2" class="data row6 col2" >0.036574</td>
#       <td id="T_f2568_row6_col3" class="data row6 col3" >0.033279</td>
#       <td id="T_f2568_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_f2568_row6_col5" class="data row6 col5" >-4</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f2568_row7_col0" class="data row7 col0" >market for electricity, PV, low voltage, CN, SSP5-H, 2040</td>
#       <td id="T_f2568_row7_col1" class="data row7 col1" >0.029717</td>
#       <td id="T_f2568_row7_col2" class="data row7 col2" >0.028768</td>
#       <td id="T_f2568_row7_col3" class="data row7 col3" >0.028669</td>
#       <td id="T_f2568_row7_col4" class="data row7 col4" >-3</td>
#       <td id="T_f2568_row7_col5" class="data row7 col5" >-4</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f2568_row8_col0" class="data row8 col0" >market for electricity, PV, low voltage, CN, SSP5-H, 2050</td>
#       <td id="T_f2568_row8_col1" class="data row8 col1" >0.024782</td>
#       <td id="T_f2568_row8_col2" class="data row8 col2" >0.021741</td>
#       <td id="T_f2568_row8_col3" class="data row8 col3" >0.024011</td>
#       <td id="T_f2568_row8_col4" class="data row8 col4" >-12</td>
#       <td id="T_f2568_row8_col5" class="data row8 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f2568_row9_col0" class="data row9 col0" >market for electricity, PV, low voltage, US, SSP1-VLLO, 2030</td>
#       <td id="T_f2568_row9_col1" class="data row9 col1" >0.020103</td>
#       <td id="T_f2568_row9_col2" class="data row9 col2" >0.022236</td>
#       <td id="T_f2568_row9_col3" class="data row9 col3" >0.019463</td>
#       <td id="T_f2568_row9_col4" class="data row9 col4" >11</td>
#       <td id="T_f2568_row9_col5" class="data row9 col5" >-3</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f2568_row10_col0" class="data row10 col0" >market for electricity, PV, low voltage, US, SSP1-VLLO, 2040</td>
#       <td id="T_f2568_row10_col1" class="data row10 col1" >0.009084</td>
#       <td id="T_f2568_row10_col2" class="data row10 col2" >0.009767</td>
#       <td id="T_f2568_row10_col3" class="data row10 col3" >0.008655</td>
#       <td id="T_f2568_row10_col4" class="data row10 col4" >8</td>
#       <td id="T_f2568_row10_col5" class="data row10 col5" >-5</td>
#     </tr>
#     <tr>
#       <th id="T_f2568_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f2568_row11_col0" class="data row11 col0" >market for electricity, PV, low voltage, US, SSP1-VLLO, 2050</td>
#       <td id="T_f2568_row11_col1" class="data row11 col1" >0.006560</td>
#       <td id="T_f2568_row11_col2" class="data row11 col2" >0.007007</td>
