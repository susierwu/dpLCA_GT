# %%
import bw2data, bw2io, bw2calc
from bw_timex import TimexLCA
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np
from datetime import datetime
import os
import re
import pandas as pd
import numpy as np
import pickle

# %%
import sys
sys.path.append('../utils/') 
from elec_builder import *

# %%
# activate the bw project
bw2data.projects.set_current("ei311")
#for db in bw2data.databases:
#    print(db, len(bw2data.Database(db)))

# %% [markdown]
# #### for CN reservoir, using RoW as proxy
# #### for US reservoir, using CA-QC as proxy

# %%
#hydro_cn = ['CN-SC']

# for CN reservoir, using RoW as proxy
hydro_us = ['US-WECC']
hydro_qc = ["CA-QC"]
hydro_row = ['RoW']

xx = build_dynamic_electricity_all(
    locations = hydro_row , 
    pathways = [ "SSP1-VLLO" , "SSP2-M", "SSP5-H" ],
    years = [2030, 2040, 2050], 
    elec_act = 'electricity production, hydro, reservoir, non-alpine region', #'electricity production, hydro, run-of-river',
    ref_name = 'market for electricity, hydro, high voltage',
    fg_db_name="elec_hydro_reservoir_foreground",
    flush_fg_db = True
)

# not tested: assign_td_from_results_dict(results_dict = xx, elec_td_year=10)
# Out:
# pathways should match the premise database names, e.g., SSP1-VLLO, SSP2-M, SSP5-H
#  also IAM locations for premise database can be found through calling:
#  from premise import geomap -> premise.geomap.Geomap('image').iam_regions
# Created fresh foreground DB: 'elec_hydro_reservoir_foreground'

# %%
yy =  build_dynamic_electricity_all(
    locations = hydro_qc,
    pathways = [ "SSP1-VLLO" , "SSP2-M", "SSP5-H" ],
    years = [2030, 2040, 2050], 
    elec_act = 'electricity production, hydro, reservoir, non-alpine region',
    ref_name = 'market for electricity, hydro, high voltage',
    fg_db_name="elec_hydro_reservoir_foreground",
    flush_fg_db = False
)
# Out:
# pathways should match the premise database names, e.g., SSP1-VLLO, SSP2-M, SSP5-H
#  also IAM locations for premise database can be found through calling:
#  from premise import geomap -> premise.geomap.Geomap('image').iam_regions
# Using foreground DB: elec_hydro_reservoir_foreground, with 9 activities currently.

# %%
hydro_db = bw2data.Database("elec_hydro_reservoir_foreground")
len(hydro_db)
# Out:
# 18

# %%
list(hydro_db)
# Out:
# ['market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2040' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2050' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2040' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2040' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2050' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2050' (kWh, RoW, None)]

# %%
act_list = list(hydro_db)[2:4]
for act in act_list:
    tech_excs = list(act.technosphere())
    print(len(tech_excs))
    exc = tech_excs[0]
    print(exc)
# Out:
# 1
# Exchange: 1 kilowatt hour 'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, RoW, None) to 'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2030' (kWh, RoW, None)>
# 1
# Exchange: 1 kilowatt hour 'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, RoW, None) to 'market for electricity, hydro, high voltage, RoW, SSP5-H, 2040' (kWh, RoW, None)>

# %%
rows = []   # collect results for all acts
act_list = list(hydro_db)   
for act in act_list: 
    print(act)

    name = act.get("name")
    name_parts = [p.strip() for p in name.split(",")]
    # run static LCI + premise_GWP vs. pGWP100 first: 
    pgwp_fixedco2 = find_dpGWP100_method(name_parts[-2], int(name_parts[-1]), method_suffix = "pGWP100 - fixed-AGWPCO2")
    pgwp_dpco2 = find_dpGWP100_method(name_parts[-2], int(name_parts[-1]), method_suffix = "pGWP100 - dp-AGWPCO2")
    gwp =  ('ecoinvent-3.11', 'IPCC 2021 (incl. biogenic CO2)', 'climate change: total (incl. biogenic CO2, incl. SLCFs)', 'global warming potential (GWP100)')   

    lca_gwp = bw2calc.lca.LCA({act: 1}, method=gwp)
    lca_gwp.lci(); lca_gwp.lcia()
    score_gwp = float(lca_gwp.score)

    lca_fixed = bw2calc.lca.LCA({act: 1}, method=pgwp_fixedco2)
    lca_fixed.lci(); lca_fixed.lcia()
    score_fixedco2 = float(lca_fixed.score)

    lca_dp = bw2calc.lca.LCA({act: 1}, method=pgwp_dpco2)
    lca_dp.lci(); lca_dp.lcia()
    score_dpco2 = float(lca_dp.score)

    print(score_gwp, score_fixedco2, score_dpco2) 

    # ---- store results for this activity ----
    rows.append({
        "Activity": name,                      # index value later
        "gwp100": score_gwp,
        "pGWP100_fixedCO2": score_fixedco2,
        "pGWP100_dpCO2": score_dpco2,
    })
# Out:
# 'market for electricity, hydro, high voltage, RoW, SSP2-M, 2030' (kWh, RoW, None)
# 0.0506240716426115 0.05584781277644521 0.04991070284626162
# 'market for electricity, hydro, high voltage, RoW, SSP2-M, 2040' (kWh, RoW, None)
# 0.05016714038066257 0.05256302093778377 0.04990881578455679
# 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2030' (kWh, CA-QC, None)
# 0.0158012883553034 0.017236325178465225 0.015666238870664376
# 'market for electricity, hydro, high voltage, RoW, SSP5-H, 2040' (kWh, RoW, None)
# 0.050594952887580834 0.04985878762114201 0.04968123964054657
# 'market for electricity, hydro, high voltage, RoW, SSP2-M, 2050' (kWh, RoW, None)
# 0.04984364079505242 0.04970101534488699 0.04993021028670728
# 'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2050' (kWh, RoW, None)
# 0.04743668155690239 0.05397877348149437 0.04740237046169956
# 'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2040' (kWh, CA-QC, None)
# 0.015561841109323798 0.016342932251011334 0.015521869353196324
# 'market for electricity, hydro, high voltage, RoW, SSP5-H, 2050' (kWh, RoW, None)
# 0.050387884419407156 0.04519814216649301 0.050005979586170334
# 'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2050' (kWh, CA-QC, None)
# 0.015460680055796176 0.015388249048912811 0.01546214441738055
# 'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2030' (kWh, CA-QC, None)
# 0.015720732558650957 0.017909496424950364 0.015649619649950153
# 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2040' (kWh, CA-QC, None)
# 0.015677933911314414 0.015612622816426731 0.015559221898336563
# 'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2050' (kWh, CA-QC, None)
# 0.013657874906730162 0.015534852035032371 0.01364607085120712
# 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None)
# 0.01558249037485818 0.014036297672589812 0.015528179132344836
# 'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2040' (kWh, RoW, None)
# 0.048724343697182676 0.05504079781454591 0.048587313819745494
# 'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2030' (kWh, RoW, None)
# 0.05052321158674736 0.05726559498803554 0.05002123263004093
# 'market for electricity, hydro, high voltage, RoW, SSP5-H, 2030' (kWh, RoW, None)
# 0.05076614048384639 0.05473730101033961 0.04973538862760401
# 'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2040' (kWh, CA-QC, None)
# 0.015027617823721764 0.016988363397679975 0.015003071350999401
# 'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2030' (kWh, CA-QC, None)
# 0.015745826396561434 0.017505039575352998 0.015649436667127252

# %%
df_scores = pd.DataFrame(rows)
df_scores = df_scores.set_index("Activity")

df2 = df_scores.sort_values(by=['Activity'])
df2
# Out:
#                                                       gwp100  \
# Activity
# market for electricity, hydro, high voltage, CA...  0.015721
# market for electricity, hydro, high voltage, CA...  0.015028
# market for electricity, hydro, high voltage, CA...  0.013658
# market for electricity, hydro, high voltage, CA...  0.015746
# market for electricity, hydro, high voltage, CA...  0.015562
# market for electricity, hydro, high voltage, CA...  0.015461
# market for electricity, hydro, high voltage, CA...  0.015801
# market for electricity, hydro, high voltage, CA...  0.015678
# market for electricity, hydro, high voltage, CA...  0.015582
# market for electricity, hydro, high voltage, Ro...  0.050523
# market for electricity, hydro, high voltage, Ro...  0.048724
# market for electricity, hydro, high voltage, Ro...  0.047437
# market for electricity, hydro, high voltage, Ro...  0.050624
# market for electricity, hydro, high voltage, Ro...  0.050167
# market for electricity, hydro, high voltage, Ro...  0.049844
# market for electricity, hydro, high voltage, Ro...  0.050766
# market for electricity, hydro, high voltage, Ro...  0.050595
# market for electricity, hydro, high voltage, Ro...  0.050388
#
#                                                     pGWP100_fixedCO2  \
# Activity
# market for electricity, hydro, high voltage, CA...          0.017909
# market for electricity, hydro, high voltage, CA...          0.016988
# market for electricity, hydro, high voltage, CA...          0.015535
# market for electricity, hydro, high voltage, CA...          0.017505
# market for electricity, hydro, high voltage, CA...          0.016343
# market for electricity, hydro, high voltage, CA...          0.015388
# market for electricity, hydro, high voltage, CA...          0.017236
# market for electricity, hydro, high voltage, CA...          0.015613
# market for electricity, hydro, high voltage, CA...          0.014036
# market for electricity, hydro, high voltage, Ro...          0.057266
# market for electricity, hydro, high voltage, Ro...          0.055041
# market for electricity, hydro, high voltage, Ro...          0.053979
# market for electricity, hydro, high voltage, Ro...          0.055848
# market for electricity, hydro, high voltage, Ro...          0.052563
# market for electricity, hydro, high voltage, Ro...          0.049701
# market for electricity, hydro, high voltage, Ro...          0.054737
# market for electricity, hydro, high voltage, Ro...          0.049859
# market for electricity, hydro, high voltage, Ro...          0.045198
#
#                                                     pGWP100_dpCO2
# Activity
# market for electricity, hydro, high voltage, CA...       0.015650
# market for electricity, hydro, high voltage, CA...       0.015003
# market for electricity, hydro, high voltage, CA...       0.013646
# market for electricity, hydro, high voltage, CA...       0.015649
# market for electricity, hydro, high voltage, CA...       0.015522
# market for electricity, hydro, high voltage, CA...       0.015462
# market for electricity, hydro, high voltage, CA...       0.015666
# market for electricity, hydro, high voltage, CA...       0.015559
# market for electricity, hydro, high voltage, CA...       0.015528
# market for electricity, hydro, high voltage, Ro...       0.050021
# market for electricity, hydro, high voltage, Ro...       0.048587
# market for electricity, hydro, high voltage, Ro...       0.047402
# market for electricity, hydro, high voltage, Ro...       0.049911
# market for electricity, hydro, high voltage, Ro...       0.049909
# market for electricity, hydro, high voltage, Ro...       0.049930
# market for electricity, hydro, high voltage, Ro...       0.049735
# market for electricity, hydro, high voltage, Ro...       0.049681
# market for electricity, hydro, high voltage, Ro...       0.050006

# %%
df2.index = df2.index.str.replace("RoW", "CN", regex=False)
df2.index = df2.index.str.replace("CA-QC", "US", regex=False)
df2
# Out:
#                                                       gwp100  \
# Activity
# market for electricity, hydro, high voltage, US...  0.015721
# market for electricity, hydro, high voltage, US...  0.015028
# market for electricity, hydro, high voltage, US...  0.013658
# market for electricity, hydro, high voltage, US...  0.015746
# market for electricity, hydro, high voltage, US...  0.015562
# market for electricity, hydro, high voltage, US...  0.015461
# market for electricity, hydro, high voltage, US...  0.015801
# market for electricity, hydro, high voltage, US...  0.015678
# market for electricity, hydro, high voltage, US...  0.015582
# market for electricity, hydro, high voltage, CN...  0.050523
# market for electricity, hydro, high voltage, CN...  0.048724
# market for electricity, hydro, high voltage, CN...  0.047437
# market for electricity, hydro, high voltage, CN...  0.050624
# market for electricity, hydro, high voltage, CN...  0.050167
# market for electricity, hydro, high voltage, CN...  0.049844
# market for electricity, hydro, high voltage, CN...  0.050766
# market for electricity, hydro, high voltage, CN...  0.050595
# market for electricity, hydro, high voltage, CN...  0.050388
#
#                                                     pGWP100_fixedCO2  \
# Activity
# market for electricity, hydro, high voltage, US...          0.017909
# market for electricity, hydro, high voltage, US...          0.016988
# market for electricity, hydro, high voltage, US...          0.015535
# market for electricity, hydro, high voltage, US...          0.017505
# market for electricity, hydro, high voltage, US...          0.016343
# market for electricity, hydro, high voltage, US...          0.015388
# market for electricity, hydro, high voltage, US...          0.017236
# market for electricity, hydro, high voltage, US...          0.015613
# market for electricity, hydro, high voltage, US...          0.014036
# market for electricity, hydro, high voltage, CN...          0.057266
# market for electricity, hydro, high voltage, CN...          0.055041
# market for electricity, hydro, high voltage, CN...          0.053979
# market for electricity, hydro, high voltage, CN...          0.055848
# market for electricity, hydro, high voltage, CN...          0.052563
# market for electricity, hydro, high voltage, CN...          0.049701
# market for electricity, hydro, high voltage, CN...          0.054737
# market for electricity, hydro, high voltage, CN...          0.049859
# market for electricity, hydro, high voltage, CN...          0.045198
#
#                                                     pGWP100_dpCO2
# Activity
# market for electricity, hydro, high voltage, US...       0.015650
# market for electricity, hydro, high voltage, US...       0.015003
# market for electricity, hydro, high voltage, US...       0.013646
# market for electricity, hydro, high voltage, US...       0.015649
# market for electricity, hydro, high voltage, US...       0.015522
# market for electricity, hydro, high voltage, US...       0.015462
# market for electricity, hydro, high voltage, US...       0.015666
# market for electricity, hydro, high voltage, US...       0.015559
# market for electricity, hydro, high voltage, US...       0.015528
# market for electricity, hydro, high voltage, CN...       0.050021
# market for electricity, hydro, high voltage, CN...       0.048587
# market for electricity, hydro, high voltage, CN...       0.047402
# market for electricity, hydro, high voltage, CN...       0.049911
# market for electricity, hydro, high voltage, CN...       0.049909
# market for electricity, hydro, high voltage, CN...       0.049930
# market for electricity, hydro, high voltage, CN...       0.049735
# market for electricity, hydro, high voltage, CN...       0.049681
# market for electricity, hydro, high voltage, CN...       0.050006

# %%
df2.to_excel("dp-LCI_output/staticLCI_(p)GWP100/hydro_reservoir_CN-asRoW_US-asQC_staticLCI_threeGWP100.xlsx")

# %% [markdown]
# ### 2. building dpLCI

# %%
hydro_db = bw2data.Database("elec_hydro_reservoir_foreground")
list(hydro_db)
# Out:
# ['market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2050' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2050' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2030' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP1-VLLO, 2030' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP2-M, 2040' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2040' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, RoW, SSP2-M, 2050' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP1-VLLO, 2040' (kWh, CA-QC, None),
#  'market for electricity, hydro, high voltage, RoW, SSP5-H, 2050' (kWh, RoW, None),
#  'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2040' (kWh, CA-QC, None)]

# %% [markdown]
# #### just run QC/ 2050 / SSP5

# %%
hydro_db_2050 = [
    act for act in hydro_db 
    if  "2050" in str(act.get('name', '')) and  "QC" in str(act.get('name', '')) and  "SSP5" in str(act.get('name', ''))   #or  "2030" in str(act.get('name', '') )
]

hydro_db_2050
# Out:
# ['market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None)]

# %%
database_dates = {
    #'ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-24': datetime.strptime("2030", "%Y"),
    #'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22': datetime.strptime("2040", "%Y"),
    #'ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22': datetime.strptime("2050", "%Y"),

    #'ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22': datetime.strptime("2030", "%Y"),
    #'ei_cutoff_3.11_image_SSP2-M_2040 2025-11-22': datetime.strptime("2040", "%Y"),
    #'ei_cutoff_3.11_image_SSP2-M_2050 2025-11-22': datetime.strptime("2050", "%Y"),

    #'ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22': datetime.strptime("2030", "%Y"),
    #'ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22': datetime.strptime("2040", "%Y"),
    'ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22': datetime.strptime("2050", "%Y"),
    
    "elec_hydro_reservoir_foreground": "dynamic", # flag databases that should be temporally distributed with "dynamic"
}

# %% [raw]
# find_dpGWP100_method('SSP1-VLLO', 2030, method_suffix = "pGWP100 - dp-AGWPCO2")

# %%
dp_results = {}

for act in list(hydro_db_2050): 
    print(act)
 
    #### dynamic LCI:: 
    assign_td_from_foreground_db( 
        select_act = act,
        elec_td_year=10,
        resolution="Y",
        kind="uniform",
        fg_db_name="elec_hydro_reservoir_foreground",
        verbose = True
     )

    tlca = run_dp_timex_lca(foreground_act = act ,   
                    pathway = None,
                    year = None,
                    method = None,
                    database_dates = None, # database_dates, #None not working, has to incl. all 9 background DB ... 
                    temporal_grouping="year", 
                    method_prefix = "Climate Change prospective GWP100",
                    method_suffix = "pGWP100 - fixed-AGWPCO2", 
                    fg_db_name = 'elec_hydro_reservoir_foreground'
     )

    tlca.lci()
    tlca.dynamic_inventory.shape

    # dyn-foreground LCI + static background LCI + pGWP100
    lca_0 = tlca.base_score 
    print(lca_0)
    # dpLCI (dyn-foreground LCI + dyn background LCI) +  pGWP100
    tlca.static_lcia()
    lca_1 = tlca.static_score
    print(lca_1)

    act_name = act.get("name")
    dp_results[act_name] = {
        "dyn FG LCI static BG p-LCI, pGWP100-fixedCO2": float(lca_0),   # static BG LCI + dyn FG LCI
        "full dp-LCI, pGWP100-fixedCO2": float(lca_1),      # dyn BG LCI + dyn FG LCI
    }

    #### now save all dyLCI flows to pandas 
    df = tlca.dynamic_inventory_df

    ##### important to convert flow and act as str to excel 
    df["flow"] = df["flow"].astype(str)
    df["activity"] = df["activity"].astype(str)

    ### export df to dp-LCI_output folder, using the act name as the excel name 
    out_dir = "dp-LCI_output/hydro_dpLCI_v2_reservoir"
    os.makedirs(out_dir, exist_ok=True)    
    raw_name = act["name"]
    safe_name = re.sub(r"[^A-Za-z0-9_\-()]+", "_", raw_name)   # replace spaces/special chars
    
    excel_path = os.path.join(out_dir, f"{safe_name}.xlsx")
    
    df.to_excel(excel_path, index=False)    
    print(f"✔ Exported dynamic inventory DF for '{raw_name}' → {excel_path}")


import pickle

out_dir = "dp-LCI_output/hydro_dpLCI_v2_reservoir"
os.makedirs(out_dir, exist_ok=True)

pickle_path = os.path.join(out_dir, "hydro_v2_reservoir_dp_results_MY2030_2050.pkl")

with open(pickle_path, "wb") as f:
    pickle.dump(dp_results, f)

print(f"✔ Saved dp_results dictionary → {pickle_path}")
# Out:
# 2025-12-18 10:58:47.583 | INFO     | bw_timex.timex_lca:__init__:114 - Initializing TimexLCA object...
# 2025-12-18 10:58:47.585 | INFO     | bw_timex.timex_lca:__init__:136 - Collecting node infos...
# 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None)
# TD applied to 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' → Exchange: 1 kilowatt hour 'electricity production, hydro, reservoir, non-alpine region' (kilowatt hour, CA-QC, None) to 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None)>
# for the activity 'market for electricity, hydro, high voltage, CA-QC, SSP5-H, 2050' (kWh, CA-QC, None),it's under SSP-SSP5-H, year-2050
#  we'll use LCIA ('Climate Change prospective GWP100', 'SSP585', 'MY2050', 'pGWP100 - fixed-AGWPCO2')  with background database.datetime = {'ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22': datetime.datetime(2050, 1, 1, 0, 0), 'elec_hydro_reservoir_foreground': 'dynamic'}
# 2025-12-18 10:59:00.975 | INFO     | bw_timex.timex_lca:build_timeline:216 - No edge filter function provided. Skipping all edges in background databases.
# 2025-12-18 10:59:04.005 | INFO     | bw_timex.timex_lca:build_timeline:232 - Calculating base LCA...
# 2025-12-18 10:59:12.888 | INFO     | bw_timex.timex_lca:build_timeline:242 - Creating activity time mapping...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 16
#       6 #### dynamic LCI::
#       7 assign_td_from_foreground_db(
#       8     select_act = act,
#       9     elec_td_year=10,
#    (...)     13     verbose = True
#      14  )
# ---> 16 tlca = run_dp_timex_lca(foreground_act = act ,
#      17                 pathway = None,
#      18                 year = None,
#      19                 method = None,
#      20                 database_dates = None, # database_dates, #None not working, has to incl. all 9 background DB ...
#      21                 temporal_grouping="year",
#      22                 method_prefix = "Climate Change prospective GWP100",
#      23                 method_suffix = "pGWP100 - fixed-AGWPCO2",
#      24                 fg_db_name = 'elec_hydro_reservoir_foreground'
#      25  )
#      27 tlca.lci()
#      28 tlca.dynamic_inventory.shape
#
# File ~/dpLCA_main/Elec_case/dynLCI/../utils/elec_builder.py:476, in run_dp_timex_lca(foreground_act, pathway, year, method, database_dates, temporal_grouping, method_prefix, method_suffix, fg_db_name)
#     474 tlca = TimexLCA({foreground_act: 1}, method, database_dates)
#     475 # 4. Build timeline
# --> 476 tlca.build_timeline(temporal_grouping=temporal_grouping)
#     478 return tlca
#
# File ~/miniconda3/envs/bw2_timex_env/lib/python3.12/site-packages/bw_timex/timex_lca.py:251, in TimexLCA.build_timeline(self, starting_datetime, temporal_grouping, interpolation_type, edge_filter_function, cutoff, max_calc, *args, **kwargs)
#     245 self.activity_time_mapping = TimeMappingDict(
#     246     start_id=bd.backends.ActivityDataset.select(fn.MAX(AD.id)).scalar() + 1
#     247 )  # making sure we get unique ids by counting up from the highest current activity id
#     249 # pre-populate the activity time mapping dict with the static activities.
#     250 # Doing this here because we need the temporal grouping for consistent time resolution.
# --> 251 self.add_static_activities_to_activity_time_mapping()
#     253 # Create timeline builder that does the graph traversal (similar to bw_temporalis) and
#     254 # extracts all edges with their temporal information. Can later be used to build a timeline
#     255 # with the TimelineBuilder.build_timeline() method.
#     256 self.timeline_builder = TimelineBuilder(
#     257     self.base_lca,
#     258     self.starting_datetime,
#    (...)    270     **kwargs,
#     271 )
#
# File ~/miniconda3/envs/bw2_timex_env/lib/python3.12/site-packages/bw_timex/timex_lca.py:1306, in TimexLCA.add_static_activities_to_activity_time_mapping(self)
#    1304 for idx in self.base_lca.dicts.activity.keys():  # activity ids
#    1305     key = self.base_lca.remapping_dicts["activity"][idx]  # ('database', 'code')
# -> 1306     time = self.database_dates[
#    1307         key[0]
#    1308     ]  # datetime (or 'dynamic' for foreground processes)
#    1309     if isinstance(time, str):  # if 'dynamic', just add the string
#    1310         self.activity_time_mapping.add((key, time), unique_id=idx)
#
# KeyError: 'ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22'
