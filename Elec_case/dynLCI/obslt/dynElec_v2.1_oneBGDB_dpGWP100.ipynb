# %%
import bw2data, bw2io
#from premise import *
#import bw_timex
from bw_timex import TimexLCA
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np
from datetime import datetime

# %%
# activate the bw project
bw2data.projects.set_current("ei311")
for db in bw2data.databases:
    print(db, len(bw2data.Database(db)))
# Out:
# ecoinvent-3.11-biosphere 9795
# ecoinvent-3.11-cutoff 25412
# ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21 37360
# ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21 37361
# ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21 37361
# ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22 41755
# ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22 41759
# ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22 41762
# ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22 41789
# ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22 41754
# ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22 41789
# ei_cutoff_3.11_image_SSP2-M_2040 2025-11-22 41759
# ei_cutoff_3.11_image_SSP2-M_2050 2025-11-22 41762
# ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-24 41774
# elec_foreground 1

# %% [markdown]
# ## step1: prepare dynamic LCI

# %%
image_ssp1_db_2030 = bw2data.Database("ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-24")
image_ssp1_db_2040 = bw2data.Database("ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22")
image_ssp1_db_2050 = bw2data.Database("ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22")

# %%
if "elec_foreground" in bw2data.databases:
    del bw2data.databases["elec_foreground"]  
foreground = bw2data.Database("elec_foreground")
foreground.register()

# %% [markdown]
# ### create new foreground DB
# #### need foreground helper::
# - depending on which location, e.g., CAN, or any other location provided by the premise background database, we'll create a final elec_highvol_loc_1kwh, as the new foreground activity to be assigned with dynamic inventory

# %% [markdown]
# ####  need background SSP/year mapping helper::
# - e.g., if we're studying 2030 elec grid for image_ssp1, then using the image_ssp1_db_2030 background database to search for bw2_act: "market group for electricity, high voltage", also location == user-input location e.g., "CAN"

# %%
elec_ssp1_2040_production = image_ssp1_db_2040.get(name="market group for electricity, high voltage", location="CAN")
print(elec_ssp1_2040_production)
# Out:
# 'market group for electricity, high voltage' (kilowatt hour, CAN, None)

# %%
elec_highvol_CAN_1kwh = foreground.new_node("elec_highvol_CAN_1kwh", 
                                            name="electricity mix, high voltage, Canada", 
                                            location = "CAN", unit="kWh")

elec_highvol_CAN_1kwh['reference product'] = "one kWh electricity mix, high voltage"
elec_highvol_CAN_1kwh.new_edge(input=elec_highvol_CAN_1kwh, amount=1, type="production").save()

### because temporal_distribution MUST be attached to the exchange, not the activity in bw_temporalis ###
input_elec_to_highvol_CAN_1kwh = elec_highvol_CAN_1kwh.new_edge(
    input=elec_ssp1_2040_production,
    amount=1,
    type="technosphere",
)

elec_highvol_CAN_1kwh.save()

# %%
len(elec_highvol_CAN_1kwh.technosphere())
# Out:
# 0

# %%
elec_highvol_CAN_1kwh.as_dict()
# Out:
# {'database': 'elec_foreground',
#  'code': 'elec_highvol_CAN_1kwh',
#  'location': 'CAN',
#  'name': 'electricity mix, high voltage, Canada',
#  'unit': 'kWh',
#  'reference product': 'one kWh electricity mix, high voltage'}

# %%
input_elec_to_highvol_CAN_1kwh
# Out:
# Exchange: 1 kilowatt hour 'market group for electricity, high voltage' (kilowatt hour, CAN, None) to 'electricity mix, high voltage, Canada' (kWh, CAN, None)>

# %%
elec_MY = 10

td_elec = easy_timedelta_distribution(
    start=0,
    end=elec_MY,
    resolution="Y",
    steps=(elec_MY + 1),
    kind="uniform",  
)
td_elec.graph(resolution="Y") 
# if `M` month resolution, so later tlca.build_timeline(temporal_grouping="month")
# Out:
# <Axes: xlabel='Time (Years)', ylabel='Amount'>

# %%
input_elec_to_highvol_CAN_1kwh["temporal_distribution"] = td_elec
input_elec_to_highvol_CAN_1kwh.save()

# %% [markdown]
# ## map to background premise

# %% [markdown]
# #### mapping foreground -> background datetime helper::
# - it's important to choose the right background database and datetime for the dynamic foreground:
# - e.g., if we're studying 2040&ssp1 electricity, like above elec_ssp1_2040_production = image_ssp1_db_2040.get, then the database_dates ={} below use the same SSP/year e.g.,  image_ssp1_db_2040.name: datetime.strptime("2040", "%Y"),
#
#
#     database_dates = {
#         #image_ssp1_db_2030.name: datetime.strptime("2030", "%Y"),
#         image_ssp1_db_2040.name: datetime.strptime("2040", "%Y"),
#         #image_ssp1_db_2050.name: datetime.strptime("2050", "%Y"),
#         "elec_foreground": "dynamic", # flag databases that should be temporally distributed with "dynamic"
#     }

# %%
database_dates = {
    #image_ssp1_db_2030.name: datetime.strptime("2030", "%Y"),
    image_ssp1_db_2040.name: datetime.strptime("2040", "%Y"),
    #image_ssp1_db_2050.name: datetime.strptime("2050", "%Y"),
    "elec_foreground": "dynamic", # flag databases that should be temporally distributed with "dynamic"
}

database_dates
# Out:
# {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22': datetime.datetime(2040, 1, 1, 0, 0),
#  'elec_foreground': 'dynamic'}

# %% [markdown]
# ### ready to instanciate tlca

# %%
method =  ('Climate Change prospective GWP100',
  'SSP119',
  'MY2040',
  'pGWP100 with with dp-AGWPCO2')
#('ecoinvent-3.11', 'IPCC 2021 (incl. biogenic CO2)', 'climate change: total (incl. biogenic CO2, incl. SLCFs)', 'global warming potential (GWP100)')  
#('ecoinvent-3.11', 'CML v4.8 2016', 'climate change', 'global warming potential (GWP100)')

# %%
tlca = TimexLCA({elec_highvol_CAN_1kwh: 1}, method, database_dates)
# Out:
# 2025-11-26 13:58:56.471 | INFO     | bw_timex.timex_lca:__init__:114 - Initializing TimexLCA object...
# 2025-11-26 13:58:56.473 | INFO     | bw_timex.timex_lca:__init__:136 - Collecting node infos...

# %%
# build a timeline of the exchanges: if `M` for td, then month here 
tlca.build_timeline(temporal_grouping="year")
# Out:
# 2025-11-26 13:59:00.570 | INFO     | bw_timex.timex_lca:build_timeline:216 - No edge filter function provided. Skipping all edges in background databases.
# 2025-11-26 13:59:03.392 | INFO     | bw_timex.timex_lca:build_timeline:232 - Calculating base LCA...
# 2025-11-26 13:59:08.740 | INFO     | bw_timex.timex_lca:build_timeline:242 - Creating activity time mapping...
# 2025-11-26 13:59:08.994 | INFO     | bw_timex.timeline_builder:__init__:99 - Traversing supply chain graph...
# 2025-11-26 13:59:09.139 | INFO     | bw_timex.timeline_builder:build_timeline:142 - Building timeline...
# 2025-11-26 13:59:09.174 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2026-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.175 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2026-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.175 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2027-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.176 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2028-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.177 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2029-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.177 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2030-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.178 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2031-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.179 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2032-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.179 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2033-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.180 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2034-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.181 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2035-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# 2025-11-26 13:59:09.182 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:522 - Reference date 2036-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
# Starting graph traversal
# Calculation count: 1
#    date_producer                               producer_name date_consumer  \
# 0     2026-01-01  market group for electricity, high voltage    2026-01-01
# 1     2026-01-01       electricity mix, high voltage, Canada    2026-01-01
# 2     2027-01-01  market group for electricity, high voltage    2026-01-01
# 3     2028-01-01  market group for electricity, high voltage    2026-01-01
# 4     2029-01-01  market group for electricity, high voltage    2026-01-01
# 5     2030-01-01  market group for electricity, high voltage    2026-01-01
# 6     2031-01-01  market group for electricity, high voltage    2026-01-01
# 7     2032-01-01  market group for electricity, high voltage    2026-01-01
# 8     2033-01-01  market group for electricity, high voltage    2026-01-01
# 9     2034-01-01  market group for electricity, high voltage    2026-01-01
# 10    2035-01-01  market group for electricity, high voltage    2026-01-01
# 11    2036-01-01  market group for electricity, high voltage    2026-01-01
#
#                             consumer_name    amount  \
# 0   electricity mix, high voltage, Canada  0.090909
# 1                                      -1       1.0
# 2   electricity mix, high voltage, Canada  0.090909
# 3   electricity mix, high voltage, Canada  0.090909
# 4   electricity mix, high voltage, Canada  0.090909
# 5   electricity mix, high voltage, Canada  0.090909
# 6   electricity mix, high voltage, Canada  0.090909
# 7   electricity mix, high voltage, Canada  0.090909
# 8   electricity mix, high voltage, Canada  0.090909
# 9   electricity mix, high voltage, Canada  0.090909
# 10  electricity mix, high voltage, Canada  0.090909
# 11  electricity mix, high voltage, Canada  0.090909
#
#                                temporal_market_shares
# 0   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 1                                                None
# 2   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 3   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 4   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 5   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 6   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 7   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 8   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 9   {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 10  {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...
# 11  {'ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-...

# %%
# calculate the time-explicit LCI, with TimexLCA.lci()
tlca.lci()
# Out:
# 2025-11-26 13:59:09.522 | INFO     | bw_timex.timex_lca:lci:360 - Expanding matrices...
# 2025-11-26 13:59:09.539 | INFO     | bw_timex.timex_lca:lci:379 - Calculating dynamic inventory...

# %%
tlca.dynamic_inventory # the new dynamic_inventory that was now created,
# instead of one row for each emission in the biosphere database we now get one row for each emission at each point in time.
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 30635 stored elements and shape (36102, 41802)>

# %%
tlca.dynamic_inventory.shape
# w/h three background DB datatime, it becomes (36102, 125365)
# Out:
# (36102, 41802)

# %%
#the dynamic inventory is calculated as a sparse matrix, more human-friendly version as a pandas:
tlca.dynamic_inventory_df.head()
# Out:
#            date    amount                flow            activity
# 2212 2026-01-01  2.583415  250401799139369058  251340274252521474
# 612  2026-01-01  1.960198  250401797902049299  251340274252521474
# 280  2026-01-01  0.481565  250401797688139822  251340274252521474
# 273  2026-01-01  0.323820  250401797688139804  251340274252521474
# 1343 2026-01-01  0.323770  250401798346645610  251340274252521474

# %% [markdown]
# ####  foreground + one background snapshot

# %%
tlca.base_score # this is BW2 static score  foreground + one background snapshot
# Out:
# -0.031080350557283015

# %% [markdown]
# #### relinking foreground -> time-specific background DBs; score differs ONLY IF multiple BGD-DB selected

# %%
### dynamic lci with the static GWP , if only one BGDB selected, almost same score as static LCIA
tlca.static_lcia()
tlca.static_score   #kg CO2-eq

#tlca.static_score  # 0.07955713173198123 if three 2030/2040/2050 BGDG chosen
# Out:
# -0.0310803505572832

# %% [raw]
# # check if timex_CF can't read the new dpGWP LCIA (import bw2pacakge won't work, need create new LCIA)
# #for flow, cf in bw2data.Method(method).load()[:3]:
# #    print(flow, type(flow), cf)

# %%
#tlca.dynamic_lcia(metric="radiative_forcing", fixed_time_horizon=True)
tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon = 100)
tlca.dynamic_score
# Out:
# 2025-11-26 14:03:14.229 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 0.12358805880179904

# %% [markdown]
# ## step2:: some plot / analysis on dyn-LCI/LCIA

# %% [markdown]
# ### plot dynamic inventory per emission flow

# %%
mybio = bw2data.Database('ecoinvent-3.11-biosphere')

# %% [raw]
# co2_fossil = [x for x in mybio if 'Carbon dioxide, fossil' in str(x)]
# ch4_fossil = [x for x in mybio if 'Methane, fossil' in str(x)]
# print(len(co2_fossil), len(ch4_fossil))

# %%
#"Carbon dioxide, in air", with a CF of -1 :: 250401797923020800 
#"Carbon dioxide, non-fossil, resource correction" ::  250401799114203150

# %% [raw]
# [x for x in mybio if 'Carbon dioxide, in air' in str(x)  ][0].as_dict()

# %% [raw]
# #"Carbon dioxide, non-fossil, resource correction",
# [x for x in mybio if 'Carbon dioxide, non-fossil, resource correction' in str(x)  ][0].as_dict()

# %%
tlca.plot_dynamic_inventory(bio_flows = [250401798745104436]) #ch4-non fossil

#tlca.plot_dynamic_inventory(bio_flows = [250401797683945508]) #ch4-fossil 
#tlca.plot_dynamic_inventory(bio_flows = [250401798669606930]) #co2

# %%
from bw2data import get_activity
print(get_activity(250401798669606930))
# Out:
# 'Carbon dioxide, fossil' (kilogram, None, ('air',))

# %%
df = tlca.dynamic_inventory_df
df_co2_air = df[df['flow'] == 250401798669606930]   #co2
df_co2_air
# Out:
#             date    amount                flow            activity
# 1729  2026-01-01 -0.001466  250401798669606930  251340274252521474
# 4514  2027-01-01 -0.001466  250401798669606930  251340274252521476
# 7299  2028-01-01 -0.001466  250401798669606930  251340274252521477
# 10084 2029-01-01 -0.001466  250401798669606930  251340274252521478
# 12869 2030-01-01 -0.001466  250401798669606930  251340274252521479
# 15654 2031-01-01 -0.001466  250401798669606930  251340274252521480
# 18439 2032-01-01 -0.001466  250401798669606930  251340274252521481
# 21224 2033-01-01 -0.001466  250401798669606930  251340274252521482
# 24009 2034-01-01 -0.001466  250401798669606930  251340274252521483
# 26794 2035-01-01 -0.001466  250401798669606930  251340274252521484
# 29579 2036-01-01 -0.001466  250401798669606930  251340274252521485

# %% [markdown]
# ###  why  fixed_time_horizon=False:
#
# - Fixed time horizon means that the time horizon for all emissions (no matter when they occur) starts counting at the time of the functional unit, resulting in shorter time horizons for emissions occuring later. This approach has been proposed by Levasseur et al. 2010 to harmonize the time frame chosen for the analysis and the time period covered by the LCA results. If the time horizon is not fixed (this is what conventional impact assessment factors assume), it starts counting from the timing of the emission.

# %%
#tlca.dynamic_lcia(metric="radiative_forcing", fixed_time_horizon=True)
#tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon = 100)
#tlca.dynamic_score
# Out:
# 2025-11-25 20:01:30.122 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 0.12366576424167698

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True)
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=False)
#tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True, cumsum=True)

# %% [markdown]
# ### waterfall to compare GWP100, pGWP100, dpGWP

# %%
s_p_scores = {}
for exc in elec_highvol_CAN_1kwh.technosphere():    
    #tlca.base_lca.lcia(demand={exc.input.id: exc.amount})
    s_p_scores[exc.input["name"]] = tlca.static_score

# %%
from bw_timex.utils import plot_characterized_inventory_as_waterfall

# only one process
#order_stacked_activities = (    [  elec_highvol_CAN_1kwh["name"] ])

plot_characterized_inventory_as_waterfall(
    tlca,
    static_scores=s_p_scores,
    prospective_scores=s_p_scores, # caz we use pGWP100 here, the static_score is actuall p_score
    #order_stacked_activities=order_stacked_activities,
)

# %% [markdown]
# ## negative CO2 (in air) (resource correction) not included in timex_dynCF

# %% [markdown]
# ![image.png](attachment:54d016f4-5669-4b21-94c6-23f3b21013d8.png)

# %%
dyn = tlca.characterized_inventory   # after dynamic_lcia
print(dyn.groupby("flow")["amount"].sum().sort_values(ascending=True).head(20))
dyn.head()
# Out:
# flow
# 250401798669606930   -1.612983e-02
# 250401797755248709   -9.420477e-08
# 250401798443114499   -2.300982e-08
# 250401798669606942    1.633907e-15
# 250401798778658821    8.647992e-15
# 250401797805580382    9.866460e-15
# 250401798346645528    2.117137e-14
# 250401798594109483    5.516488e-13
# 250401798594109452    1.183827e-12
# 250401798166290508    2.056883e-12
# 250401798250176534    2.265587e-12
# 250401799110008842    2.951424e-12
# 250401798644441126    8.430609e-12
# 250401799428775954    8.552497e-12
# 250401797709111342    1.679718e-11
# 250401797755248645    4.631670e-11
# 250401797709111341    8.004450e-11
# 250401799470718979    1.045076e-10
# 250401798229205114    1.555120e-10
# 250401799307141151    3.070604e-10
# Name: amount, dtype: float64
#         date        amount                flow            activity
# 0 2026-01-01 -1.466348e-03  250401798669606930  251340274252521474
# 1 2026-01-01 -8.564070e-09  250401797755248709  251340274252521474
# 2 2026-01-01 -2.091802e-09  250401798443114499  251340274252521474
# 3 2026-01-01  1.485370e-16  250401798669606942  251340274252521474
# 4 2026-01-01  7.861811e-16  250401798778658821  251340274252521474

# %%
# the top 3 negative flows from bio-CO2
from bw2data import get_activity
print(get_activity(250401797755248709))
print(get_activity(250401798443114499))
print(get_activity(250401798443114499))
# Out:
# 'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil', 'agricultural'))
# 'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil',))
# 'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil',))

# %% [raw]
# from bw2calc import LCA
#
# lca = LCA({elec_ssp1_2040_production:1}, method)
# lca.lci()
# lca.lcia()
# print("pGWP100 score:", lca.score)
#
# # all EFs captured:
# stat_alEF = lca.biosphere_mm.row_mapper.to_dict()
# len(stat_alEF) , type(stat_alEF)
#
# keys_to_check = {250401797923020800, 250401799114203150}
# #"Carbon dioxide, in air", with a CF of -1 :: 250401797923020800
# #"Carbon dioxide, non-fossil, resource correction" ::  250401799114203150
# present_keys = keys_to_check.intersection(stat_alEF.keys())
# if present_keys:
#     print("Found key(s):", present_keys)
# else:
#     print("No keys found")

# %% [markdown]
# ### these two negative CO2 flows are in the dynLCI, but not dynCF

# %%
dyn = tlca.characterized_inventory 
keys_to_check = {250401797923020800, 250401799114203150}
present_keys = keys_to_check.intersection(dyn['flow'].unique())
if present_keys:
    print("Found key(s):", present_keys)
else:
    print("No keys found")
# Out:
# Found key(s): {250401797923020800, 250401799114203150}

# %%
filtered_dyn_negCO2 = dyn[dyn["flow"].isin(keys_to_check)]
filtered_dyn_negCO2
# Out:
#           date    amount                flow            activity
# 60  2026-01-01  0.002869  250401799114203150  251340274252521474
# 61  2026-01-01  0.004163  250401797923020800  251340274252521474
# 122 2027-01-01  0.002869  250401799114203150  251340274252521476
# 123 2027-01-01  0.004163  250401797923020800  251340274252521476
# 184 2028-01-01  0.002869  250401799114203150  251340274252521477
# 185 2028-01-01  0.004163  250401797923020800  251340274252521477
# 246 2029-01-01  0.002869  250401799114203150  251340274252521478
# 247 2029-01-01  0.004163  250401797923020800  251340274252521478
# 308 2030-01-01  0.002869  250401799114203150  251340274252521479
# 309 2030-01-01  0.004163  250401797923020800  251340274252521479
# 370 2031-01-01  0.002869  250401799114203150  251340274252521480
# 371 2031-01-01  0.004163  250401797923020800  251340274252521480
# 432 2032-01-01  0.002869  250401799114203150  251340274252521481
# 433 2032-01-01  0.004163  250401797923020800  251340274252521481
# 494 2033-01-01  0.002869  250401799114203150  251340274252521482
# 495 2033-01-01  0.004163  250401797923020800  251340274252521482
# 556 2034-01-01  0.002869  250401799114203150  251340274252521483
# 557 2034-01-01  0.004163  250401797923020800  251340274252521483
# 618 2035-01-01  0.002869  250401799114203150  251340274252521484
# 619 2035-01-01  0.004163  250401797923020800  251340274252521484
# 680 2036-01-01  0.002869  250401799114203150  251340274252521485
# 681 2036-01-01  0.004163  250401797923020800  251340274252521485

# %% [markdown]
# ## step3:: filter out GHG flows, for the new dpGWP LCIA

# %%
mybio = bw2data.Database('ecoinvent-3.11-biosphere')

# %%
df = tlca.dynamic_inventory_df
#[x for x in mybio if 'Carbon dioxide, fossil' in str(x)][0].as_dict()

# %%
#df
#all_ef = np.unique(df['flow'] )
#print(len(all_ef))

# %%
from bw2data import get_activity

method = ('ecoinvent-3.11',
  'IPCC 2021 (incl. biogenic CO2)',
  'climate change: total (incl. biogenic CO2, incl. SLCFs)',
  'global warming potential (GWP100)')  

loaded_m = bw2data.Method(method).load()   

flow_dict = {}

# keep all the ghg flows in a meta dict, with keys as the flow 'id'
for fid, cf in loaded_m:         
    act = get_activity(fid)
    flow_dict[fid] = act.as_dict()


df_ghg = df[df['flow'].isin(flow_dict.keys())].copy()

df_ghg
# Out:
#             date        amount                flow            activity
# 621   2026-01-01  4.163197e-03  250401797923020800  251340274252521474
# 2167  2026-01-01  2.869412e-03  250401799114203150  251340274252521474
# 574   2026-01-01  2.515586e-03  250401797876883529  251340274252521474
# 2155  2026-01-01  1.491888e-03  250401799110008870  251340274252521474
# 2658  2026-01-01  5.804681e-04  250401799567187993  251340274252521474
# ...          ...           ...                 ...                 ...
# 29997 2036-01-01  1.152072e-17  250401799110008842  251340274252521485
# 28247 2036-01-01  2.510449e-21  250401797755248741  251340274252521485
# 29739 2036-01-01  9.897443e-32  250401798837379133  251340274252521485
# 30224 2036-01-01  7.623153e-33  250401799277781018  251340274252521485
# 29579 2036-01-01 -1.466348e-03  250401798669606930  251340274252521485
#
# [1133 rows x 4 columns]

# %%
df_year_agg = (
    df.groupby(['year', 'flow'], as_index=False)
      .agg({'amount': 'sum'})
)

# %%
df_year_agg
# Out:
#        year                flow        amount
# 0      2026  250401797453258752  7.932527e-18
# 1      2026  250401797453258766  1.112640e-10
# 2      2026  250401797453258768  2.971286e-08
# 3      2026  250401797453258769  2.931021e-20
# 4      2026  250401797453258770  5.079233e-18
# ...     ...                 ...           ...
# 30630  2036  250401799659462718  1.014173e-12
# 30631  2036  250401799659462722  1.316604e-16
# 30632  2036  250401799659462727  1.509524e-07
# 30633  2036  250401799659462730  1.513620e-19
# 30634  2036  250401799659462736  4.637887e-13
#
# [30635 rows x 3 columns]

# %%
#for flow_id in all_ef: 
    #flow = [x for x in mybio if str(x.as_dict()['id']) == str(flow_id)] 
    #if len(flow) == 1:
    #    if flow[0]('type') == 'emission'
    #        print(flow[0]['name']) 
    #else:
    #    print(f"no unique flow found {len(flow)}")
# Out:
# Flurochloridone
# Phenol
# Solids, inorganic
# Prothioconazole
# Sulfadiazine
# Pentachlorobenzene
# Azinphos-methyl
# Thiobencarb
# Carbon
# m-Xylene
# Transformation, to dump site
# Mancozeb
# Iodine-131
# Flurochloridone
# Chlorothalonil
# Transformation, to annual crop, irrigated
# Phosphorus
# Dibenz(a,h)anthracene
# Terbuthylazin
# Ethyl benzene
# Radium-226
# Beryllium II
# Copper oxide
# Acrylate
# Cyanide
# Bromate
# Propaquizafop
# Carbon disulfide
# Ethylene oxide
# Beryllium II
# Peracetic acid
# Barium II
# Acetamiprid
# Spirotetramat
# Radon-220
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Magnesium
# Hydrocarbons, unspecified
# Cupric hydroxide
# Beryllium II
# Uranium-238
# Aluminium III
# Lambda-cyhalothrin
# Hydrogen peroxide
# Acetamiprid
# Isobutanol
# Dinitrogen monoxide
# Phosphorus
# Diquat
# Transformation, from dump site, residual material landfill
# Chlorimuron-ethyl
# Paraquat
# Oxydemeton-methyl
# Iridium
# Mecoprop-P
# t-Butyl amine
# Copper ion
# Transformation, to pasture, man made, extensive
# Chlorothalonil
# Butene
# Trinexapac-ethyl
# Vanadium V
# Boron
# Metolachlor
# Water
# Spinosad
# Scandium
# Bromine
# Non-hazardous waste disposed
# Ioxynil
# Titanium ion
# Fluoxastrobin
# Desmedipham
# Etofenprox
# Acenaphthene
# Dichloromethane
# Caesium-137
# Nitrogen, organic bound
# Xenon-137
# Radium-228
# Carfentrazone-ethyl
# N,N-Dimethylformamide
# Metsulfuron-methyl
# Tritosulfuron
# Thorium-230
# Acetonitrile
# Chromium VI
# Isohexane
# Diuron
# Boron
# Scandium
# Atrazine
# Radium-226
# Strontium II
# Titanium ion
# Mesotrione
# Diisobutyl ketone
# Barium-140
# Pyridate
# Glutaraldehyde
# Ethylene oxide
# Formic acid
# Epoxiconazole
# Silicon
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Sulfate
# Hydrocarbons, aliphatic, alkanes, unspecified
# Triclopyr
# Dimethachlor
# Dichlorprop-P
# Iron ion
# BOD5, Biological Oxygen Demand
# Ametryn
# Silicon
# Silicon tetrachloride
# Uranium-238
# Methyl acrylate
# Sulfur
# Thorium-232
# 1,1,2-Trichloroethane
# Argon-41
# Pyrimethanil
# Transformation, from forest, secondary (non-use)
# Dimethyldichlorosilane
# 2,4-DB
# Cloquintocet-mexyl
# Mandipropamid
# 1,4-Diethylbenzene
# Olivine
# BOD5, Biological Oxygen Demand
# Florasulam
# Clopyralid
# Helium
# Dimethenamide
# Hydrocarbons, aliphatic, alkanes, unspecified
# Thiram
# Carbon
# Zinc II
# Barium
# Methyl acetate
# Urea
# Cyanide
# Imidacloprid
# o-Chlorotoluene
# Benalaxyl-M
# Selenium IV
# Carbosulfan
# Mesotrione
# Lambda-cyhalothrin
# Aldehydes, unspecified
# Barium II
# Occupation, forest, intensive
# Haloxyfop-ethoxyethyl
# Atrazine
# Difenoconazole
# Nitrogen dioxide
# 2,4-D ester
# Transformation, to pasture, man made
# Pesticides, unspecified
# Paraquat
# Amidosulfuron
# Chlorothalonil
# Propiconazole
# Wood, unspecified, standing
# Transformation, to urban/industrial fallow (non-use)
# Phosphorous acid
# Spiroxamine
# Transformation, to heterogeneous, agricultural
# Acenaphthene
# Fludioxonil
# Antimony ion
# Tantalum
# Propane
# Benzo(k)fluoranthene
# Propionic acid
# Coal, brown
# NMVOC, non-methane volatile organic compounds
# Dimethylamine
# Bifenthrin
# Lead-210
# Occupation, unspecified
# Chrysene
# Thiabendazole
# Beryllium II
# Carbon tetrachloride
# Succinic acid
# Pesticides, unspecified
# Organic carbon
# Gadolinium
# Lenacil
# Fluorine
# Dicamba
# Triadimenol
# Mesotrione
# Aluminium III
# Transformation, from seabed, unspecified
# Chromium III
# Propargite
# Clodinafop-propargyl
# Lead-210
# Iodine
# Zinc II
# Benzene
# Tritium
# Propylene
# Bromine
# Ozone
# Chlorine
# Isophoronenitrile
# Silicon
# Fluquinconazole
# Fluazinam
# Acetaldehyde
# Methylamine
# Florasulam
# Praseodymium
# Toluene
# Sodium I
# Hazardous waste disposed
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Tribenuron
# Helium
# Isoproturon
# Cobalt-60
# Sodium I
# Occupation, traffic area, rail/road embankment
# 4-Methyl-2-pentanone
# Oils, non-fossil
# Titanium ion
# Nitrogen
# Hexachlorobenzene
# Metolachlor
# Sulcotrione
# Potassium I
# Manganese II
# Sulfuric acid
# Technetium-99m
# Particulate Matter, > 2.5 um and < 10um
# Bifenox
# Cumene
# Chromium III
# Transformation, from forest, intensive
# Monobutyltin (III)
# Quizalofop-ethyl
# Haloxyfop-P
# Thallium I
# Arsine
# Propiconazole
# Fluopyram
# Particulate Matter, > 2.5 um and < 10um
# Uranium
# Ametoctradin
# Clopyralid
# Flupyrsulfuron-methyl sodium
# Barium II
# Tembotrione
# Bromotrifluoromethane
# Chloridazon
# Suspended solids, unspecified
# Transformation, from urban, green area
# Phosphorus
# Potassium I
# Strontium II
# Particulate Matter, < 2.5 um
# Oxyfluorfen
# Polonium-210
# Magnesium
# Methane, fossil
# Thallium I
# Clethodim
# Clethodim
# Fluoranthene
# Nickel II
# Water, turbine use, unspecified natural origin
# Fluopicolide
# Prothioconazole
# Laterite
# Phosphorus
# Vanadium V
# Cymoxanil
# Tritium
# Haloxyfop-ethoxyethyl
# Uranium alpha
# Sodium hydroxide
# Pyraclostrobin
# Antimony-124
# Selenium IV
# Ammonium carbonate
# Ammonia
# Fluazinam
# Hydrocarbons, aromatic
# Sodium I
# Sodium I
# Ethylene oxide
# Silicon
# Dimethenamid-P
# Dolomite
# Particulate Matter, > 10 um
# Thallium I
# Calcium II
# Ioxynil
# Benzal chloride
# Chloride
# Iodine
# Thallium I
# Hydrogen sulfide
# Heat, waste
# Nitrogen oxides
# Propane
# Chloroform
# Occupation, pasture, man made, intensive
# Phenol
# Fluazinam
# Pymetrozine
# Paraquat
# Fenbuconazole
# Acetone
# Toluene
# Copper ion
# Hexachlorobenzene
# Cadmium II
# Butyric acid
# Metolachlor
# Diquat
# Antimony ion
# Indoxacarb
# Transformation, from traffic area, road network
# Metaldehyde
# Transformation, to cropland fallow (non-use)
# Cinidon-ethyl
# Bromomethane
# Oxyfluorfen
# Potassium-40
# Metamitron
# Iron ion
# Chlorsulfuron
# Acetamiprid
# Tribenuron
# Monoethanolamine
# Mepiquat chloride
# Sethoxydim
# Sulfur dichloride
# Cadmium II
# Metrafenone
# Ammonium carbonate
# Bentazone
# Acetone cyanohydrin
# Benzal chloride
# Ethoprop
# Hydrocarbons, aromatic
# Formic acid
# Hydrogen peroxide
# Pinoxaden
# Scandium
# Tungsten
# Benzovindiflupyr
# Fluazinam
# Ethofumesate
# Napropamide
# Pyrimethanil
# Lufenuron
# Radium-228
# Asulam
# Spinosad
# Volume occupied, final repository for low-active radioactive waste
# 2,4-DB
# Thorium-232
# Iodosulfuron-methyl-sodium
# Occupation, permanent crop, irrigated
# DOC, Dissolved Organic Carbon
# Fluroxypyr
# Butane
# Fish, pelagic, in ocean
# Phosphate
# Iodine-131
# DOC, Dissolved Organic Carbon
# Ethylene
# Propanal
# Fluroxypyr
# Spirotetramat
# Alpha-cypermethrin
# Prochloraz
# Nickel II
# Phenanthrene
# Thallium I
# Carbon dioxide, to soil or biomass stock
# Fenamidone
# Maleic hydrazide
# Ametoctradin
# Metazachlor
# Chlorotoluron
# Transformation, from permanent crop, non-irrigated
# Cyclohexane
# Aclonifen
# Fungicides, unspecified
# Carfentrazone-ethyl
# Dibutyltin
# Bromomethane
# Tungsten
# Chlorotoluron
# Thiram
# 2-Chloro-1,1,1,2-tetrafluoroethane
# Haloxyfop-ethoxyethyl
# Spinosad
# Thiodicarb
# Hydrocarbons, unspecified
# Chlorosulfonic acid
# Fipronil
# Hydrocarbons, aliphatic, alkanes, cyclic
# Iodosulfuron-methyl-sodium
# Herbicides, unspecified
# Chlorantraniliprole
# Isobutanol
# Acetaldehyde
# Hydrocarbons, aromatic
# Trifloxystrobin
# Thiacloprid
# Nickel II
# Transformation, from cropland fallow (non-use)
# Carbon dioxide, fossil
# 4-Methyl-2-pentanol
# Propoxycarbazone-sodium (prop)
# Cadmium II
# Uranium-238
# Isohexane
# Uranium-238
# Diflubenzuron
# Linuron
# Chrysotile
# Phenyltin
# Xylenes, unspecified
# Occupation, annual crop, irrigated, intensive
# Chloro-fluoromethane
# Tin ion
# Transformation, from dump site, inert material landfill
# Hydrochloric acid
# Saflufenacil
# Volume occupied, reservoir
# Insecticides, unspecified
# Transformation, to permanent crop, irrigated
# Triflusulfuron-methyl
# Desmedipham
# Zinc II
# Radioactive species, other beta emitters
# Azoxystrobin
# Methane, from soil or biomass stock
# Strontium
# Copper oxychloride
# Methacrylamide sulfate
# Styrene
# Sodium
# Thulium
# Ethyl benzene
# Gibberellic acid
# Hydrogen
# Chlormequat chloride
# Nitric acid
# Pyraclostrobin
# Polonium-210
# Chromium-51
# Arsenic ion
# Beta-cyfluthrin
# Bifenthrin
# Platinum
# Bromine
# Butane
# Silver-110
# Benthiavalicarb
# Sulfur dichloride
# Formaldehyde
# Water, salt, sole
# Metrafenone
# Thifensulfuron
# Pyriproxyfen
# MCPB
# Prosulfocarb
# Acrolein
# Solids, inorganic
# Dinitrogen monoxide
# t-Butyl methyl ether
# Fluoride
# Methyl acetate
# Cerium-144
# Thorium-228
# Chlorantraniliprole
# Flucarbazone sodium salt
# Chlorine
# Chloramine
# Carbaryl
# Prohexadione calcium
# Sodium I
# Copper
# Vinclozolin
# Lead II
# Water
# Cypermethrin
# Pencycuron
# Energy, gross calorific value, in biomass
# Amidosulfuron
# Phorate
# Manganese II
# Radium-226
# Chlorodifluoromethane
# Bromine
# Iodide
# Fluopicolide
# Etofenprox
# Ethyl benzene
# Iron ion
# Thallium I
# Dimethylamine
# Hypochlorite
# Transformation, from unspecified, natural (non-use)
# Tellurium
# Gas, natural
# Metconazole
# Permethrin
# Aluminium III
# 1,1,1-Trichloroethane
# Cadmium II
# Tembotrione
# Prothioconazole
# Barium II
# Ethane
# Tin
# Fluopyram
# Fluorine
# Carbon monoxide, fossil
# Sulfosate
# Pyraflufen-ethyl
# Calcium II
# VOC, volatile organic compounds
# Metsulfuron-methyl
# Butadiene
# o-Nitrotoluene
# Cyprodinil
# Thiram
# Silicon
# Mefenpyr-diethyl
# o-Xylene
# Methyl lactate
# Cycloxydim
# Chromium VI
# Ethyl benzene
# Cymoxanil
# Pydiflumetofen
# Potassium-40
# Metrafenone
# Dimethenamid-P
# Fludioxonil
# Borate
# Cypermethrin
# Quinoxyfen
# Pyroxasulfone
# Aluminium III
# Quizalofop-p-ethyl
# Chlorpyrifos
# Butyrolactone
# Hydrogen cyanide
# Flufenacet
# Toluene
# Iron
# Phosphorus
# Sodium I
# Antimony ion
# Rimsulfuron
# Quinclorac
# Kresoxim-methyl
# Prosulfocarb
# Trifluralin
# Occupation, annual crop, irrigated
# Pyraclostrobin
# Mandipropamid
# 1,1,1-Trichloroethane
# Carbon dioxide, fossil
# Bromine
# Isoxaflutole
# Ammonium
# Silicon
# Ethylene
# Dicamba
# Mesosulfuron-methyl (prop)
# Lead II
# Phosphate
# Silver I
# Flusilazole
# Thiencarbazone-methyl
# Carbonate
# Beryllium II
# Nitrate
# Methylchloride
# Sodium hydroxide
# Cobalt-60
# Xenon-135
# Thiacloprid
# Sulfuric acid
# Procymidone
# Arsenic ion
# Metaldehyde
# Zinc II
# Nitrite
# Thorium
# Thorium-234
# Metolachlor
# Bromoxynil
# Pendimethalin
# PAH, polycyclic aromatic hydrocarbons
# Foramsulfuron
# Potassium-40
# Lambda-cyhalothrin
# Phenmedipham
# Picoxystrobin
# Radon-222
# Niobium-95
# Metsulfuron-methyl
# Rhodium III
# Carbon monoxide, fossil
# Phosmet
# Caesium-137
# Trifloxystrobin
# Herbicides, unspecified
# Carbon dioxide, in air
# Indeno(1,2,3-cd)pyrene
# Diethanolamine
# Scandium
# Acetylene
# Difenoconazole
# Pyriproxyfen
# Novaluron
# Mefentrifluconazole
# Chlorantraniliprole
# Benzo(k)fluoranthene
# Energy, solar, converted
# Pymetrozine
# Chromium III
# Fipronil
# 1,1,1-Trichloroethane
# Nitrogen
# Oils, non-fossil
# Cypermethrin
# Occupation, seabed, drilling and mining
# Thallium I
# Methanol
# Butanol
# Quinmerac
# Cumene
# Cobalt II
# 2,4-D dimethylamine salt
# Acrolein
# Uranium alpha
# Propionic acid
# Transformation, from unknown
# Formic acid
# Transformation, to river, artificial
# Tebuthiuron
# PAH, polycyclic aromatic hydrocarbons
# Occupation, permanent crop, non-irrigated
# t-Butyl methyl ether
# Sulfuric acid
# Transformation, from wetland, inland (non-use)
# Radium-226
# Amidosulfuron
# Fluazifop-P-butyl
# Cumene
# Diquat
# Chloride
# Acetic acid
# Formic acid
# Manganese II
# Silicon
# Fluoride
# Transformation, to dump site, inert material landfill
# Nitrate
# Tepraloxydim
# Teflubenzuron
# Iodide
# Copper oxide
# Transformation, to forest, secondary (non-use)
# Lead II
# Ethanol
# Silver I
# Transformation, to industrial area
# Carbon monoxide, non-fossil
# Metalaxyl-M
# Metconazole
# 2,4-D
# Oils, non-fossil
# Novaluron
# Acidity, unspecified
# Gibberellic acid
# Tebupirimfos
# Dichlorprop
# Nitrogen
# Nitrogen fluoride
# Silver I
# Chrysene
# Strontium II
# Hydrocarbons, aliphatic, alkanes, cyclic
# Sulfur
# 1,1,1,2-Tetrafluoroethane
# Chlormequat chloride
# Molybdenum VI
# Benzo(a)pyrene
# Nitric acid
# Diuron
# Diflufenican
# Graphite
# Metalaxil
# Magnesium
# Ammonium
# Sulfite
# Amisulbrom
# Dimethenamid-P
# Indoxacarb
# Silver I
# Flumetsulam
# Lenacil
# Prohexadione calcium
# Clay, bentonite
# Pymetrozine
# Transformation, to seabed, unspecified
# Acetochlor
# Benthiavalicarb
# Buprofezin
# Flufenacet
# Deltamethrin
# Tebuthiuron
# Acrylate
# Cycloxydim
# Methylamine
# Paclobutrazol
# Thiabendazole
# Iodosulfuron
# Yttrium
# Sulfur
# Transformation, to unspecified
# Transformation, to annual crop, non-irrigated, intensive
# Tebuconazole
# Krypton-85
# Acenaphthene
# Benzo(k)fluoranthene
# Metribuzin
# Nitrogen
# BOD5, Biological Oxygen Demand
# Iron-59
# Chlorantraniliprole
# Iodine
# Silicon
# Carbaryl
# Heat, waste
# Ethylene dichloride
# Picoxystrobin
# Ethylamine
# Metconazole
# Imazethapyr
# Fungicides, unspecified
# Glufosinate ammonium
# Silver I
# Methyl ethyl ketone
# Spirotetramat
# Chlorimuron-ethyl
# Mesotrione
# Silver I
# Methyl acrylate
# Benthiavalicarb
# Hydrogen fluoride
# Mercury II
# Antimony-122
# Chromium III
# Ethanol
# Radium-226
# Uranium-238
# Nitrogen oxides
# Diflufenzopyr-sodium
# Transformation, from pasture, man made, intensive
# Beryllium II
# Beta-cyfluthrin
# Cobalt II
# Picoxystrobin
# Chlorpyrifos
# Cadmium II
# Paclobutrazol
# Fenoxaprop-P
# Tin ion
# Hydrogen sulfide
# NMVOC, non-methane volatile organic compounds
# Hydrocarbons, aliphatic, unsaturated
# Chloride
# Manganese-54
# Fluazifop-P-butyl
# Chromium III
# Bitertanol
# Metribuzin
# Beryllium II
# Occupation, traffic area, rail network
# Transformation, to unspecified, natural (non-use)
# Chlorimuron-ethyl
# Vanadium V
# Piperonyl butoxide
# 2,4-D
# Caesium I
# Azadirachtin
# Zoxamide
# Thiencarbazone-methyl
# Phosphate
# Pentachlorophenol
# Pyraflufen-ethyl
# Scandium
# Acenaphthene
# Diquat dibromide
# Mineral oil
# Imazamox
# Uranium
# Solids, inorganic
# Linuron
# Hafnium
# Cerium-141
# 2,4-Dichlorophenol
# Rubidium
# Occupation, urban, discontinuously built
# Diethyl ether
# Isopropanol
# Ioxynil
# Tributyltin compounds
# Hydrocarbons, aromatic
# Thallium I
# Formaldehyde
# Occupation, river, artificial
# 2,4-D ester
# Ethyl acetate
# Picloram
# Methoxyfenozide
# Thiabendazole
# Organic carbon
# Occupation, annual crop, non-irrigated
# Aluminium hydroxide
# Sulfur hexafluoride
# VOC, volatile organic compounds
# Diethylamine
# Carbonate
# Bensulfuron methyl ester
# Peat
# Selenium IV
# Triethylene glycol
# Dimethoate
# Carbon dioxide, non-fossil
# Mecoprop
# Pyrimethanil
# Holmium
# Pentachlorophenol
# Sodium I
# Silver I
# Napropamide
# Zineb
# Triclopyr
# Fluopicolide
# Nitrite
# Nitrate
# Prochloraz
# Xenon-135m
# Rubidium
# Fentin hydroxide
# Cupric hydroxide
# Boron
# Occupation, annual crop, non-irrigated, intensive
# Xylenes, unspecified
# Metalaxyl-M
# Molybdenum VI
# 2,2,4-Trimethylpentane
# Ketene
# Potassium I
# Manganese-54
# Nickel II
# Bentazone
# Simazine
# Chlorpyrifos methyl
# Carbon, organic, increase in soil or biomass stock
# PAH, polycyclic aromatic hydrocarbons
# Oils, unspecified
# Transformation, to urban, discontinuously built
# VOC, volatile organic compounds
# Dimethyl ether
# Thiamethoxam
# Ethyl benzene
# Molybdenum-99
# Monoethanolamine
# o-Xylene
# Alpha-cypermethrin
# Thiram
# Europium
# Prothioconazole
# Heat, waste
# Chlorodifluoromethane
# Chromium III
# VOC, volatile organic compounds
# Laminarin
# Fenoxaprop
# Metamitron
# Sodium-24
# Styrene
# Metaldehyde
# Transformation, from dump site, sanitary landfill
# Aluminium III
# Iron ion
# Transformation, from river, natural (non-use)
# Zinc II
# Boscalid
# Glyphosate
# Phosphorus pentachloride
# Diflufenican
# Benz(a)anthracene
# Actinides, radioactive, unspecified
# Titanium ion
# Benzaldehyde
# Propanol
# Clopyralid
# Phthalic anhydride
# 4-Methyl-2-pentanone
# Phosphorus
# Triflumuron
# Monocrotophos
# Nickel
# Lead II
# DOC, Dissolved Organic Carbon
# 1,1,2-Trichloro-1,2,2-trifluoroethane
# Hexamethylene diisocyanate
# 2,4-D
# Paclobutrazol
# Fluoxastrobin
# Methomyl
# Fenamidone
# Quizalofop-P
# Carfentrazone-ethyl
# COD, Chemical Oxygen Demand
# Pirimicarb
# Carbon monoxide, fossil
# 1,4-Butanediol
# Spiromesifen
# Isopropylamine
# Thorium-234
# Spodumene
# Fluorine
# Thallium I
# Hydrocarbons, chlorinated
# Abamectin
# Nitrate
# Hypochlorite
# Chlorpyrifos methyl
# Aclonifen
# Benzene
# Toluene
# Propionic acid
# Suspended solids, unspecified
# Pesticides, unspecified
# Octaethylene glycol monododecyl ether
# Antimony-124
# Hydrocarbons, chlorinated
# Ethephon
# Sodium chlorate
# Occupation, dump site
# Chlorimuron-ethyl
# PAH, polycyclic aromatic hydrocarbons
# Dipropyl amine
# Nitrate
# Lead
# Transformation, to seabed, drilling and mining
# Metolachlor
# Sulfosulfuron
# Phosphorus
# Radium-224
# Molybdenum VI
# Quizalofop-P
# Nitrate
# Xenon
# Mepiquat chloride
# Molybdenum VI
# Benz(a)anthracene
# Ethyl acetate
# Xylenes, unspecified
# Thiophanate-methyl
# 1-Pentanol
# Arsenic ion
# Bromoxynil
# Styrene
# Abamectin
# Triflusulfuron-methyl
# Scandium
# Boscalid
# Bisphenol A
# Sodium chlorate
# Hydrocarbons, aliphatic, alkanes, cyclic
# Methanol
# Aldrin
# Tribenuron-methyl
# 2-Aminopropanol
# Deltamethrin
# Radium-228
# Selenium IV
# Ammonia
# Magnesium
# Indoxacarb
# Transformation, from annual crop
# Silicon
# Molybdenum
# Vanadium V
# Iodine-129
# Butanol
# Lithium I
# Prosulfuron
# 2,4-Dichlorophenol
# Xylenes, unspecified
# COD, Chemical Oxygen Demand
# Nicosulfuron
# Pyroxsulam
# Magnesium
# Emamectin benzoate
# Radon-220
# Chlorodifluoromethane
# Organic carbon
# Pyraflufen-ethyl
# Butyl acrylate
# Occupation, shrub land, sclerophyllous
# Lithium
# Vinyl chloride
# Metsulfuron-methyl
# Sulfuric acid
# Lufenuron
# Isoxaflutole
# Glufosinate
# Propyl amine
# Triallate
# Manganese II
# Uranium-238
# Carbon-14
# Phenyl isocyanate
# Carbonate
# Trimethylchlorosilane
# Magnesite
# Transformation, to permanent crop, irrigated, intensive
# Fluosilicic acid
# Zirconium-95
# Clomazone
# Nitric acid
# Manganese
# Clomazone
# Hydrocarbons, unspecified
# Acetic acid
# Tetrachloroethylene
# Formaldehyde
# Quizalofop-p-ethyl
# Iodosulfuron-methyl-sodium
# Phosphorus trichloride
# Pyrene
# Transformation, from pasture, man made, extensive
# Pyriproxyfen
# Tepraloxydim
# Acetone
# Triflusulfuron-methyl
# Carbendazim
# Bromine
# Lithium hexafluorophosphate
# Tefluthrin
# Propaquizafop
# Beryllium II
# Strontium-89
# Aluminium III
# 2-Chlorophenol
# Cyproconazole
# Hydrochloric acid
# Sulfur trioxide
# Transformation, from annual crop, non-irrigated, intensive
# Spinosad
# Prochloraz
# TOC, Total Organic Carbon
# Methomyl
# S-Metolachlor
# Phenoxy compounds
# Transformation, from dump site
# Acetic anhydride
# Manganese
# Xylenes, unspecified
# Fenamidone
# Sulfate
# Occupation, mineral extraction site
# Heat, waste
# Ytterbium
# Imidacloprid
# Thallium I
# Lambda-cyhalothrin
# Chlorate
# TOC, Total Organic Carbon
# DOC, Dissolved Organic Carbon
# Flumioxazin
# Pyroxsulam
# Naphthalene
# Bixafen
# Mepiquat chloride
# Acetone
# Urea
# Strontium-90
# Laminarin
# Feldspar
# Mesotrione
# Fenpropimorph
# Methylamine
# Krypton-88
# Antimony ion
# Chlorosulfonic acid
# Metamitron
# Terbium
# Tungsten
# Phosgene
# Fenpropidin
# Xenon-133
# Butene
# Epoxiconazole
# Lithium I
# Borate
# Clethodim
# Abamectin
# Occupation, unspecified, natural (non-use)
# Emamectin benzoate
# Dimethomorph
# Nickel II
# Ethephon
# Sulcotrione
# Water
# Propiconazole
# Lithium I
# Water
# Thiodicarb
# Cymoxanil
# Vinyl chloride
# Dibenz(a,h)anthracene
# Propamocarb
# Lactofen
# Diquat dibromide
# Nitrogen
# Teflubenzuron
# Isoproturon
# Tebuthiuron
# Arsenic ion
# Talc
# Barite
# Dichlorvos
# Tritosulfuron
# Vanadium V
# Tin ion
# Flurtamone
# AOX, Adsorbable Organic Halides
# Copper
# Methyl formate
# Cobalt II
# Cadmium
# Terbuthylazin
# Pyraclostrobin
# Carbon dioxide, from soil or biomass stock
# MCPB
# Decanoic acid
# Phenoxy compounds
# Cobalt II
# Xenon-131m
# Iron ion
# Sulfate
# Cobalt II
# Bifenthrin
# Methyl formate
# Occupation, inland waterbody, unspecified
# Kresoxim-methyl
# Calcium II
# Dodecanol
# Mesosulfuron
# Butanol
# NMVOC, non-methane volatile organic compounds
# Methyl ethyl ketone
# Rimsulfuron
# Palladium II
# Imidacloprid
# Hexane
# Tepraloxydim
# Simazine
# Fluorine
# Propane
# Tin ion
# Cloquintocet-mexyl
# Pentane
# Formic acid
# Tetrachloroethylene
# Silicon
# Trifloxystrobin
# Acetaldehyde
# Magnesium
# Ethylene carbonate
# Plutonium-238
# Occupation, cropland fallow (non-use)
# Oils, unspecified
# NMVOC, non-methane volatile organic compounds
# Amisulbrom
# Ethofumesate
# Barium II
# Ethylamine
# Glufosinate
# Acetylene
# Pyroxsulam
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Dimethyl malonate
# Thorium-228
# Pendimethalin
# Toluene
# Chromium III
# Diquat dibromide
# Strontium II
# Amidosulfuron
# Pentane
# Chlormequat chloride
# Sodium formate
# Transformation, from annual crop, non-irrigated, extensive
# Transformation, to inland waterbody, unspecified
# Actinides, radioactive, unspecified
# Boron
# Polychlorinated biphenyls
# Benzo(ghi)perylene
# Ethephon
# Benzaldehyde
# Hydrocarbons, aliphatic, alkanes, unspecified
# Cyprodinil
# 2,4-DB
# Sulfentrazone
# Trifluoromethane
# Hydrogen
# Flufenacet
# Potassium I
# Calcium II
# Tetrafluoromethane
# Bromochlorodifluoromethane
# Fluoride
# Caesium-134
# Sulfur
# Potassium I
# Bromoxynil
# Samarium
# Fluazifop-P-butyl
# Sulfur
# Pentachlorophenol
# Ozone
# Dichloromethane
# Tribenuron
# Lanthanum-140
# Phenoxy compounds
# Copper ion
# Bromine
# Terbufos
# Cadmium II
# Chlorides, unspecified
# Ethyl benzene
# Gypsum
# Volume occupied, underground deposit
# Bicyclopyrone
# Isoxaflutole
# Mecoprop-P
# Magnesium
# Diethyl ether
# Benzo(a)pyrene
# Naphthalene
# Chlorantraniliprole
# Nickel II
# Phosphoric acid
# Hexane
# 2-Methyl-2-butene
# Water, in air
# Fluazinam
# Difenoconazole
# Selenium IV
# Phenmedipham
# Occupation, grassland, natural (non-use)
# Pendimethalin
# Calcium II
# Ethyl acetate
# m-Xylene
# Ethephon
# Glyphosate
# Flupyrsulfuron-methyl sodium
# Tin ion
# Monopotassium phosphite
# Molybdenum VI
# Alpha-cypermethrin
# Mercury II
# Methiocarb
# Phenol
# PAH, polycyclic aromatic hydrocarbons
# Carbendazim
# Oxygen
# Mesosulfuron
# Pymetrozine
# Tin ion
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Acetone cyanohydrin
# Thifensulfuron
# Flufenacet
# Sodium I
# Hydrocarbons, unspecified
# Methyl acrylate
# Carbon disulfide
# Hydrochloric acid
# Scandium
# Tebuconazole
# Polychlorinated biphenyls
# Antimony ion
# Myclobutanil
# Thiodicarb
# Azoxystrobin
# Pronamide
# Fludioxonil
# Pinoxaden
# Transformation, from permanent crop, irrigated
# Cyazofamid
# Sulfentrazone
# Phosphorus trichloride
# Boron
# Sodium sulfate
# Magnesium
# Propane
# Molybdenum VI
# Bifenazate
# Barium II
# Heptane
# Lambda-cyhalothrin
# 2,4-D
# Dimethomorph
# Lanthanum-140
# Furan
# Aclonifen
# Sulfur
# Pentachlorophenol
# Thiencarbazone-methyl
# Suspended solids, unspecified
# Propiconazole
# Vanadium V
# Anthraquinone
# Acenaphthene
# Imazapyr
# Copper ion
# Sodium dichromate
# Water
# Selenium IV
# Barium II
# Cloransulam-methyl
# Pencycuron
# Tin ion
# Antimony ion
# Iron ion
# Acenaphthylene
# Transformation, from permanent crop, irrigated, intensive
# Haloxyfop-P
# Chlorinated solvents, unspecified
# Formamide
# Scandium
# Sodium tetrahydridoborate
# Chlorine
# Clomazone
# MCPB
# Zinc II
# Strontium II
# Lead-210
# Flonicamid
# Chlormequat chloride
# Erbium
# Occupation, pasture, man made
# Fluxapyroxad
# Propionic acid
# Quinmerac
# Azoxystrobin
# Flupyrsulfuron-methyl sodium
# Thiophanate-methyl
# Strontium II
# Metamitron
# Vanadium V
# Acetic acid
# Cyanoacetic acid
# Sylvite
# Nickel II
# Thiacloprid
# Ammonium
# Vanadium V
# Metalaxyl-M
# Manganese II
# Boron
# Benzovindiflupyr
# Alkylbenzene (c10-c15)
# Cadmium II
# Heptane
# Nitrogen
# Pyrene
# Maleic hydrazide
# Furan
# 1,4-Butanediol
# Caesium I
# Allyl chloride
# Bromuconazole
# Energy, kinetic (in wind), converted
# Water, unspecified natural origin
# Benzo(b)fluoranthene
# Thallium I
# Mesosulfuron
# 2,4-DB
# Lithium I
# Hydrochloric acid
# Mancozeb
# Teflubenzuron
# COD, Chemical Oxygen Demand
# Phenanthrene
# Silicon tetrafluoride
# Zinc II
# Orbencarb
# Nitrobenzene
# Azoxystrobin
# Copper oxide
# Aluminium III
# Fish, demersal, in ocean
# Sulfuric acid
# Transformation, from annual crop, non-irrigated
# Protactinium-234
# MCPA
# Silicon
# Propaquizafop
# Silver I
# Clothianidin
# Mercury II
# Pentachlorobenzene
# Anthracene
# Fenpropidin
# Sodium methoxide
# Kaolin
# Metribuzin
# Sulfur dioxide
# Teflubenzuron
# Clay, unspecified
# Hydrogen fluoride
# Sulfate
# Arsenic ion
# Carbon dioxide, to soil or biomass stock
# Carbon, organic, decrease in soil or biomass stock
# Mancozeb
# Lutetium
# Chromium VI
# Chlorotoluron
# Zirconium
# Beta-cyfluthrin
# Sulfur
# Zoxamide
# Caesium-137
# Iodine-133
# Titanium ion
# Fluosilicic acid
# Acetonitrile
# Bentazone
# Styrene
# Krypton-85m
# Hydrochloric acid
# Transformation, to dump site, sanitary landfill
# Polychlorinated biphenyls
# Chlorpyrifos
# Methane, non-fossil
# Bicarbonate
# Metazachlor
# Benzene
# Bromine
# Bifenthrin
# Hydroxide
# Aluminium III
# MCPA
# Fluazinam
# Isopropanol
# Silver-110
# Radioactive species, Nuclides, unspecified
# Alkylbenzene (c10-c15)
# Tungsten
# Cyproconazole
# Isophorondiamine
# Dimethachlor
# Glufosinate
# Barium II
# Dicamba
# Silicon
# 2-Methyl-2-butanol
# Occupation, lake, artificial
# Zinc II
# Heptane
# Molybdenum VI
# Particulate Matter, < 2.5 um
# Lactic acid
# Titanium ion
# Hydrocarbons, unspecified
# Krypton
# Calcium II
# Carbetamide
# Cobalt II
# Sulfur
# Pyridate
# Chlorantraniliprole
# 1,1,1-Trichloroethane
# Cyproconazole
# Transformation, to permanent crop
# Nitrate
# Water, unspecified natural origin
# Metolachlor
# Phenmedipham
# Thiocyanate
# Lambda-cyhalothrin
# Carbaryl
# Ammonium
# Methomyl
# Chlormequat
# Transformation, to shrub land, sclerophyllous
# Cadmium II
# Arsenic ion
# Atrazine
# Phosphorus oxychloride
# Linuron
# Pendimethalin
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Methoxyfenozide
# Bentazone
# Carfentrazone-ethyl
# Benz(a)anthracene
# Lead II
# Potassium I
# Particulate Matter, > 10 um
# Sulfate
# Iodide
# Dissolved solids
# Fluoride
# Molinate
# Cypermethrin
# Phenanthrene
# Dichlorprop
# Boron
# Xenon-133m
# Propiconazole
# Chlorine
# Hexamethylenediamine
# Gangue
# Carbon
# Thorium-230
# Phosphine
# Occupation, pasture, man made, extensive
# Metalaxyl-M
# Perlite
# Iodosulfuron-methyl-sodium
# Iron ion
# Transformation, from grassland, natural (non-use)
# Heat, waste
# Calcium II
# Pentachlorobenzene
# Kaolin
# Transformation, from annual crop, irrigated
# Silicon
# Fluquinconazole
# Pencycuron
# Organic carbon, placed in landfill
# Butene
# Fluroxypyr
# Carbon-14
# 2,4-di-tert-butylphenol
# Carbon
# Manganese II
# Pyraclostrobin
# Benalaxyl-M
# Amisulbrom
# Mercury II
# Sulfur dioxide
# Terbuthylazin
# Acephate
# Triflumuron
# Lead II
# Acetic acid
# Triflumuron
# Zinc-65
# Ruthenium-103
# Nitrite
# Fluxapyroxad
# Pencycuron
# 2-Methyl-2-butene
# Bromine
# Oxamyl
# Thiram
# Triasulfuron
# Oxygen
# 2,4-D
# Cyproconazole
# 4-Methyl-2-pentanone
# Abamectin
# Ethylene diamine
# Kaolinite
# Hydrocarbons, aliphatic, alkanes, unspecified
# Lead II
# Transformation, to grassland, natural, for livestock grazing
# Tributyltin compounds
# Ammonia
# Dicamba
# Cycloxydim
# Iprodione
# Tebuconazole
# Uranium
# Monochloroethane
# Methiocarb
# Simazine
# Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin
# Chromium
# Aluminium III
# Methomyl
# Occupation, permanent crop
# Tetrachloroethylene
# Hexane
# Cymoxanil
# Metconazole
# Imazamox
# Benalaxyl-M
# Diatomite
# o-Xylene
# Zinc II
# PAH, polycyclic aromatic hydrocarbons
# Thifensulfuron
# Fenoxaprop-P
# Boric acid
# Ethyl acetate
# Polonium-210
# Ruthenium
# Nitrogen, organic bound
# Bentazone
# Tetrafluoromethane
# Pethoxamid
# Pesticides, unspecified
# Flurochloridone
# Hydrocarbons, chlorinated
# Terbuthylazin
# Silthiofam
# Spiroxamine
# Copper oxychloride
# 2,4-D ester
# Phosphorus
# Hydrogen
# Trichlorofluoromethane
# t-Butyl amine
# Dibenz(a,h)anthracene
# Fomesafen
# Strontium-90
# Gibberellic acid
# Manganese II
# Chloroform
# Methane, non-fossil
# Hydrocarbons, aliphatic, unsaturated
# Nitrogen oxides
# Boron trifluoride
# Thiophanate-methyl
# Neodymium
# Antimony ion
# Beryllium
# Barium II
# Prohexadione calcium
# Glufosinate
# Thionyl chloride
# Cobalt II
# Trinexapac-ethyl
# Ethylene dichloride
# MCPA
# Chloroacetic acid
# Emamectin benzoate
# Cu-HDO
# Arsenic
# Cyazofamid
# Sulfur
# Arsenic ion
# Chlorothalonil
# Ferrocyanide
# Diflufenican
# Lead II
# Tungsten
# Carbendazim
# Boron
# Etofenprox
# Alpha-cypermethrin
# Trichloroethylene
# Fenoxaprop-P
# Methanesulfonic acid
# S-Metolachlor
# NMVOC, non-methane volatile organic compounds
# Azoxystrobin
# Isoproturon
# Teflubenzuron
# Trioctyltin
# Sulfentrazone
# Trifloxystrobin
# Boron
# Beryllium II
# Radon-220
# Propiconazole
# Trimethylamine
# Particulate Matter, > 10 um
# Isoxaflutole
# Iron ion
# Thiabendazole
# Epoxiconazole
# Water
# Imazethapyr
# Suspended solids, unspecified
# Benalaxyl-M
# Gas, mine, off-gas, process, coal mining
# Cinidon-ethyl
# Alachlor
# Acetamide
# Spiroxamine
# Diflubenzuron
# Carnallite
# Selenium IV
# Dimethyl carbonate
# Aniline
# Benzovindiflupyr
# Ethylene oxide
# Radon-222
# Thorium-228
# Kresoxim-methyl
# Cobalt II
# Flupyrsulfuron-methyl sodium
# Hexafluoroethane
# Hydrocarbons, chlorinated
# Lead II
# Particulate Matter, > 10 um
# Nickel II
# Carbon dioxide, fossil
# Epoxiconazole
# Trichloroethylene
# Fenpiclonil
# Chlorosulfonic acid
# Fluoxastrobin
# 1,1-Difluoroethane
# Benzo(a)pyrene
# Fenpropidin
# Bixafen
# Benzo(b)fluoranthene
# Atrazine
# Chloroacetyl chloride
# Oils, non-fossil
# Transformation, to permanent crop, non-irrigated
# Pinoxaden
# Acephate
# Linuron
# Phosphate
# Halosulfuron-methyl
# Acetaldehyde
# Ethylene oxide
# Nicosulfuron
# Titanium
# Iron ion
# Indeno(1,2,3-cd)pyrene
# Cobalt II
# Molybdenum VI
# Radioactive species, other beta emitters
# Cadmium II
# Thiodicarb
# Chloramine
# Transformation, from forest, primary (non-use)
# Lithium I
# Coal, hard
# Boron
# Cinidon-ethyl
# Metribuzin
# Hydrogen sulfide
# Beryllium II
# Occupation, industrial area
# Ammonium bisulfate
# 1,4-Diisopropylbenzene
# Dithianon
# Tungsten
# Endothall
# Zirconium
# Arsenic ion
# Protactinium-234
# Kresoxim-methyl
# Sulfide
# Sulfate
# Thorium-228
# Fludioxonil
# Copper ion
# Tebuconazole
# Carbon tetrachloride
# Sulfate
# Thiram
# Flurochloridone
# Methane, non-fossil
# Selenium IV
# Dichlorprop
# Cupric hydroxide
# Bixafen
# Methiocarb
# Transformation, to forest, extensive
# Ethane
# Laminarin
# Monoethanolamine
# Tin ion
# Heat, waste
# Mercury II
# Carbaryl
# Carfentrazone-ethyl
# Nitrogen
# Thiamethoxam
# Scandium
# o-Dichlorobenzene
# Thorium-228
# Difenoconazole
# Isophorondiisocyanate
# Carbon monoxide, from soil or biomass stock
# Iodine-133
# Propanol
# Iron ion
# Trifluoromethane
# Platinum
# Maleic hydrazide
# Phosphoric acid
# Fungicides, unspecified
# Quizalofop-p-ethyl
# Diflufenican
# Methyl acetate
# Monochloroethane
# Propylene
# Difluoromethane
# Phosphorus
# Lead-210
# Difenoconazole
# Propanol
# Diquat dibromide
# Lead II
# Toluene
# Triflumuron
# Pesticides, unspecified
# Argon
# Particulate Matter, > 2.5 um and < 10um
# Trifluralin
# Transformation, from grassland, natural, for livestock grazing
# Pyriproxyfen
# Ethalfluralin
# Chromium III
# Chloride
# Cerium-141
# Mecoprop-P
# Novaluron
# Mercury II
# Gallium
# Dodecanol
# Tellurium-123m
# Dimethenamid-P
# Acetic acid
# Carbon
# Dimethomorph
# Particulate Matter, < 2.5 um
# Occupation, permanent crop, non-irrigated, intensive
# Ametoctradin
# Zinc II
# Copper oxychloride
# PAH, polycyclic aromatic hydrocarbons
# Benzovindiflupyr
# Hydrogen
# Cycloxydim
# Zinc-65
# Sulfur
# Hydrocarbons, unspecified
# Lithium carbonate
# Pentachlorophenol
# Pyroxsulam
# Transformation, from dump site, slag compartment
# Carbon dioxide, non-fossil
# Tetrachloroethylene
# Dichloroethylene
# Benzyl alcohol
# Thifensulfuron
# Metazachlor
# Chlorotoluron
# Clodinafop-propargyl
# Sulfosulfuron
# o-Chlorotoluene
# Transformation, from forest, unspecified
# Fluopicolide
# Transformation, to traffic area, rail network
# Particulate Matter, > 2.5 um and < 10um
# Copper ion
# Pentane
# Phenol
# Dicamba
# Nickel II
# Pentafluoroethane
# Carboxylic acids, unspecified
# Chlorine
# Copper ion
# Nicosulfuron
# Pethoxamid
# Krypton-87
# Zinc
# Cadmium II
# m-Xylene
# Energy, geothermal, converted
# Imidacloprid
# Strontium II
# Fenpropidin
# Chlorpyrifos
# Formamide
# Bromine
# Zeta-cypermethrin
# Fluxapyroxad
# Scandium
# Bifenthrin
# Bifenthrin
# Titanium ion
# Tellurium
# Silver I
# Deltamethrin
# Oil, crude
# Fludioxonil
# Cadmium II
# Manganese II
# Transformation, to permanent crop, non-irrigated, intensive
# Topramezone
# Ethanol
# Wood, hard, standing
# Transformation, to seabed, infrastructure
# Metazachlor
# Dichromate
# Sodium I
# Barium II
# Transformation, to forest, intensive
# Phosphorus
# Methoxyfenozide
# Desmedipham
# Herbicides, unspecified
# 1,1,1,2-Tetrafluoroethane
# Ethofumesate
# Florasulam
# Butadiene
# Sulfosulfuron
# Iodide
# Ethylene dichloride
# Thiamethoxam
# Aldehydes, unspecified
# m-Xylene
# Occupation, annual crop
# Strontium II
# Calcium II
# Niobium
# Thorium
# Fluorine
# Trinexapac-ethyl
# Carbon monoxide, non-fossil
# Fluorspar
# Chloridazon
# Chromium VI
# Methylchloride
# Benzo(b)fluoranthene
# Sulfur dioxide
# Dimethenamide
# Clethodim
# Bromide
# Benzene
# Trifloxystrobin
# Quizalofop-p-ethyl
# Trimethylamine
# Benzo(a)pyrene
# Phosphorus pentafluoride
# Tembotrione
# Cyanide
# Carbonyl sulfide
# Beta-cyfluthrin
# Chlorpyrifos methyl
# Imidacloprid
# Clopyralid
# Bromate
# Potassium I
# Silicon dioxide
# Aluminium
# Fungicides, unspecified
# Hydrogen peroxide
# Chloride
# Water
# Zinc II
# Copper oxide
# Isoprene
# Acetamiprid
# Copper ion
# Picoxystrobin
# Fluopyram
# S-Metolachlor
# Boscalid
# o-Xylene
# Methyl formate
# Benzene
# Endosulfan
# Aldicarb
# Tungsten
# Occupation, forest, extensive
# Metalaxyl-M
# Maleic anhydride
# 2,4-D ester
# Nickel II
# Simazine
# Oxygen
# Propamocarb
# Nitrate
# Pyriproxyfen
# Maleic hydrazide
# Propylene
# Azoxystrobin
# Carboxylic acids, unspecified
# Fluoranthene
# Methane, fossil
# Dinitrogen monoxide
# Thiamethoxam
# Haloxyfop-P
# Fluoride
# Zinc II
# Diafenthiuron
# Cyazofamid
# Lauric acid
# Plutonium-alpha
# Sulfur dioxide
# Vanadium V
# Copper oxychloride
# Sulfosulfuron
# Potassium-40
# Sulfite
# BOD5, Biological Oxygen Demand
# Ethanol
# Prochloraz
# Tetramethyl ammonium hydroxide
# Tellurium-132
# Mancozeb
# Sodium hydroxide
# Transformation, from permanent crop
# Mandipropamid
# Pronamide
# tau-Fluvalinate
# Polonium-210
# Hexachlorobenzene
# Trifloxystrobin
# Discarded fish, demersal, to ocean
# Anthracene
# Emamectin benzoate
# Cloquintocet-mexyl
# Flumioxazin
# Fluxapyroxad
# Cadmium II
# Flutolanil
# Mefenpyr
# Fenpropimorph
# Methyl acetate
# Mercury II
# Granite
# Acetone
# Alpha-cypermethrin
# Methiocarb
# Borax
# Copper ion
# Transformation, to arable land, unspecified use
# Germanium
# Fluxapyroxad
# Pethoxamid
# Mesosulfuron
# Imidacloprid
# Transformation, from forest, extensive
# Water, lake
# Phenol
# Benthiavalicarb
# Fenoxaprop-P
# Difenoconazole
# Fenpropimorph
# 1-Pentene
# Silicon dioxide
# Kaolin
# Transformation, to traffic area, road network
# Fluosilicic acid
# Boron
# Magnesium
# AOX, Adsorbable Organic Halides
# Isobutanol
# 1,1-Difluoroethane
# Transformation, from unspecified
# Metsulfuron-methyl
# Cyanide
# Propaquizafop
# Copper
# Silver
# Fluxapyroxad
# Calcium
# Thiacloprid
# Chlorpyrifos
# Cyclohexane
# Copper ion
# Boron
# Water, well, in ground
# Flumioxazin
# Diflubenzuron
# Water, river
# Argon
# Metaldehyde
# Chlorine
# Methyl acrylate
# Hypochlorite
# Diquat
# Antimony-125
# Kieserite
# Chromium-51
# Imazamox
# Transformation, from shrub land, sclerophyllous
# Diuron
# Radon-222
# Rimsulfuron
# Methylamine
# Acetamiprid
# Lauric acid
# Fipronil
# Krypton-89
# Particulate Matter, < 2.5 um
# Flumioxazin
# Phosphorus
# Isocyanic acid
# Phenol
# Lead-210
# Maneb
# Aclonifen
# Quizalofop-p-ethyl
# Flumioxazin
# Pronamide
# Discarded fish, pelagic, to ocean
# Methoxyfenozide
# Alkylbenzene (c10-c15)
# Methanol
# Particulate Matter, < 2.5 um
# Mancozeb
# Selenium IV
# Transformation, from mineral extraction site
# Silver I
# Chrysene
# Ethylene dichloride
# Carbon dioxide, fossil
# Spiroxamine
# Carbofuran
# Hexafluoroethane
# Quizalofop-P
# Pirimicarb
# Nicosulfuron
# Sulfur hexafluoride
# Radium-228
# Trinexapac-ethyl
# Ethanol
# Potassium-40
# Diflubenzuron
# Antimony
# Potassium I
# Carbon dioxide, non-fossil
# Manganese II
# Nickel II
# Tebuconazole
# Cinidon-ethyl
# Fenpropimorph
# Epoxiconazole
# Transformation, to wetland, inland (non-use)
# Chloride
# Thorium-232
# Prosulfocarb
# Lead II
# Carbon dioxide, non-fossil, resource correction
# 1,1,1,2-Tetrafluoroethane
# Vanadium V
# Thifensulfuron-methyl
# Transformation, to forest, unspecified
# Nickel II
# Heptane
# Mercury II
# Lead II
# Ulexite
# Indoxacarb
# Cyanide
# Fluoride
# Occupation, annual crop, non-irrigated, extensive
# Ethylene diamine
# Triflusulfuron-methyl
# Pirimicarb
# Carbon monoxide, non-fossil
# Chromium III
# Transformation, to lake, artificial
# Nitrogen oxides
# Cadmium II
# Transformation, to urban, continuously built
# Dichloromethane
# Water, salt, ocean
# Picloram
# Quizalofop-P
# Selenium IV
# Hydrocarbons, unspecified
# Napropamide
# Isoproturon
# Cyhalothrin
# Metsulfuron-methyl
# Pyraclostrobin
# Heat, waste
# Mercury II
# Transformation, from annual crop, irrigated, intensive
# Zoxamide
# Amisulbrom
# Etofenprox
# Cyproconazole
# Radon-222
# Hydrogen fluoride
# Phosphate
# Tin ion
# Noble gases, radioactive, unspecified
# Hydrocarbons, aliphatic, unsaturated
# Transformation, to annual crop, non-irrigated
# Fluopyram
# Glyphosate
# Radioactive species, other beta emitters
# Thorium
# Carbon monoxide, fossil
# Primisulfuron
# Titanium ion
# Acetyl chloride
# Copper ion
# Dodecanol
# 1,1,2-Trichloro-1,2,2-trifluoroethane
# Cupric hydroxide
# Fipronil
# Cyprodinil
# Zirconium-95
# 2-Aminopropanol
# Molybdenum VI
# Flusilazole
# Iodide
# Picloram
# Sulfentrazone
# Thiencarbazone-methyl
# Transformation, to dump site, slag compartment
# Phosphorus trichloride
# Mercury II
# Uranium-235
# Methomyl
# Cobalt
# Methylchloride
# TOC, Total Organic Carbon
# Dichlorofluoromethane
# Formaldehyde
# Chlorimuron-ethyl
# Acifluorfen
# Boron
# Thiabendazole
# Nitrite
# Chromium VI
# Thiodicarb
# Boscalid
# Glyphosate
# Hydrocarbons, aliphatic, alkanes, unspecified
# Caesium-136
# t-Butyl methyl ether
# Flumiclorac-pentyl
# Propylene
# Chromium III
# Propanal
# Aniline
# Chromium III
# Chromium VI
# Ethylene
# MCPB
# Aldehydes, unspecified
# Benzo(ghi)perylene
# Propamocarb
# Fluquinconazole
# Haloxyfop-P
# Titanium ion
# Isopropanol
# Diethylamine
# Zinc II
# Napropamide
# Nitrate
# Transformation, to dump site, residual material landfill
# Occupation, urban/industrial fallow (non-use)
# Potassium I
# Niobium-95
# Clethodim
# Famoxadone
# Lanthanum
# Acetone
# Chromium III
# Acephate
# Tin ion
# Quinmerac
# 1,1-Difluoroethane
# Magnesium
# Molybdenum VI
# Xenon-138
# Deltamethrin
# Titanium ion
# Copper oxychloride
# Abamectin
# Trifluralin
# Butane
# Propamocarb HCl
# Radium-226
# Benzo(ghi)perylene
# Dissolved solids
# Anthracene
# Volume occupied, final repository for radioactive waste
# Chlorine
# Thorium-232
# Titanium ion
# Barium II
# 1-Pentanol
# Methanol
# Dipropyl amine
# Benzene
# Fluoranthene
# Acenaphthylene
# Sulfide
# Beryllium II
# Antimony ion
# Tritosulfuron
# Cyanide
# Aluminium III
# Sulfide
# Tralkoxydim
# Tin ion
# EPTC
# Nitrate
# Lithium I
# Cobalt II
# 2-Nitrobenzoic acid
# Molybdenum VI
# Bromine
# Spirotetramat
# Gold
# Uranium-235
# Silver I
# Dichlorofluoromethane
# Diclofop
# Lead II
# Nitrite
# Lead-210
# Pethoxamid
# Polonium-210
# Pirimiphos methyl
# Transformation, to annual crop, irrigated, intensive
# Metam-sodium
# Propanal
# Aluminium III
# Imazethapyr
# Quizalofop-p-ethyl
# Paraffins
# Tribenuron
# Manganese II
# Aluminium III
# Nitrogen oxides
# Anhydrite
# Formamide
# Calcite
# Acrolein
# Trifluralin
# Transformation, from seabed, infrastructure
# Carbon disulfide
# Copper
# Hydrogen sulfide
# Chloridazon
# Waste mass, total, placed in landfill
# Trimethyl borate
# Bixafen
# Flusilazole
# Transformation, to traffic area, rail/road embankment
# Acrinathrin
# Chromium VI
# Radioactive species, Nuclides, unspecified
# 1,1,1-Trifluoroethane
# PAH, polycyclic aromatic hydrocarbons
# Sulcotrione
# Scandium
# Diquat dibromide
# Captan
# Acenaphthylene
# TOC, Total Organic Carbon
# COD, Chemical Oxygen Demand
# Selenium
# Bromoxynil
# Tembotrione
# Formaldehyde
# Carbendazim
# Carbon tetrachloride
# Lenacil
# Methoxyfenozide
# Clothianidin
# Mecoprop-P
# Dysprosium
# Dimethenamide
# Manganese II
# Magnesium
# Antimony ion
# Hydrogen sulfide
# Platinum
# Lenacil
# Platinum
# Occupation, arable land, unspecified use
# Mercury
# Steatite
# Fenamidone
# Chloroacetic acid
# Glyphosate
# m-Xylene
# Acetamiprid
# t-Butyl methyl ether
# Foramsulfuron
# TOC, Total Organic Carbon
# Asulam
# Occupation, seabed, infrastructure
# Sulfate
# Indium
# Fluorene
# Diethylene glycol
# Chloroform
# Isophorone
# Prohexadione calcium
# Desmedipham
# Sulfur trioxide
# Butadiene
# Cobalt-57
# Chloroform
# Diphenyltin
# Antimony ion
# Propanil
# Formaldehyde
# Magnesium
# Pinoxaden
# Energy, potential (in hydropower reservoir), converted
# Pyrimethanil
# Cyproconazole
# Palladium
# Chromium VI
# Dichloromethane
# Sulcotrione
# Benzaldehyde
# Bromotrifluoromethane
# Ethylene
# Florasulam
# Transformation, to pasture, man made, intensive
# Hydrocarbons, aromatic
# Sodium nitrate
# Metosulam
# Benzo(a)pyrene
# Lead II
# Propylene oxide
# Tritium
# Sodium I
# Mandipropamid
# Manganese II
# Fluoxastrobin
# Ruthenium-103
# Occupation, bare area (non-use)
# Hydrocarbons, aliphatic, unsaturated
# Acenaphthylene
# Rimsulfuron
# Thiophanate-methyl
# Pendimethalin
# Strontium II
# Esfenvalerate
# Hydrocarbons, aliphatic, unsaturated
# Sodium I
# Methyl methacrylate
# Rhenium
# Tefluthrin
# Antimony ion
# Ethofumesate
# Propyl amine
# Oils, unspecified
# Propylene oxide
# Thorium-232
# Iodine
# Magnesium
# Carboxylic acids, unspecified
# Sulfur hexafluoride
# Sulfur oxides
# Oils, unspecified
# Antimony ion
# Radium-226
# Sodium I
# Carbon disulfide
# Nitrogen
# Water
# Formate
# Beta-cyfluthrin
# Benomyl
# Isopropanol
# Acetaldehyde
# Kaolin
# Thiophanate-methyl
# Sulfentrazone
# Barium-140
# Triphenyltin
# Chloridazon
# Fluquinconazole
# Radium-224
# Dimethachlor
# Triclopyr
# Mercury II
# Cypermethrin
# Pyraflufen-ethyl
# Anthranilic acid
# Imazamox
# Pentachlorobenzene
# Hexachloroethane
# Tepraloxydim
# Terpenes
# Occupation, permanent crop, irrigated, intensive
# Chlorinated solvents, unspecified
# Chloride
# Ethyl cellulose
# Triflumuron
# Iron ion
# Uranium-234
# Sulfate
# Imidacloprid
# Fluorine
# 2,4-D dimethylamine salt
# Chlorinated solvents, unspecified
# Butanol
# Fluorene
# Methane, fossil
# Triethylammonium
# Dichlorprop
# Mancozeb
# Polonium-210
# Chloropicrin
# Transformation, from traffic area, rail/road embankment
# Prosulfocarb
# Oils, non-fossil
# Zinc II
# Acrolein
# Dinitrogen monoxide
# Dimethomorph
# Dimethyl ether
# Calcium II
# Flusilazole
# Sand, unspecified
# Vanadium V
# Paclobutrazol
# Silver I
# Butane
# 2,4-D
# Oxyfluorfen
# Antimony-125
# Arsenic ion
# Copper ion
# Methomyl
# Chloroform
# Ethephon
# Fluazifop-P-butyl
# Fenoxaprop ethyl ester
# Gravel
# Pyridate
# Tritosulfuron
# Zoxamide
# Glyphosate
# Occupation, traffic area, road network
# Metalaxyl-M
# Vinyl chloride
# Hydrocarbons, aliphatic, unsaturated
# Gamma-cyhalothrin
# Phosphorus
# Pronamide
# Chlorate
# Shale
# Ethylene dichloride
# Transformation, to grassland, natural (non-use)
# Isopropylamine
# Tetraconazole
# Ethane
# Acetaldehyde
# Fluthiacet-methyl
# Chromium VI
# PAH, polycyclic aromatic hydrocarbons
# Uranium
# Nitric oxide
# Quintozene
# Tebuconazole
# Nickel II
# Dimethenamide
# Choline chloride
# Chloride
# Acephate
# TCMTB
# Malathion
# N-methyl-2-pyrrolidone
# Solids, inorganic
# Carbendazim
# Nicosulfuron
# Pentane
# Barium II
# Aerosols, radioactive, unspecified
# Tefluthrin
# Radium-228
# Thiophanate-methyl
# Pyrene
# Potassium I
# Caesium-134
# Copper ion
# Strontium II
# Acephate
# Isopropanol
# Wood, soft, standing
# Mercury II
# Potassium I
# Arsenic ion
# Benzene
# Foramsulfuron
# Iodine
# Diclofop-methyl
# BOD5, Biological Oxygen Demand
# Transformation, from pasture, man made
# Chlorpyrifos
# Iodine
# Heat, waste
# Lactic acid
# Titanium ion
# Transformation, from heterogeneous, agricultural
# Cyazofamid
# Gibberellic acid
# Picloram
# Ammonium
# Hydroxide
# Benzovindiflupyr
# Selenium IV
# Thorium-232
# Cyprodinil
# Oils, unspecified
# Benzaldehyde
# Clodinafop-propargyl
# Clomazone
# Ammonia
# Xylenes, unspecified
# Water, cooling, unspecified natural origin
# Tungsten
# Iron ion
# Ametoctradin
# Imazethapyr
# Basalt
# Asulam
# Mepiquat chloride
# 2,4-D dimethylamine salt
# Naphthalene
# Ioxynil
# Methyl ethyl ketone
# Prothioconazole
# Calcium II
# o-Dichlorobenzene
# Pyrethrins
# Dimethylamine
# Quinmerac
# Nitrogen, organic bound
# Carbon dioxide, from soil or biomass stock
# Transformation, from arable land, unspecified use
# Fludioxonil
# Occupation, urban, continuously built
# Indeno(1,2,3-cd)pyrene
# Profenofos
# Nitrogen, organic bound
# Arsenic ion
# Dodecanol
# Asulam
# Alpha-cypermethrin
# Nicosulfuron
# Cupric chloride dihydrate
# Hexachlorobenzene
# Sulfuric acid
# Pyridate
# Aniline
# 1-Pentene
# 2,4-D dimethylamine salt
# Ammonia
# Cobalt-58
# Nickel II
# Potassium-40
# Hydrogen fluoride
# Mercury II
# Atrazine
# Tin ion
# Metsulfuron-methyl
# Cadmium II
# Epoxiconazole
# Radioactive species, alpha emitters
# Monochlorobenzene
# Propamocarb
# Fenoxaprop-P ethyl ester
# Tefluthrin
# Toluene
# Dichloromethane
# Acetylene
# Chlorine
# Selenium IV
# Cobalt-58
# Cypermethrin
# Polychlorinated biphenyls
# Dichlorodifluoromethane
# Sodium chloride
# Methyl ethyl ketone
# Diazinon
# Clothianidin
# Hydrogen sulfide
# Fluorene
# Dimethachlor
# Thorium-228
# Occupation, grassland, natural, for livestock grazing
# Vanadium
# Potassium
# Clothianidin
# Fipronil
# o-Xylene
# Vanadium V
# Copper ion
# Occupation, construction site
# Calcium II
# Tebuthiuron
# Diflubenzuron
# MCPA
# Chlorpyrifos methyl
# Potassium I
# Foramsulfuron
# Chromium III
# Water, unspecified natural origin
# Energy, gross calorific value, in biomass, primary forest
# Arsenic ion
# Rhodium
# Clodinafop-propargyl
# Acidity, unspecified
# DOC, Dissolved Organic Carbon
# Hydrocarbons, aromatic
# Transformation, to mineral extraction site
# Trichlorfon
# Dodecanol
# Vinyl chloride
# Calcium II
# Prothioconazole
# Methane, fossil
# Propionic acid
# S-Metolachlor
# Ammonium sulfate
# Cobalt II
# Pirimicarb
# Cobalt II
# 1,3-Dichloropropene
# Propanal
# Thiamethoxam
# COD, Chemical Oxygen Demand
# Strontium II
# Bromoxynil
# Uranium-234
# MCPB
# Diuron
# Transformation, to annual crop
# Atrazine
# Molybdenum VI
# Laminarin
# Sulfate
# 1,1,2-Trichloro-1,2,2-trifluoroethane
# Simazine
# Fluroxypyr
# Novaluron
# Methanol
# Phenoxy compounds
# Tebuthiuron
# Uranium-238
# Herbicides, unspecified
# Oils, unspecified
# Cerium
# Tebutam
# Propylene oxide
# Transformation, from industrial area
# Fluoride
# Transformation, to annual crop, non-irrigated, extensive
# Parathion
# AOX, Adsorbable Organic Halides
# Phenmedipham
# Glyphosate
# Carbon monoxide, fossil
# Metrafenone
# Sodium formate
