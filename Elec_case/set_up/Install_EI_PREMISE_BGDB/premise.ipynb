# %%
import bw2data, bw2io
from premise import *

# %%
# activate the bw project
bw2data.projects.set_current("ei311")
# list currently installed databases
bw2data.databases
# Out:
# Databases dictionary with 2 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff

# %%
ndb = NewDatabase(
            scenarios=[
                {"model":"remind", "pathway":"SSP2-NDC", "year":2030},
                {"model":"remind", "pathway":"SSP2-NDC", "year":2040},
                {"model":"remind", "pathway":"SSP2-NDC", "year":2050},
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 2 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-NDC. Will check online.
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# ...

# %%
ndb.update() # <- updates all sectors
# Out:
# Processing scenarios for all sectors: 100%|█| 3/3 [11:09<00:00, 223.20
# Done!

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 19:01:46 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  68%|█████████████████████████████████████████████▋                     | 25480/37360 [01:03<00:22, 518.91it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect exchange key found: Given `Comment` but `comment` is more common
#   warnings.warn(
#  74%|█████████████████████████████████████████████████▌                 | 27629/37360 [01:10<01:00, 160.54it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# ...

# %%
clear_cache() # clears both ecoinvent and additional inventories cache
#clear_inventory_cache() # clears only additional inventories cache
# Out:
# Cache folder cleared!

# %% [markdown]
# ### add another two SSP, three year

# %%
ndb3 = NewDatabase(
            scenarios=[
                #{"model":"remind", "pathway":"SSP5-NPi", "year":2030},
                #{"model":"remind", "pathway":"SSP5-NPi", "year":2040},
                #{"model":"remind", "pathway":"SSP5-NPi", "year":2050},
                
                {"model":"remind", "pathway":"SSP1-PkBudg650", "year":2030},
                {"model":"remind", "pathway":"SSP1-PkBudg650", "year":2040},
                {"model":"remind", "pathway":"SSP1-PkBudg650", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 5 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP1-PkBudg650. Will check online.
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP1-PkBudg650. Will check online.
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP1-PkBudg650. Will check online.
# ...

# %%
ndb3.update() # <- updates all sectors
# Out:
# Processing scenarios for all sectors: 100%|█| 3/3 [14:11<00:00, 283.82
# Done!

# %%
ndb3.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 21:18:06 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  68%|█████████████████████████████████████████████▊                     | 25511/37360 [02:47<00:26, 450.60it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect exchange key found: Given `Comment` but `comment` is more common
#   warnings.warn(
#  74%|█████████████████████████████████████████████████▌                 | 27638/37360 [02:53<01:08, 141.33it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# ...

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %%
list(bw2data.databases)
# Out:
# ['ecoinvent-3.11-biosphere',
#  'ecoinvent-3.11-cutoff',
#  'ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21',
#  'ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21',
#  'ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21',
#  'ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21',
#  'ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21',
#  'ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21']

# %%
len(bw2data.Database("ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21"))
# Out:
# 37360
