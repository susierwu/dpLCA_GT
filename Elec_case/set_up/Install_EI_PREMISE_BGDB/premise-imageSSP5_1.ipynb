# %%
import bw2data, bw2io
from premise import *

# %%
# activate the bw project
bw2data.projects.set_current("ei311")
# list currently installed databases
for db in bw2data.databases:
    print(db, len(bw2data.Database(db)))
# Out:
# ecoinvent-3.11-biosphere 9795
# ecoinvent-3.11-cutoff 25412
# ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21 37360
# ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21 37361
# ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21 37361
# ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22 41755
# ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22 41759
# ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22 41762
# ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22 41789
# ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22 41754
# ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22 41789
# ei_cutoff_3.11_image_SSP2-M_2040 2025-11-22 41759
# ei_cutoff_3.11_image_SSP2-M_2050 2025-11-22 41762
# ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-24 41774

# %% [raw]
# # becaz low disk space, let's delete remind SSP1 (we'll use image anyway as error for remind SSP5-NPi )
# #del bw2data.databases['ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21']
# #del bw2data.databases['ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21']
# #del bw2data.databases['ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21']

# %% [markdown]
# ### reinstall SSP1 as there's the disk low error

# %%
ndb130 = NewDatabase(
            scenarios=[
                {"model":"image", "pathway":"SSP1-VLLO", "year":2030},
                #{"model":"image", "pathway":"SSP1-VLLO", "year":2040},
                #{"model":"image", "pathway":"SSP1-VLLO", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 14 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-23
# 	ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2050 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# ...

# %%
ndb130.update()
# Out:
# Processing scenarios for all sectors:   0%|     | 0/1 [00:00<?, ?it/s]
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors: 100%|█| 1/1 [03:42<00:00, 222.95
# Done!

# %%
ndb130.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 08:30:03 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  66%|██████████████████████████████▍               | 27639/41774 [01:09<00:49, 286.22it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# 100%|██████████████████████████████████████████████| 41774/41774 [01:51<00:00, 376.03it/s]
# 08:36:31 [info     ] Vacuuming database
# Created database: ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-24
# Generate scenario report.
# Report saved under /Users/susierwu/dpLCA_main/Elec_case/Install_EI_PREMISE_BGDB/export/scenario_report.
# Generate change report.
# ...

# %% [markdown]
# ## DB installed 11/21-22

# %%
ndb1.update()
# Out:
# Processing scenarios for all sectors:   0%|     | 0/1 [00:00<?, ?it/s]
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors: 100%|█| 1/1 [03:57<00:00, 237.31
# Done!

# %%
ndb1.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 20:02:27 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  61%|█████████████████████▉              | 25468/41789 [01:02<00:33, 483.85it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect exchange key found: Given `Comment` but `comment` is more common
#   warnings.warn(
#  66%|███████████████████████▊            | 27643/41789 [01:07<01:25, 164.66it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# 100%|████████████████████████████████████| 41789/41789 [01:50<00:00, 376.85it/s]
# 20:07:04 [info     ] Vacuuming database
# ...

# %%
clear_cache()
# Out:
# Cache folder cleared!

# %% [markdown]
# ### image SSP2

# %%
ndb240 = NewDatabase(
            scenarios=[
                #{"model":"image", "pathway":"SSP2-M", "year":2030},
                {"model":"image", "pathway":"SSP2-M", "year":2040},
                #{"model":"image", "pathway":"SSP2-M", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)

ndb240.update()
ndb240.write_db_to_brightway()
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 12 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# ...

# %%
ndb250 = NewDatabase(
            scenarios=[
                #{"model":"image", "pathway":"SSP2-M", "year":2030},
                #{"model":"image", "pathway":"SSP2-M", "year":2040},
                {"model":"image", "pathway":"SSP2-M", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)

ndb250.update()
ndb250.write_db_to_brightway()
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 13 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_image_SSP1-VLLO_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP1-VLLO_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP1-VLLO_2050 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP2-M_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# ...

# %% [raw]
# # now becaz the scenario report from the SSP5 was overwritten by the new SSP, we'll redo ndb for SSP5:
# ndb5 = NewDatabase(
#             scenarios=[
#                 #{"model":"image", "pathway":"SSP5-H", "year":2030},
#                 #{"model":"image", "pathway":"SSP5-H", "year":2040},
#                 {"model":"image", "pathway":"SSP5-H", "year":2050},
#
#             ],
#             source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
#             source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
#             key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
# )

# %% [raw]
# #if only wanna sscenario report, then before write_db, .generate_scenario_report()
# ndb5.generate_scenario_report()

# %% [markdown]
# ###  there's problems downloading remind_SSP5-NPi
# - under premise v2.3.2 IAM csv:  https://zenodo.org/records/17619500

# %%
ndb2 = NewDatabase(
            scenarios=[
                {"model":"image", "pathway":"SSP5-H", "year":2030},
                {"model":"image", "pathway":"SSP5-H", "year":2040},
                {"model":"image", "pathway":"SSP5-H", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 8 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# ...

# %%
ndb2.update() # <- updates all sectors
# Out:
# Processing scenarios for all sectors:   0%|     | 0/3 [00:00<?, ?it/s]
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors:  33%|▎| 1/3 [05:04<10:09, 304.58
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors:  67%|▋| 2/3 [09:47<04:51, 291.76
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors: 100%|█| 3/3 [14:32<00:00, 290.80
# Done!

# %%
ndb2.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 09:38:08 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  66%|███████████████████████▊            | 27637/41755 [01:31<01:15, 187.92it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# 100%|████████████████████████████████████| 41755/41755 [02:27<00:00, 282.51it/s]
# 09:41:55 [info     ] Vacuuming database
# Created database: ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22
# Running all checks...
# Minor anomalies found: check the change report.
# 09:53:08 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# ...

# %%
bw2data.databases

# %%
clear_cache()

# %% [markdown]
# ### image_SSP1-VLLO -> very low long term RF objective -> SSP1-19
# ### image_SSP2-M  ->  SSP2-45

# %%
ndb1 = NewDatabase(
            scenarios=[
                {"model":"image", "pathway":"SSP1-VLLO", "year":2030},
                {"model":"image", "pathway":"SSP1-VLLO", "year":2040},
                {"model":"image", "pathway":"SSP1-VLLO", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 11 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_image_SSP5-H_2030 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2040 2025-11-22
# 	ei_cutoff_3.11_image_SSP5-H_2050 2025-11-22
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# Cannot find the IAM scenario file at /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files/image_SSP1-VLLO. Will check online.
# ...

# %%
ndb1.update()
# Out:
# Processing scenarios for all sectors:   0%|     | 0/3 [00:00<?, ?it/s]
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors:  33%|▎| 1/3 [04:10<08:21, 250.56
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors:  67%|▋| 2/3 [08:20<04:10, 250.09
# No DAC energy mix data available -- skipping
# No EWR energy mix data available -- skipping
# No two-wheeler fleet scenario data available -- skipping
# Processing scenarios for all sectors: 100%|█| 3/3 [12:32<00:00, 250.92
# Done!

# %%
ndb1.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 14:16:27 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
#  61%|█████████████████████▉              | 25528/41774 [01:22<00:41, 389.30it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect exchange key found: Given `Comment` but `comment` is more common
#   warnings.warn(
#  66%|███████████████████████▊            | 27633/41774 [01:27<01:43, 137.03it/s]/Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/bw2data/backends/typos.py:90: UserWarning: Possible incorrect activity key found: Given `Comment` but `comment` is more common
#   warnings.warn(
# 100%|████████████████████████████████████| 41774/41774 [02:25<00:00, 287.61it/s]
# 14:20:36 [info     ] Vacuuming database
# ...
