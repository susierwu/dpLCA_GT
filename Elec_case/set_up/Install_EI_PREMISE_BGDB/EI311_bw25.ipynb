# %%
import bw2data, bw2io
import numpy as np
import pandas as pd

# %% [raw]
# bw2data.projects

# %%
bw2data.projects.set_current('ei311')

# %%
# caz it's new project, nothing yet
list(bw2data.databases)
# Out:
# []

# %%
len(bw2data.Database("ecoinvent-3.11-cutoff"))
# Out:
# 25412

# %% [markdown]
# #### new way of talking to ecoinvent ... no longer .setup() / .SingleOutputEcospold2Importer()

# %%
if 'ecoinvent-3.11-cutoff' in bw2data.databases:
    print('ecoinvent 3.11 is already present in the project')
else:
    bw2io.import_ecoinvent_release(
        version='3.11',
        system_model='cutoff', 
        username='***',
        password='***'
    )
# Out:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.01 seconds
# Graph statistics for `ecoinvent-3.11-biosphere` importer:
# 9795 graph nodes:
# 	emission: 9428
# 	natural resource: 347
# 	inventory indicator: 15
# 	economic: 5
# 0 graph edges:
# 0 edges to the following databases:
# 0 unique unlinked edges (0 total):
# 100%|███████████████████████████████████████████████████████████████████| 9795/9795 [00:00<00:00, 18599.67it/s]
# 18:27:21 [info     ] Vacuuming database
# Created database: ecoinvent-3.11-biosphere
# Extracting XML data from 25412 datasets
# 18:28:44 [info     ] Extracted 25412 datasets in 81.25 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# ...
