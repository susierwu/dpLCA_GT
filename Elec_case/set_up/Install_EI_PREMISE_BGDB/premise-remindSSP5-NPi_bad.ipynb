# %%
import bw2data, bw2io
from premise import *

# %%
# activate the bw project
bw2data.projects.set_current("ei311")
# list currently installed databases
bw2data.databases
# Out:
# Databases dictionary with 8 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21

# %%
ndb2 = NewDatabase(
            scenarios=[
                {"model":"remind", "pathway":"SSP5-NPi", "year":2030},
                {"model":"remind", "pathway":"SSP5-NPi", "year":2040},
                {"model":"remind", "pathway":"SSP5-NPi", "year":2050},
                
            ],
            source_db="ecoinvent-3.11-cutoff", # <-- name of the database. Must be a string.
            source_version="3.11", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.7.1"
            key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo='
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 8 object(s):
# 	ecoinvent-3.11-biosphere
# 	ecoinvent-3.11-cutoff
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP1-PkBudg650_2050 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2030 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2040 2025-11-21
# 	ei_cutoff_3.11_remind_SSP2-NDC_2050 2025-11-21
# Name of the biosphere database:  ecoinvent-3.11-biosphere
# premise v.(2, 3, 2)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Found file: remind_SSP5-NPi
# Reading remind_SSP5-NPi as CSV file
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +------------------------------------------------------+
# |                       Variable                       |
# +------------------------------------------------------+
# |    SE|Liquids|Biomass|Cellulosic|++|Energy Crops     |
# |      SE|Liquids|Biomass|Cellulosic|++|Residues       |
# | SE|Liquids|Biomass|Non-Cellulosic|+|Sugar and Starch |
# +------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-----------------------------------------------+
# |                    Variable                   |
# +-----------------------------------------------+
# | SE|Liquids|Biomass|Non-Cellulosic|+|Oil-based |
# +-----------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +----------------------------------+
# |             Variable             |
# +----------------------------------+
# | Production|Industry|Cement w CCS |
# +----------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +--------------------------------------------+
# |                  Variable                  |
# +--------------------------------------------+
# | Production|Industry|Steel|+|DRI-NG-EAF-CCS |
# |   Production|Industry|Steel|+|DRI-NG-EAF   |
# |   Production|Industry|Steel|+|DRI-H2-EAF   |
# |     Production|Industry|Steel|+|BF-BOF     |
# |   Production|Industry|Steel|+|BF-BOF-CCS   |
# |   Production|Industry|Steel|+|SCRAP-EAF    |
# +--------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-----------------------------------+
# |              Variable             |
# +-----------------------------------+
# |         Emi|CO2|CDR|+|OAE         |
# |          Emi|CO2|CDR|+|EW         |
# |        Emi|CO2|CDR|+|DACCS        |
# | Emi|CO2|CDR|+|Synthetic Fuels CCS |
# |        Emi|CO2|CDR|+|BECCS        |
# +-----------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +--------------------------------------------------------------+
# |                           Variable                           |
# +--------------------------------------------------------------+
# | MAGICC7 AR6|Raw Surface Temperature (GMST)|50.0th Percentile |
# +--------------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-------------------------------------------------------+
# |                        Variable                       |
# +-------------------------------------------------------+
# |   ES|Transport|Freight|Road|Heavy|Truck(18t)|Liquids  |
# |    ES|Transport|Freight|Road|Heavy|Truck(26t)|Gases   |
# |    ES|Transport|Freight|Road|Light|Truck(7_5t)|FCEV   |
# |   ES|Transport|Freight|Road|Heavy|Truck(26t)|Liquids  |
# |    ES|Transport|Freight|Road|Heavy|Truck(40t)|Gases   |
# | ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids |
# |   ES|Transport|Freight|Road|Heavy|Truck(40t)|Liquids  |
# |     ES|Transport|Freight|Road|Heavy|Truck(18t)|BEV    |
# |   ES|Transport|Freight|Road|Light|Truck(0-3_5t)|FCEV  |
# |    ES|Transport|Freight|Road|Light|Truck(7_5t)|BEV    |
# |   ES|Transport|Freight|Road|Light|Truck(7_5t)|Gases   |
# |    ES|Transport|Freight|Road|Heavy|Truck(18t)|Gases   |
# |    ES|Transport|Freight|Road|Heavy|Truck(18t)|FCEV    |
# |    ES|Transport|Freight|Road|Heavy|Truck(26t)|FCEV    |
# |     ES|Transport|Freight|Road|Heavy|Truck(40t)|BEV    |
# |  ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases  |
# |     ES|Transport|Freight|Road|Heavy|Truck(26t)|BEV    |
# |   ES|Transport|Freight|Road|Light|Truck(0-3_5t)|BEV   |
# |    ES|Transport|Freight|Road|Heavy|Truck(40t)|FCEV    |
# |  ES|Transport|Freight|Road|Light|Truck(7_5t)|Liquids  |
# +-------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +--------------------------------------------+
# |                  Variable                  |
# +--------------------------------------------+
# |     ES|Transport|Freight|Rail|Electric     |
# |     ES|Transport|Freight|Rail|Liquids      |
# | ES|Transport|Freight|Rail|Liquids|Hydrogen |
# +--------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +----------------------------------------------------------------------+
# |                               Variable                               |
# +----------------------------------------------------------------------+
# |        ES|Transport|Freight|Domestic Shipping|Liquids|Biomass        |
# | FE|Transport|Bunkers|Freight|International Shipping|Liquids|Hydrogen |
# |        ES|Transport|Freight|Domestic Shipping|Liquids|Fossil         |
# +----------------------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +----------------------------------------------------------------------------------+
# |                                     Variable                                     |
# +----------------------------------------------------------------------------------+
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|FCEV           |
# | ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Hybrid electric |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|FCEV       |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids        |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|FCEV           |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|BEV       |
# |     ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hybrid electric     |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|FCEV         |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|BEV         |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases          |
# |   ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Hybrid electric    |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|BEV          |
# |  ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hybrid electric   |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|BEV           |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|BEV            |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids         |
# |              ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|BEV              |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases         |
# |             ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases             |
# |     ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Hybrid electric      |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Hybrid electric        |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|FCEV        |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases           |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids          |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids            |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases        |
# |     ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids     |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases      |
# |             ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|FCEV              |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids       |
# +----------------------------------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +------------------------------------+
# |              Variable              |
# +------------------------------------+
# |  ES|Transport|Pass|Road|Bus|FCEV   |
# |  ES|Transport|Pass|Road|Bus|Gases  |
# | ES|Transport|Pass|Road|Bus|Liquids |
# |   ES|Transport|Pass|Road|Bus|BEV   |
# +------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +----------------------------------------------------------------------+
# |                               Variable                               |
# +----------------------------------------------------------------------+
# |    ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|BEV    |
# |  ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids  |
# | ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids |
# |          ES|Transport|Pass|Road|LDV|Two Wheelers|Moped|BEV           |
# |        ES|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids         |
# |   ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|BEV   |
# +----------------------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-----------------------------------------------------------------------------------+
# |                                      Variable                                     |
# +-----------------------------------------------------------------------------------+
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Biomass     |
# |                        FE|Industry|Cement|Liquids|+|Biomass                       |
# |        FE|Transport|Bunkers|Freight|International Shipping|Liquids|Hydrogen       |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Biomass   |
# |                      FE|CDR|OAE, traditional calciner|+|Gases                     |
# |                FE|Transport|Freight|Road|Heavy|Truck(40t)|Hydrogen                |
# |                         FE|Industry|Steel|Solids|+|Biomass                        |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Biomass      |
# |                        FE|Industry|Cement|Gases|+|Hydrogen                        |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Hydrogen   |
# |         FE|Transport|Bunkers|Freight|International Shipping|Liquids|Fossil        |
# |            FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Hydrogen            |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Fossil     |
# |                FE|Transport|Freight|Road|Heavy|Truck(26t)|Hydrogen                |
# |                    FE|CDR|OAE, traditional calciner|+|Hydrogen                    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Hydrogen      |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Fossil         |
# |                          FE|Industry|Steel|Gases|+|Fossil                         |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Hydrogen        |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Electricity        |
# |     FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Fossil     |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Hydrogen             |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Hydrogen       |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Hydrogen             |
# |           FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Biomass           |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Biomass      |
# |      FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Electricity     |
# |                    FE|Industry|Other Industry|Gases|+|Hydrogen                    |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Fossil  |
# |            FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Hydrogen            |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Fossil    |
# |              FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Fossil              |
# |                       FE|Industry|Chemicals|Gases|+|Biomass                       |
# |                      FE|Industry|Chemicals|Liquids|+|Biomass                      |
# |                       FE|Industry|Chemicals|Solids|+|Biomass                      |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Biomass            |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Hydrogen             |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Biomass    |
# |                   FE|Industry|Other Industry|Liquids|+|Hydrogen                   |
# |               FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Hydrogen              |
# |            FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Hydrogen           |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Fossil    |
# |                     FE|Industry|Other Industry|Gases|+|Biomass                    |
# |                      FE|Transport|Pass|Road|Bus|Gases|Biomass                     |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Biomass  |
# |                   FE|Non-energy Use|Industry|Liquids|+|Hydrogen                   |
# |            FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Hydrogen            |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Hydrogen         |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Biomass    |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Electricity              |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Fossil    |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Hydrogen          |
# |         FE|Transport|Bunkers|Pass|International Aviation|Liquids|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Biomass     |
# |                FE|Transport|Pass|Domestic Aviation|Liquids|Biomass                |
# |                       FE|Industry|Chemicals|Liquids|+|Fossil                      |
# |                       FE|Industry|Cement|Liquids|+|Hydrogen                       |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Biomass            |
# |                    FE|Transport|Pass|Domestic Aviation|Hydrogen                   |
# |                      FE|CDR|OAE, electric calciner|+|Hydrogen                     |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Biomass           |
# |                FE|Transport|Freight|Road|Light|Truck(7_5t)|Hydrogen               |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hydrogen         |
# |                     FE|Transport|Pass|Road|Bus|Gases|Hydrogen                     |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Hydrogen    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Fossil      |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Electricity      |
# |                     FE|CDR|OAE, traditional calciner|+|Diesel                     |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Electricity       |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Fossil    |
# |                       FE|CDR|OAE, electric calciner|+|Diesel                      |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Biomass   |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Hydrogen     |
# |               FE|Transport|Freight|Road|Heavy|Truck(40t)|Electricity              |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Fossil              |
# |                         FE|Industry|Steel|Solids|+|Fossil                         |
# |            FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Fossil           |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Fossil   |
# |                      FE|Industry|Chemicals|Liquids|+|Hydrogen                     |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Hydrogen            |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Fossil   |
# |                FE|Transport|Freight|Road|Heavy|Truck(18t)|Hydrogen                |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Fossil       |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hydrogen      |
# |   FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Hydrogen   |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Biomass       |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Fossil     |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Biomass            |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Biomass             |
# |              FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Biomass             |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Hydrogen  |
# |                     FE|Industry|Other Industry|Solids|+|Fossil                    |
# |                     FE|Industry|Other Industry|Gases|+|Fossil                     |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Fossil              |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Hydrogen      |
# |                        FE|Industry|Cement|Solids|+|Biomass                        |
# |                   FE|CDR|OAE, traditional calciner|+|Electricity                  |
# |                 FE|Transport|Pass|Domestic Aviation|Liquids|Fossil                |
# |                        FE|Industry|Steel|Liquids|+|Biomass                        |
# |                        FE|Industry|Steel|Liquids|+|Hydrogen                       |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Biomass        |
# |                    FE|Industry|Other Industry|Solids|+|Biomass                    |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Biomass    |
# |     FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Biomass    |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Electricity     |
# |          FE|Transport|Bunkers|Pass|International Aviation|Liquids|Fossil          |
# |                    FE|CDR|OAE, electric calciner|+|Electricity                    |
# |            FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Biomass            |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Electricity      |
# |                     FE|Non-energy Use|Industry|Solids|+|Fossil                    |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Biomass             |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Hydrogen  |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Hydrogen     |
# |             FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Fossil            |
# |                         FE|Industry|Cement|Solids|+|Fossil                        |
# |                         FE|Industry|Steel|Gases|+|Hydrogen                        |
# |               FE|Transport|Freight|Road|Heavy|Truck(18t)|Electricity              |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Hydrogen     |
# |                    FE|Non-energy Use|Industry|Liquids|+|Biomass                   |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Fossil            |
# |                         FE|Industry|Steel|Gases|+|Biomass                         |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Fossil             |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Biomass            |
# |                      FE|Transport|Pass|Road|Bus|Gases|Fossil                      |
# |                     FE|Non-energy Use|Industry|Gases|+|Fossil                     |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Electricity   |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Biomass |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Biomass             |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Hydrogen    |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Fossil          |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Fossil      |
# |             FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Electricity             |
# |                    FE|Non-energy Use|Industry|Liquids|+|Fossil                    |
# |                         FE|Industry|Steel|Liquids|+|Fossil                        |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Fossil       |
# |            FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Hydrogen            |
# |                        FE|Industry|Cement|Liquids|+|Fossil                        |
# |               FE|Transport|Freight|Road|Heavy|Truck(26t)|Electricity              |
# |                    FE|Non-energy Use|Industry|Solids|+|Biomass                    |
# |        FE|Transport|Bunkers|Freight|International Shipping|Liquids|Biomass        |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Fossil           |
# |                    FE|Industry|Other Industry|Liquids|+|Biomass                   |
# |              FE|Transport|Freight|Domestic Shipping|Liquids|Hydrogen              |
# |               FE|Transport|Freight|Domestic Shipping|Liquids|Fossil               |
# |                         FE|Industry|Cement|Gases|+|Fossil                         |
# |                    FE|Industry|Other Industry|Liquids|+|Fossil                    |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Fossil             |
# |             FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Electricity             |
# | FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Hydrogen |
# |                FE|Transport|Pass|Domestic Aviation|Liquids|Hydrogen               |
# |                       FE|Industry|Chemicals|Gases|+|Hydrogen                      |
# |                    FE|Non-energy Use|Industry|Gases|+|Hydrogen                    |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Hydrogen   |
# |                        FE|Industry|Chemicals|Gases|+|Fossil                       |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Hydrogen           |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Hydrogen   |
# |               FE|Transport|Freight|Domestic Shipping|Liquids|Biomass              |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Hydrogen       |
# |           FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Electricity          |
# |           FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Hydrogen          |
# |          FE|Transport|Bunkers|Pass|International Aviation|Liquids|Biomass         |
# |                       FE|Industry|Chemicals|Solids|+|Fossil                       |
# |                     FE|Non-energy Use|Industry|Gases|+|Biomass                    |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Biomass         |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Biomass     |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Hydrogen    |
# |                         FE|Industry|Cement|Gases|+|Biomass                        |
# |       FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Electricity      |
# +-----------------------------------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +---------------------------------------------------------+
# |                         Variable                        |
# +---------------------------------------------------------+
# |        Tech|Liquids|Biomass|Biodiesel|Efficiency        |
# | Tech|Liquids|Biomass|Lignocellulosic Ethanol|Efficiency |
# +---------------------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-------------------------------------------+
# |                  Variable                 |
# +-------------------------------------------+
# | Tech|Liquids|Biomass|Biodiesel|Efficiency |
# +-------------------------------------------+
# The following variables are missing from the IAM file: /Users/susierwu/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/data/iam_output_files
# +-----------------------------------------------------------------------------------+
# |                                      Variable                                     |
# +-----------------------------------------------------------------------------------+
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Biomass     |
# |                        FE|Industry|Cement|Liquids|+|Biomass                       |
# |        FE|Transport|Bunkers|Freight|International Shipping|Liquids|Hydrogen       |
# |           ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|BEV          |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Biomass   |
# |  ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Hybrid electric |
# |                FE|Transport|Freight|Road|Heavy|Truck(40t)|Hydrogen                |
# |                      FE|CDR|OAE, traditional calciner|+|Gases                     |
# |                  ES|Transport|Freight|Road|Heavy|Truck(26t)|Gases                 |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Biomass      |
# |                 ES|Transport|Pass|Road|LDV|Two Wheelers|Moped|BEV                 |
# |                         FE|Industry|Steel|Solids|+|Biomass                        |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids        |
# |                 ES|Transport|Freight|Road|Heavy|Truck(26t)|Liquids                |
# |                         FE|Industry|Cement|Gases|+|Biomass                        |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|BEV       |
# |                        FE|Industry|Cement|Gases|+|Hydrogen                        |
# |                  ES|Transport|Freight|Road|Heavy|Truck(40t)|Gases                 |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Hydrogen   |
# |                           ES|Transport|Pass|Road|Bus|BEV                          |
# |                 ES|Transport|Freight|Road|Heavy|Truck(40t)|Liquids                |
# |                                Emi|CO2|CDR|+|DACCS                                |
# |         FE|Transport|Bunkers|Freight|International Shipping|Liquids|Fossil        |
# |            FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Hydrogen            |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|BEV          |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Fossil     |
# |                FE|Transport|Freight|Road|Heavy|Truck(26t)|Hydrogen                |
# |                    FE|CDR|OAE, traditional calciner|+|Hydrogen                    |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Electricity        |
# |     FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Fossil     |
# |                          FE|Industry|Steel|Gases|+|Fossil                         |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Fossil         |
# |                 ES|Transport|Freight|Road|Light|Truck(0-3_5t)|FCEV                |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Hydrogen      |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Hydrogen       |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Hydrogen             |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Hydrogen             |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Hydrogen        |
# |           FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Biomass           |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Biomass      |
# |      FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Electricity     |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids         |
# |                    FE|Industry|Other Industry|Gases|+|Hydrogen                    |
# |              ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases             |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Fossil  |
# |            FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Hydrogen            |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Fossil    |
# |                                Emi|CO2|CDR|+|BECCS                                |
# |                     ES|Transport|Freight|Rail|Liquids|Hydrogen                    |
# |                   SE|Liquids|Biomass|Non-Cellulosic|+|Oil-based                   |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases           |
# |              FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Fossil              |
# |             ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids            |
# |                     SE|Liquids|Biomass|Cellulosic|++|Residues                     |
# |                       FE|Industry|Chemicals|Gases|+|Biomass                       |
# |                      FE|Industry|Chemicals|Liquids|+|Biomass                      |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids     |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases      |
# |                       FE|Industry|Chemicals|Solids|+|Biomass                      |
# |                         ES|Transport|Freight|Rail|Electric                        |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Biomass            |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Hydrogen             |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Biomass    |
# |                          ES|Transport|Pass|Road|Bus|Gases                         |
# |                   FE|Industry|Other Industry|Liquids|+|Hydrogen                   |
# |               FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Hydrogen              |
# |            FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Hydrogen           |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Fossil    |
# |                  ES|Transport|Freight|Road|Light|Truck(7_5t)|FCEV                 |
# |                     FE|Industry|Other Industry|Gases|+|Biomass                    |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|FCEV       |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Hydrogen          |
# |                      FE|Transport|Pass|Road|Bus|Gases|Biomass                     |
# |                   FE|Non-energy Use|Industry|Liquids|+|Hydrogen                   |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Fossil    |
# |            FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Hydrogen            |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Hydrogen         |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Biomass  |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Biomass    |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Electricity              |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|BEV         |
# |         FE|Transport|Bunkers|Pass|International Aviation|Liquids|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Biomass     |
# |                FE|Transport|Pass|Domestic Aviation|Liquids|Biomass                |
# |                    FE|Transport|Pass|Domestic Aviation|Hydrogen                   |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Biomass            |
# |                       FE|Industry|Cement|Liquids|+|Hydrogen                       |
# |                       FE|Industry|Chemicals|Liquids|+|Fossil                      |
# |   ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hybrid electric   |
# |                      FE|CDR|OAE, electric calciner|+|Hydrogen                     |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Biomass           |
# |                FE|Transport|Freight|Road|Light|Truck(7_5t)|Hydrogen               |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hydrogen         |
# |                     FE|Transport|Pass|Road|Bus|Gases|Hydrogen                     |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Hydrogen    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Fossil      |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Electricity      |
# |                   SE|Liquids|Biomass|Cellulosic|++|Energy Crops                   |
# |                     FE|CDR|OAE, traditional calciner|+|Diesel                     |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Hybrid electric        |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Electricity       |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Fossil    |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|FCEV        |
# |                       FE|CDR|OAE, electric calciner|+|Diesel                      |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Biomass   |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Hydrogen     |
# |               FE|Transport|Freight|Road|Heavy|Truck(40t)|Electricity              |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Fossil              |
# |                         FE|Industry|Steel|Solids|+|Fossil                         |
# |            FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Fossil           |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Fossil   |
# |                   ES|Transport|Freight|Road|Heavy|Truck(40t)|BEV                  |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Hydrogen            |
# |                      FE|Industry|Chemicals|Liquids|+|Hydrogen                     |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Fossil   |
# |                FE|Transport|Freight|Road|Heavy|Truck(18t)|Hydrogen                |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Fossil       |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hydrogen      |
# |   FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Hydrogen   |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Biomass       |
# |                  ES|Transport|Freight|Road|Heavy|Truck(40t)|FCEV                  |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Fossil     |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Biomass            |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Biomass             |
# |              FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Biomass             |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Hydrogen  |
# |                     FE|Industry|Other Industry|Solids|+|Fossil                    |
# |                     FE|Industry|Other Industry|Gases|+|Fossil                     |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Fossil              |
# |                          ES|Transport|Pass|Road|Bus|FCEV                          |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Hydrogen      |
# |                        FE|Industry|Cement|Solids|+|Biomass                        |
# |                   FE|CDR|OAE, traditional calciner|+|Electricity                  |
# |                 FE|Transport|Pass|Domestic Aviation|Liquids|Fossil                |
# |                        FE|Industry|Steel|Liquids|+|Biomass                        |
# |                         ES|Transport|Pass|Road|Bus|Liquids                        |
# |                        FE|Industry|Steel|Liquids|+|Hydrogen                       |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|FCEV           |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Biomass    |
# |                    FE|Industry|Other Industry|Solids|+|Biomass                    |
# |     FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Biomass    |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Biomass        |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Electricity     |
# |               ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids               |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|FCEV         |
# |          FE|Transport|Bunkers|Pass|International Aviation|Liquids|Fossil          |
# |    ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Hybrid electric    |
# |         ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids        |
# |            FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Biomass            |
# |                   ES|Transport|Freight|Road|Heavy|Truck(18t)|BEV                  |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Biomass             |
# |                     FE|Non-energy Use|Industry|Solids|+|Fossil                    |
# |                    FE|CDR|OAE, electric calciner|+|Electricity                    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Electricity      |
# |               ES|Transport|Freight|Domestic Shipping|Liquids|Biomass              |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Hydrogen  |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Hydrogen     |
# |             FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Fossil            |
# |                         FE|Industry|Cement|Solids|+|Fossil                        |
# |                         FE|Industry|Steel|Gases|+|Hydrogen                        |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Hydrogen     |
# |               FE|Transport|Freight|Road|Heavy|Truck(18t)|Electricity              |
# |                    FE|Non-energy Use|Industry|Liquids|+|Biomass                   |
# |                  ES|Transport|Freight|Road|Light|Truck(7_5t)|BEV                  |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Fossil            |
# |                                 Emi|CO2|CDR|+|OAE                                 |
# |               ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|BEV              |
# |                         FE|Industry|Steel|Gases|+|Biomass                         |
# |                       Production|Industry|Steel|+|DRI-NG-EAF                      |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Fossil             |
# |                 ES|Transport|Freight|Road|Light|Truck(7_5t)|Gases                 |
# |                      FE|Transport|Pass|Road|Bus|Gases|Fossil                      |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Biomass            |
# |                  ES|Transport|Freight|Road|Heavy|Truck(18t)|Gases                 |
# |                     FE|Non-energy Use|Industry|Gases|+|Fossil                     |
# |                       Production|Industry|Steel|+|DRI-H2-EAF                      |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Electricity   |
# |                  ES|Transport|Freight|Road|Heavy|Truck(18t)|FCEV                  |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Biomass |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Biomass             |
# |                  ES|Transport|Freight|Road|Heavy|Truck(26t)|FCEV                  |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Hydrogen    |
# |                ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases                |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Fossil          |
# |                   ES|Transport|Freight|Road|Heavy|Truck(26t)|BEV                  |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Fossil      |
# |             FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Electricity             |
# |                    FE|Non-energy Use|Industry|Liquids|+|Fossil                    |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids       |
# |                         FE|Industry|Steel|Liquids|+|Fossil                        |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Fossil       |
# |                ES|Transport|Freight|Road|Light|Truck(7_5t)|Liquids                |
# |            FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Hydrogen            |
# |                SE|Liquids|Biomass|Non-Cellulosic|+|Sugar and Starch               |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|FCEV           |
# |               ES|Transport|Freight|Domestic Shipping|Liquids|Fossil               |
# |                 ES|Transport|Freight|Road|Heavy|Truck(18t)|Liquids                |
# |                         Production|Industry|Steel|+|BF-BOF                        |
# |                        FE|Industry|Cement|Liquids|+|Fossil                        |
# |          ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|BEV         |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hybrid electric     |
# |                         ES|Transport|Freight|Rail|Liquids                         |
# |               FE|Transport|Freight|Road|Heavy|Truck(26t)|Electricity              |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases          |
# |                    FE|Non-energy Use|Industry|Solids|+|Biomass                    |
# |        FE|Transport|Bunkers|Freight|International Shipping|Liquids|Biomass        |
# |                         Emi|CO2|CDR|+|Synthetic Fuels CCS                         |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Fossil           |
# |                    FE|Industry|Other Industry|Liquids|+|Biomass                   |
# |              FE|Transport|Freight|Domestic Shipping|Liquids|Hydrogen              |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|BEV           |
# |               FE|Transport|Freight|Domestic Shipping|Liquids|Fossil               |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|BEV            |
# |                         FE|Industry|Cement|Gases|+|Fossil                         |
# |                    FE|Industry|Other Industry|Liquids|+|Fossil                    |
# ...
# |                  ES|Transport|Freight|Road|Light|Truck(7_5t)|FCEV                 |
# |                     FE|Industry|Other Industry|Gases|+|Biomass                    |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|FCEV       |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Hydrogen          |
# |                      FE|Transport|Pass|Road|Bus|Gases|Biomass                     |
# |                   FE|Non-energy Use|Industry|Liquids|+|Hydrogen                   |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Fossil    |
# |            FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Hydrogen            |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Hydrogen         |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Biomass  |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases|Biomass    |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Electricity              |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|BEV         |
# |         FE|Transport|Bunkers|Pass|International Aviation|Liquids|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Biomass     |
# |                FE|Transport|Pass|Domestic Aviation|Liquids|Biomass                |
# |                    FE|Transport|Pass|Domestic Aviation|Hydrogen                   |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Biomass            |
# |                       FE|Industry|Cement|Liquids|+|Hydrogen                       |
# |                       FE|Industry|Chemicals|Liquids|+|Fossil                      |
# |   ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hybrid electric   |
# |                      FE|CDR|OAE, electric calciner|+|Hydrogen                     |
# |           FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Biomass           |
# |                FE|Transport|Freight|Road|Light|Truck(7_5t)|Hydrogen               |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hydrogen         |
# |                     FE|Transport|Pass|Road|Bus|Gases|Hydrogen                     |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Hydrogen    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Fossil      |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Electricity      |
# |                   SE|Liquids|Biomass|Cellulosic|++|Energy Crops                   |
# |                     FE|CDR|OAE, traditional calciner|+|Diesel                     |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Hybrid electric        |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Electricity       |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Fossil    |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|FCEV        |
# |                       FE|CDR|OAE, electric calciner|+|Diesel                      |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Biomass   |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Hydrogen     |
# |               FE|Transport|Freight|Road|Heavy|Truck(40t)|Electricity              |
# |             FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Fossil              |
# |                         FE|Industry|Steel|Solids|+|Fossil                         |
# |            FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids|Fossil           |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Fossil   |
# |                   ES|Transport|Freight|Road|Heavy|Truck(40t)|BEV                  |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Hydrogen            |
# |                      FE|Industry|Chemicals|Liquids|+|Hydrogen                     |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Fossil   |
# |                FE|Transport|Freight|Road|Heavy|Truck(18t)|Hydrogen                |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Fossil       |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Hydrogen      |
# |   FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids|Hydrogen   |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Biomass       |
# |                  ES|Transport|Freight|Road|Heavy|Truck(40t)|FCEV                  |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Gases|Fossil     |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Biomass            |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Biomass             |
# |              FE|Transport|Freight|Road|Heavy|Truck(18t)|Gases|Biomass             |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Gases|Hydrogen  |
# |                     FE|Industry|Other Industry|Solids|+|Fossil                    |
# |                     FE|Industry|Other Industry|Gases|+|Fossil                     |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Fossil              |
# |                          ES|Transport|Pass|Road|Bus|FCEV                          |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Gases|Hydrogen      |
# |                        FE|Industry|Cement|Solids|+|Biomass                        |
# |                   FE|CDR|OAE, traditional calciner|+|Electricity                  |
# |                 FE|Transport|Pass|Domestic Aviation|Liquids|Fossil                |
# |                        FE|Industry|Steel|Liquids|+|Biomass                        |
# |                         ES|Transport|Pass|Road|Bus|Liquids                        |
# |                        FE|Industry|Steel|Liquids|+|Hydrogen                       |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|FCEV           |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Biomass    |
# |                    FE|Industry|Other Industry|Solids|+|Biomass                    |
# |     FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Biomass    |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Liquids|Biomass        |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Electricity     |
# |               ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids               |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|FCEV         |
# |          FE|Transport|Bunkers|Pass|International Aviation|Liquids|Fossil          |
# |    ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Hybrid electric    |
# |         ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids        |
# |            FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Biomass            |
# |                   ES|Transport|Freight|Road|Heavy|Truck(18t)|BEV                  |
# |              FE|Transport|Freight|Road|Heavy|Truck(40t)|Gases|Biomass             |
# |                     FE|Non-energy Use|Industry|Solids|+|Fossil                    |
# |                    FE|CDR|OAE, electric calciner|+|Electricity                    |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Electricity      |
# |               ES|Transport|Freight|Domestic Shipping|Liquids|Biomass              |
# |   FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids|Hydrogen  |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Hydrogen     |
# |             FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Fossil            |
# |                         FE|Industry|Cement|Solids|+|Fossil                        |
# |                         FE|Industry|Steel|Gases|+|Hydrogen                        |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Hydrogen     |
# |               FE|Transport|Freight|Road|Heavy|Truck(18t)|Electricity              |
# |                    FE|Non-energy Use|Industry|Liquids|+|Biomass                   |
# |                  ES|Transport|Freight|Road|Light|Truck(7_5t)|BEV                  |
# |             FE|Transport|Freight|Road|Light|Truck(7_5t)|Liquids|Fossil            |
# |                                 Emi|CO2|CDR|+|OAE                                 |
# |               ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|BEV              |
# |                         FE|Industry|Steel|Gases|+|Biomass                         |
# |                       Production|Industry|Steel|+|DRI-NG-EAF                      |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Fossil             |
# |              FE|Transport|Freight|Road|Light|Truck(7_5t)|Gases|Fossil             |
# |                 ES|Transport|Freight|Road|Light|Truck(7_5t)|Gases                 |
# |                      FE|Transport|Pass|Road|Bus|Gases|Fossil                      |
# |             FE|Transport|Freight|Road|Heavy|Truck(18t)|Liquids|Biomass            |
# |                  ES|Transport|Freight|Road|Heavy|Truck(18t)|Gases                 |
# |                     FE|Non-energy Use|Industry|Gases|+|Fossil                     |
# |                       Production|Industry|Steel|+|DRI-H2-EAF                      |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Electricity   |
# |                  ES|Transport|Freight|Road|Heavy|Truck(18t)|FCEV                  |
# |  FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Biomass |
# |              FE|Transport|Freight|Road|Heavy|Truck(26t)|Gases|Biomass             |
# |                  ES|Transport|Freight|Road|Heavy|Truck(26t)|FCEV                  |
# |         FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Hydrogen         |
# |     FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases|Hydrogen    |
# |                ES|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases                |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Fossil          |
# |                   ES|Transport|Freight|Road|Heavy|Truck(26t)|BEV                  |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids|Fossil      |
# |             FE|Transport|Pass|Road|LDV|Two Wheelers|Moped|Electricity             |
# |                    FE|Non-energy Use|Industry|Liquids|+|Fossil                    |
# |       ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Liquids       |
# |                         FE|Industry|Steel|Liquids|+|Fossil                        |
# |       FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases|Fossil       |
# |                ES|Transport|Freight|Road|Light|Truck(7_5t)|Liquids                |
# |            FE|Transport|Freight|Road|Heavy|Truck(40t)|Liquids|Hydrogen            |
# |                SE|Liquids|Biomass|Non-Cellulosic|+|Sugar and Starch               |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|FCEV           |
# |               ES|Transport|Freight|Domestic Shipping|Liquids|Fossil               |
# |                 ES|Transport|Freight|Road|Heavy|Truck(18t)|Liquids                |
# |                         Production|Industry|Steel|+|BF-BOF                        |
# |                        FE|Industry|Cement|Liquids|+|Fossil                        |
# |          ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|BEV         |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Hybrid electric     |
# |                         ES|Transport|Freight|Rail|Liquids                         |
# |               FE|Transport|Freight|Road|Heavy|Truck(26t)|Electricity              |
# |           ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Gases          |
# |                    FE|Non-energy Use|Industry|Solids|+|Biomass                    |
# |        FE|Transport|Bunkers|Freight|International Shipping|Liquids|Biomass        |
# |                         Emi|CO2|CDR|+|Synthetic Fuels CCS                         |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Fossil           |
# |                    FE|Industry|Other Industry|Liquids|+|Biomass                   |
# |              FE|Transport|Freight|Domestic Shipping|Liquids|Hydrogen              |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|BEV           |
# |               FE|Transport|Freight|Domestic Shipping|Liquids|Fossil               |
# |            ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|BEV            |
# |                         FE|Industry|Cement|Gases|+|Fossil                         |
# |                    FE|Industry|Other Industry|Liquids|+|Fossil                    |
# | FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car and SUV|Liquids|Hydrogen |
# |         ES|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Gases         |
# |             FE|Transport|Freight|Road|Heavy|Truck(26t)|Liquids|Fossil             |
# |                     Production|Industry|Steel|+|DRI-NG-EAF-CCS                    |
# |                FE|Transport|Pass|Domestic Aviation|Liquids|Hydrogen               |
# |                                  Emi|CO2|CDR|+|EW                                 |
# |             FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Electricity             |
# |      ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Hybrid electric      |
# |        ES|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(50-250cc)|Liquids       |
# |                       FE|Industry|Chemicals|Gases|+|Hydrogen                      |
# |                    FE|Non-energy Use|Industry|Gases|+|Hydrogen                    |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Liquids|Hydrogen   |
# |          ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Mini Car|Liquids          |
# |            FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Gases|Hydrogen           |
# |                        FE|Industry|Chemicals|Gases|+|Fossil                       |
# |    FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Compact Car|Liquids|Hydrogen   |
# |               ES|Transport|Pass|Road|LDV|Two Wheelers|Moped|Liquids               |
# |               FE|Transport|Freight|Domestic Shipping|Liquids|Biomass              |
# |        FE|Transport|Pass|Road|LDV|Four Wheelers|Medium|Midsize Car|Hydrogen       |
# |        ES|Transport|Pass|Road|LDV|Four Wheelers|Small|Subcompact Car|Gases        |
# |           FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Electricity          |
# |                          Production|Industry|Cement w CCS                         |
# |           FE|Transport|Freight|Road|Light|Truck(0-3_5t)|Liquids|Hydrogen          |
# |          FE|Transport|Bunkers|Pass|International Aviation|Liquids|Biomass         |
# |                 ES|Transport|Freight|Road|Light|Truck(0-3_5t)|BEV                 |
# |                       FE|Industry|Chemicals|Solids|+|Fossil                       |
# |                     FE|Non-energy Use|Industry|Gases|+|Biomass                    |
# |              ES|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|FCEV              |
# |          FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Van|Gases|Biomass         |
# |      FE|Transport|Pass|Road|LDV|Four Wheelers|Large|Large Car|Liquids|Biomass     |
# |    FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Liquids|Hydrogen    |
# |                       Production|Industry|Steel|+|BF-BOF-CCS                      |
# |       FE|Transport|Pass|Road|LDV|Two Wheelers|Motorcycle(>250cc)|Electricity      |
# |                       Production|Industry|Steel|+|SCRAP-EAF                       |
# +-----------------------------------------------------------------------------------+
# Done!

# %%
ndb2.update() # <- updates all sectors
# Out:
# Processing scenarios for all sectors:   0%|     | 0/3 [00:00<?, ?it/s]
# No steel scenario data available -- skipping
# Processing scenarios for all sectors:   0%|     | 0/3 [00:54<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bioethanol, from wood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/xarray/core/indexes.py:772, in PandasIndex.sel(self, labels, method, tolerance)
#     771 try:
# --> 772     indexer = self.index.get_loc(label_value)
#     773 except KeyError as e:
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#
# KeyError: 'bioethanol, from wood'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 ndb2.update() # <- updates all sectors
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/new_database.py:1080, in NewDatabase.update(self, sectors)
#    1078 update_func = self.sector_update_methods[sector]["func"]
#    1079 fixed_args = self.sector_update_methods[sector]["args"]
# -> 1080 scenario = update_func(scenario, *fixed_args)
#    1082 if "applied functions" not in scenario:
#    1083     scenario["applied functions"] = []
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/fuels/base.py:45, in _update_fuels(scenario, version, system_model)
#      35 if any(
#      36     x is not None
#      37     for x in (
#    (...)
#      42     )
#      43 ):
#      44     fuels.generate_hydrogen_activities()
# ---> 45     fuels.generate_synthetic_fuel_activities()
#      46     fuels.generate_biogas_activities()
#      47     fuels.relink_datasets()
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/fuels/liquid_fuels.py:37, in SyntheticFuelsMixin.generate_synthetic_fuel_activities(self)
#      34 # gasoline
#      35 # check that IAM data has "petrol_blend" attribute
#      36 if hasattr(self.iam_data, "petrol_blend"):
# ---> 37     mapping = {
#      38         k: v
#      39         for k, v in self.fuel_map.items()
#      40         if any(
#      41             k.startswith(x)
#      42             for x in ("gasoline", "bioethanol", "ethanol", "petrol", "methanol")
#      43         )
#      44         and self.iam_data.petrol_blend.sel(variables=k).sum() > 0
#      45     }
#      46     if mapping:
#      47         for market_name in [
#      48             "market for petrol",
#      49             "market for petrol, low-sulfur",
#      50         ]:
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/premise/fuels/liquid_fuels.py:44, in <dictcomp>(.0)
#      34 # gasoline
#      35 # check that IAM data has "petrol_blend" attribute
#      36 if hasattr(self.iam_data, "petrol_blend"):
#      37     mapping = {
#      38         k: v
#      39         for k, v in self.fuel_map.items()
#      40         if any(
#      41             k.startswith(x)
#      42             for x in ("gasoline", "bioethanol", "ethanol", "petrol", "methanol")
#      43         )
# ---> 44         and self.iam_data.petrol_blend.sel(variables=k).sum() > 0
#      45     }
#      46     if mapping:
#      47         for market_name in [
#      48             "market for petrol",
#      49             "market for petrol, low-sulfur",
#      50         ]:
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/xarray/core/dataarray.py:1614, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1498 def sel(
#    1499     self,
#    1500     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1504     **indexers_kwargs: Any,
#    1505 ) -> Self:
#    1506     """Return a new DataArray whose data is given by selecting index
#    1507     labels along the specified dimension(s).
#    1508
#    (...)
#    1612     Dimensions without coordinates: points
#    1613     """
# -> 1614     ds = self._to_temp_dataset().sel(
#    1615         indexers=indexers,
#    1616         drop=drop,
#    1617         method=method,
#    1618         tolerance=tolerance,
#    1619         **indexers_kwargs,
#    1620     )
#    1621     return self._from_temp_dataset(ds)
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/xarray/core/dataset.py:3091, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    3023 """Returns a new dataset with each array indexed by tick labels
#    3024 along the specified dimension(s).
#    3025
#    (...)
#    3088
#    3089 """
#    3090 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 3091 query_results = map_index_queries(
#    3092     self, indexers=indexers, method=method, tolerance=tolerance
#    3093 )
#    3095 if drop:
#    3096     no_scalar_variables = {}
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/xarray/core/indexing.py:190, in map_index_queries(obj, indexers, method, tolerance, **indexers_kwargs)
#     188         results.append(IndexSelResult(labels))
#     189     else:
# --> 190         results.append(index.sel(labels, **options))
#     192 merged = merge_sel_results(results)
#     194 # drop dimension coordinates found in dimension indexers
#     195 # (also drop multi-index if any)
#     196 # (.sel() already ensures alignment)
#
# File ~/miniconda3/envs/bw25_viz/lib/python3.11/site-packages/xarray/core/indexes.py:774, in PandasIndex.sel(self, labels, method, tolerance)
#     772                 indexer = self.index.get_loc(label_value)
#     773             except KeyError as e:
# --> 774                 raise KeyError(
#     775                     f"not all values found in index {coord_name!r}. "
#     776                     "Try setting the `method` keyword argument (example: method='nearest')."
#     777                 ) from e
#     779 elif label_array.dtype.kind == "b":
#     780     indexer = label_array
#
# KeyError: "not all values found in index 'variables'. Try setting the `method` keyword argument (example: method='nearest')."

# %%
ndb2.write_db_to_brightway()
