# %% [markdown]
# ###  ONE scn/MY dplcia and decompost single flows

# %%
import bw2data
from bw2data import get_activity

# %%
import sys
sys.path.append('../../utils/') 
from dpLCIA import *

# %%
# activate the bw project needed to use bw2data.
bw2data.projects.set_current("ei311")

# %% [markdown]
# ### SSP5

# %%
metric = 'rf'
one_file_path =  "../dp-LCI_output/hydro_dpLCI_reservoir/dateshifted/market_for_electricity_hydro_high_voltage_CA-QC_SSP5-H_2050.xlsx"

ghg_dir = "../../../dpLCIA/FaIR_dpCFs/output/metrics_AGWP_wh_ModC_CC_T"   # directory containing all CO2/CH4/N2O Excel files


out = compute_dynamic_lcia_by_category(
    elec_path=one_file_path,
    ghg_dir=ghg_dir,
    metric=metric,
)

eval_years = out["eval_years"]
central    = out["central"]
band       = out["band"]
flow_info  = out["flow_info"]
ssp_ = out["SSP"]
MY_ = out["ModelYear"] 

#print("=== DONE: dynamic LCIA computed ===")
print("central columns:", central.columns.tolist())
print("band columns (lower):", band["lower"].columns.tolist())
print("band columns (upper):", band["upper"].columns.tolist())
# Out:
# [dynamic_ghg_lcia] Truncating CO2 kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1CO2_ssp585_fair_start1750MY2050.xlsx'
# [dynamic_ghg_lcia] Truncating CH4 kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1CH4_ssp585_fair_start1750MY2050.xlsx'
# [dynamic_ghg_lcia] Truncating N2O kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1N2O_ssp585_fair_start1750MY2050.xlsx'
# central columns: ['ch4_biomass', 'ch4_fossil', 'ch4_non_fossil', 'ch4_other', 'co2_biogenic', 'co2_fossil_positive', 'co2_other_negative', 'n2o_all', 'co2_total', 'ch4_total', 'n2o_total', 'all_ghg']
# band columns (lower): ['ch4_biomass', 'ch4_fossil', 'ch4_non_fossil', 'ch4_other', 'co2_biogenic', 'co2_fossil_positive', 'co2_other_negative', 'n2o_all', 'co2_total', 'ch4_total', 'n2o_total', 'all_ghg']
# ...

# %%
central["co2_biogenic"]
# Out:
# 2046-01-01    1.990892e-18
# 2047-01-01    3.876255e-18
# 2048-01-01    5.682923e-18
# 2049-01-01    7.430753e-18
# 2050-01-01    9.133320e-18
#                   ...
# 2152-01-01    8.297417e-18
# 2153-01-01    6.550498e-18
# 2154-01-01    4.847545e-18
# 2155-01-01    3.187957e-18
# 2156-01-01    1.572011e-18
# Freq: YS-JAN, Name: co2_biogenic, Length: 111, dtype: float64

# %% [markdown]
# #### hard coded color needed : SSP5: #d7191c

# %%
# -----------------------------------------------------------
# PLOTTING HELPERS
# -----------------------------------------------------------
def quick_plot(y, lower, upper, title, color="#d7191c"):
    fig, ax = plt.subplots(figsize=(8, 3.5))
    ax.plot(y.index, y.values, color=color, lw=2)
    #ax.plot(y.index, y.values)
    ax.fill_between(y.index, lower.values, upper.values, color=color, alpha=0.20)

    ax.set_title(title)
    plt.grid(True)
    plt.show()
    

# 1. CO2 category 
if "co2_biogenic" in central.columns:
    quick_plot(
        central["co2_biogenic"],
        band["lower"]["co2_biogenic"],
        band["upper"]["co2_biogenic"],
        f"dp-{metric}: CO₂ (biogenic), SSP5-85/2050",
        color="#d7191c"
    )
else:
    print("Not found.")



quick_plot(
    central["co2_fossil_positive"],
    band["lower"]["co2_fossil_positive"],
    band["upper"]["co2_fossil_positive"],
    f"dp-{metric}: CO₂ (fossil), SSP5-85/2050",
    color="#d7191c"
    
)


quick_plot(
    central["co2_other_negative"],
    band["lower"]["co2_other_negative"],
    band["upper"]["co2_other_negative"],
    f"dp-{metric}: CO₂ negative, SSP5-85/2050",
    color="#d7191c"
)


#   CO2 total
quick_plot(
    central["co2_total"],
    band["lower"]["co2_total"],
    band["upper"]["co2_total"],
    f"dp-{metric}: CO₂ total, SSP5-85/2050",
    color="#d7191c"
)


# -----------------------------------------------------------
# 3. CH4 total
# -----------------------------------------------------------

if "ch4_non_fossil" in central.columns:
    quick_plot(
        central["ch4_non_fossil"],
        band["lower"]["ch4_non_fossil"],
        band["upper"]["ch4_non_fossil"],
        f"dp-{metric}: CH₄ (biogenic), SSP5-85/2050",
        color="#d7191c"
    )
else:
    print("Not found.")


quick_plot(
    central["ch4_total"],
    band["lower"]["ch4_total"],
    band["upper"]["ch4_total"],
    f"dp-{metric}: CH₄ total, SSP5-85/2050",
    color="#d7191c"
)

# %% [markdown]
# #### now SSP1 2050 : color = #2c7bb6  # not changed yet caz it's already blueish

# %%
metric = 'rf'
one_file_path =  "../dp-LCI_output/hydro_dpLCI_reservoir/dateshifted/market_for_electricity_hydro_high_voltage_CA-QC_SSP1-VLLO_2050.xlsx"

ghg_dir = "../../../dpLCIA/FaIR_dpCFs/output/metrics_AGWP_wh_ModC_CC_T"   # directory containing all CO2/CH4/N2O Excel files


out = compute_dynamic_lcia_by_category(
    elec_path=one_file_path,
    ghg_dir=ghg_dir,
    metric=metric,
)

eval_years = out["eval_years"]
central    = out["central"]
band       = out["band"]
flow_info  = out["flow_info"]
ssp_ = out["SSP"]
MY_ = out["ModelYear"] 

#print("=== DONE: dynamic LCIA computed ===")
print("central columns:", central.columns.tolist())
print("band columns (lower):", band["lower"].columns.tolist())
print("band columns (upper):", band["upper"].columns.tolist())
# Out:
# [dynamic_ghg_lcia] Truncating CO2 kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1CO2_ssp119_fair_start1750MY2050.xlsx'
# [dynamic_ghg_lcia] Truncating CH4 kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1CH4_ssp119_fair_start1750MY2050.xlsx'
# [dynamic_ghg_lcia] Truncating N2O kernels from 201 / 201 rows to 101 rows (index 0..100) from file 'agwp_by_pIRF_tstep1N2O_ssp119_fair_start1750MY2050.xlsx'
# central columns: ['ch4_biomass', 'ch4_fossil', 'ch4_non_fossil', 'ch4_other', 'co2_biogenic', 'co2_fossil_positive', 'co2_other_negative', 'n2o_all', 'co2_total', 'ch4_total', 'n2o_total', 'all_ghg']
# band columns (lower): ['ch4_biomass', 'ch4_fossil', 'ch4_non_fossil', 'ch4_other', 'co2_biogenic', 'co2_fossil_positive', 'co2_other_negative', 'n2o_all', 'co2_total', 'ch4_total', 'n2o_total', 'all_ghg']
# ...

# %%
def quick_plot(series, lower, upper, title):
    plt.figure(figsize=(10,4))
    plt.fill_between(eval_years, lower, upper, alpha=0.25)
    plt.plot(eval_years, series, lw=2)
    plt.title(title)
    plt.grid(True)
    plt.show()



# 1. CO2 category 
if "co2_biogenic" in central.columns:
    quick_plot(
        central["co2_biogenic"],
        band["lower"]["co2_biogenic"],
        band["upper"]["co2_biogenic"],
        f"dp-{metric}: CO₂ (biogenic), SSP1-19/2050"
    )
else:
    print("Not found.")



quick_plot(
    central["co2_fossil_positive"],
    band["lower"]["co2_fossil_positive"],
    band["upper"]["co2_fossil_positive"],
    f"dp-{metric}: CO₂ (fossil), SSP1-19/2050"
)


quick_plot(
    central["co2_other_negative"],
    band["lower"]["co2_other_negative"],
    band["upper"]["co2_other_negative"],
    f"dp-{metric}: CO₂ negative, SSP1-19/2050"
)


#   CO2 total
quick_plot(
    central["co2_total"],
    band["lower"]["co2_total"],
    band["upper"]["co2_total"],
    f"dp-{metric}: CO₂ total, SSP1-19/2050"
)


# -----------------------------------------------------------
# 3. CH4 total
# -----------------------------------------------------------

if "ch4_non_fossil" in central.columns:
    quick_plot(
        central["ch4_non_fossil"],
        band["lower"]["ch4_non_fossil"],
        band["upper"]["ch4_non_fossil"],
        f"dp-{metric}: CH₄ (biogenic), SSP1-19/2050"
    )
else:
    print("Not found.")


quick_plot(
    central["ch4_total"],
    band["lower"]["ch4_total"],
    band["upper"]["ch4_total"],
    f"dp-{metric}: CH₄ total, SSP1-19/2050"
)
