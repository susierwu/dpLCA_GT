# %% [markdown]
# # I. IVEO_v1.0.1_w/h `premise-remind`

# %%
import bw2data, bw2io
from premise import *
from premise_gwp import add_premise_gwp
import numpy as np
import pandas as pd
import brightway25 as bw
# Out:
# /Users/susierwu/miniconda3/envs/prm/lib/python3.9/site-packages/brightway25/__init__.py:6: UserWarning: The Brightway25 package doesn't provide anything; import the constituent libraries separately
#   warnings.warn("The Brightway25 package doesn't provide anything; import the constituent libraries separately")

# %% [raw]
# bw2data.projects

# %%
bw2data.projects.set_current('iveo_v1')

# %% [raw]
# bw2data.databases

# %% [markdown]
# ## I.2 The premise bit

# %%
from premise import *

# %% [markdown]
# ### I.2.1 With ecoinvent in a brightway project

# %%
ndb = NewDatabase(
    scenarios=[
        #{"model":"image", "pathway":"SSP2-RCP19", "year":2050},
        #SSP119
        {"model":"remind", "pathway":"SSP1-PkBudg500", "year":2020},
        {"model":"remind", "pathway":"SSP1-PkBudg500", "year":2030},
        {"model":"remind", "pathway":"SSP1-PkBudg500", "year":2040},
        {"model":"remind", "pathway":"SSP1-PkBudg500", "year":2050},
        #SSP126
        {"model":"remind", "pathway":"SSP1-PkBudg1150", "year":2020},
        {"model":"remind", "pathway":"SSP1-PkBudg1150", "year":2030},
        {"model":"remind", "pathway":"SSP1-PkBudg1150", "year":2040},
        {"model":"remind", "pathway":"SSP1-PkBudg1150", "year":2050},
        #SSP245
        {"model":"remind", "pathway":"SSP2-Base", "year":2020},
        {"model":"remind", "pathway":"SSP2-Base", "year":2030},
        {"model":"remind", "pathway":"SSP2-Base", "year":2040},
        {"model":"remind", "pathway":"SSP2-Base", "year":2050},
        #SSP585
        {"model":"remind", "pathway":"SSP5-Base", "year":2020},
        {"model":"remind", "pathway":"SSP5-Base", "year":2030},
        {"model":"remind", "pathway":"SSP5-Base", "year":2040},
        {"model":"remind", "pathway":"SSP5-Base", "year":2050},
    ],
    source_db="ecoinvent 3.9.1", # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.9", # <-- version of ecoinvent. Can be "3.5", "3.6", "3.7" or "3.8". Must be a string.
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=' # <-- decryption key
)
# Out:
# premise v.(1, 7, 1)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# ...

# %% [markdown]
# ### I.3 Printing out scenario data

# %%
ndb.generate_scenario_report()
# Out:
# Generate scenario report.
# Report saved under /Users/susierwu/Dropbox/DLCA_DynCO2/BW2-dLCA/export/scenario_report.

# %%
len(ndb.scenarios)
# Out:
# 16

# %%
len(ndb.scenarios[0]["database"])
# Out:
# 22356

# %% [markdown]
# ### I.4 Exploring the database

# %%
# print the first activity
#ndb.scenarios[0]["database"][0]

# %%
# printing all non-ecoinvent datasets
ds = (d for d in ndb.scenarios[0]["database"] if d.get("database") != "ecoinvent 3.9.1")
for d in ds:
    print(d["name"])
# Out:
# auto-thermal reforming-hydrogen GT power plant, 400MWe
# carbon dioxide, captured at hydrogen production plant, pre, pipeline 200km, storage 1000m
# carbon dioxide, captured at hydrogen production plant, pre, pipeline 400km, storage 3000m
# carbon dioxide, captured at wood burning power plant 20 MW post, pipeline 200km, storage 1000m
# carbon dioxide, captured from hard coal-fired power plant, oxy, pipeline 200km, storage 1000m
# carbon dioxide, captured from hard coal-fired power plant, post, pipeline 200km, storage 1000m
# carbon dioxide, captured from hard coal-fired power plant, post, pipeline 400km, storage 1000m
# carbon dioxide, captured from hard coal-fired power plant, pre, pipeline 200km, storage 1000m
# carbon dioxide, captured from lignite, oxy, pipeline 200km, storage 1000m
# carbon dioxide, captured from lignite, post, pipeline 200km, storage 1000m
# carbon dioxide, captured from lignite, pre, pipeline 200km, storage 1000m
# ...

# %% [markdown]
# ### I.5 updating the electricity sector

# %% [markdown]
# ndb.update_electricity()

# %% [markdown]
# ### I.6 Or everything!

# %%
ndb.update_all()
# Out:
# `update_all()` will skip the following steps:
# update_two_wheelers(), update_cars(), and update_buses()
# If you want to update these steps, please run them separately afterwards.
# Extracted 1 worksheets in 11.98 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
# Done!
# Extracted 1 worksheets in 32.60 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Done!
# Done!
# Extracted 1 worksheets in 17.42 seconds
# Migrating to 3.8 first
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying strategy: migrate_datasets
# ...

# %% [markdown]
# # II. Export

# %% [markdown]
# ## II.1 Export back to a `brightway` project

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway2.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 01:06:31
# Title: Writing activities to SQLite3 database:
#   Started: 03/13/2024 22:03:35
#   Finished: 03/13/2024 23:10:07
#   Total time elapsed: 01:06:31
#   CPU %: 42.10
#   Memory %: 13.26
# Created database: ecoinvent_cutoff_3.9_remind_SSP1-PkBudg500_2020
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:37:03
# Title: Writing activities to SQLite3 database:
#   Started: 03/13/2024 23:16:36
#   Finished: 03/13/2024 23:53:40
#   Total time elapsed: 00:37:03
#   CPU %: 38.00
#   Memory %: 3.71
# Created database: ecoinvent_cutoff_3.9_remind_SSP1-PkBudg500_2030
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:33:38
# Title: Writing activities to SQLite3 database:
# ...
