# %%
import pickle
import bw2io, bw2data
import bw2calc
import lca_algebraic as agb
import wurst as ws
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib import rcParams
plt.rcParams["font.family"] = "Times New Roman"

# %% [markdown]
# ### what activities we wanna run the calculation?

# %%
pkl_file = "filtered_agri_N201.pkl"
# Step 2: Load the file
with open(pkl_file, "rb") as f:
    agri = pickle.load(f)

# %%
bw2data.projects.set_current('iveo_v1')
bw2data.databases
# Out:
# Databases dictionary with 43 objects, including:
# 	SIB
# 	batteries
# 	batteries-NMC622-LTO
# 	batteries_LiS
# 	batteries_SIB
# 	battery_lithium-oxygen
# 	biosphere3
# 	ecoinvent 3.9.1
# 	ecoinvent_cutoff_3.9_remind_SSP1-PkBudg1150_2020
# 	ecoinvent_cutoff_3.9_remind_SSP1-PkBudg1150_2030
# Use `list(this object)` to get the complete list.

# %%
eidb = 	bw2data.Database("ecoinvent 3.9.1")
print(len(eidb))
# Out:
# 21238

# %%
# new method name:
[m for m in bw2data.methods if 'pGWP100 with fixed' in str(m) and 'prospective GWP100' in str(m)]
# Out:
# [('Climate Change prospective GWP100',
#   'SSP119',
#   '2030',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP119',
#   '2040',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP119',
#   '2050',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP245',
#   '2030',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP245',
#   '2040',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP245',
#   '2050',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP585',
#   '2030',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP585',
#   '2040',
#   'pGWP100 with fixed AGWPCO2'),
#  ('Climate Change prospective GWP100',
#   'SSP585',
#   '2050',
#   'pGWP100 with fixed AGWPCO2')]

# %% [markdown]
# ### let's compare GWP100 vs. pGWP100

# %%
gwp_fixedCO2_all = [
  ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2'),  
  ('Climate Change prospective GWP100',
  'SSP119',
  '2030',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP119',
  '2040',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP119',
  '2050',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP245',
  '2030',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP245',
  '2040',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP245',
  '2050',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP585',
  '2030',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP585',
  '2040',
  'pGWP100 with fixed AGWPCO2'),
 ('Climate Change prospective GWP100',
  'SSP585',
  '2050',
  'pGWP100 with fixed AGWPCO2')]

"""
[
     ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2'),
     ('IPCC 2021 - dpCFsSSP119_MY2030 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP245_MY2030 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP585_MY2030 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP119_MY2040 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP245_MY2040 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP585_MY2040 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP119_MY2050 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP245_MY2050 - year100', 'climate change', 'pGWP100'),
     ('IPCC 2021 - dpCFsSSP585_MY2050 - year100', 'climate change', 'pGWP100')
]
"""
len(gwp_fixedCO2_all)
# Out:
# 10

# %%
def calculate_everything(activities, method_list):
    results = np.zeros((len(activities), len(method_list)))
    
    # Use only the .key from the first activity
    lca = bw2calc.LCA({activities[0][0]: 1}, method=method_list[0])  
    lca.lci()
    lca.decompose_technosphere()
    lca.lcia()

    #builds characterization_matrices in the same order as gwp_all, so later we can append col_names in final DF 
    characterization_matrices = []
    for method in method_list:
        lca.switch_method(method)
        characterization_matrices.append(lca.characterization_matrix.copy())
        
    for first, activity in enumerate(activities):
        activity_key = activity[0]  # Extract just the key
        activity_name = activity[1] 
        activity_rp = activity[2] 
        lca.redo_lci({activity_key: 1})
        
        for second, matrix in enumerate(characterization_matrices):
            results[first, second] = (matrix * lca.inventory).sum()
            
    return results

# %% [markdown]
# ### filtering all act to be calculated from ecoinvent, takes long

# %%
activities = sorted([
    (e.key, e['name'], e['reference product'])
    for a in agri
    for e in eidb
    if e['name'] == a['name'] 
    and e['location'] == a['location'] 
    and e['reference product'] == a['reference product']
])

# %%
print(len(activities))
print(activities[36])
# Out:
# 201
# (('ecoinvent 3.9.1', '27772ec7fb0507af396d02619fabb574'), 'fattening of calves for beef production, feedlot', 'cattle for slaughtering, live weight')

# %% [markdown]
# ### start calc with the selected pGWP100 method

# %%
from time import time
start = time()
lca_scores = calculate_everything(activities, gwp_fixedCO2_all)
elapsed = time() - start

# %%
print(f"calculate all filtered process N = {len(agri)},  in {elapsed:.2f} seconds, at {lca_scores.shape[0] * lca_scores.shape[1] / elapsed:.1f} calculations per second")
# Out:
# calculate all filtered process N = 201,  in 5.05 seconds, at 397.8 calculations per second

# %%
with open("calculated_GWP100_vs_pGWP100_N201_agri_fixedCO2.pkl", "wb") as f:
    pickle.dump(lca_scores, f)

# %%
#with open("calculated_GWP100_vs_pGWP100_N201_agri_fixedCO2.pkl", "rb") as f:
#    lca_scores = pickle.load(f)

# %% [raw]
# print("Array shape:", lca_scores.shape)
# #print("Number of activities:", len(activities))
# #print("Average:", np.average(lca_scores))
# #print("Median (of absolute value):", np.median(np.abs(lca_scores)))
# #print("Min, Max:", np.min(lca_scores), np.max(lca_scores))
# #print("Fraction of all scores with score of zero:", (lca_scores == 0).sum() / float(lca_scores.shape[0] * lca_scores.shape[1]))
# #print("Methods where all scores are zero:", (lca_scores.sum(axis=0) == 0).sum())
# #print("Activities where all scores are zero:", (lca_scores.sum(axis=1) == 0).sum())
# #np.histogram(lca_scores)

# %%
df = pd.DataFrame(lca_scores, columns=gwp_fixedCO2_all)

df['name'] = [act[1] for act in activities]
df['reference product'] = [act[2] for act in activities]
df['activity key'] = [act[0] for act in activities]
df = df[[ 'name', 'reference product', 'activity key' ] + list(df.columns[:-3])]
df
# Out:
#                                                 name  \
# 0                         sheep production, for meat
# 1        intensive beef cattle production on pasture
# 2        intensive beef cattle production on pasture
# 3           pea seed production, organic, for sowing
# 4     nutrient supply from NPK (26-15-15) fertiliser
# ..                                               ...
# 196            fava bean seed production, for sowing
# 197  operation, dried roughage store, non ventilated
# 198                 linseed seed production, at farm
# 199                                 olive production
# 200                           maize grain production
#
#                                    reference product  \
# 0                sheep for slaughtering, live weight
# 1               cattle for slaughtering, live weight
# 2                        weaned heifers, live weight
# 3                      pea seed, organic, for sowing
# 4                inorganic nitrogen fertiliser, as N
# ..                                               ...
# 196                       fava bean seed, for sowing
# 197  operation, dried roughage store, non ventilated
# 198                            linseed seed, at farm
# 199                                            olive
# 200                                      maize grain
#
#                                           activity key  \
# 0    (ecoinvent 3.9.1, 007e6b3a65b4c76d50ee97e28e38...
# 1    (ecoinvent 3.9.1, 00dbb25d67f7aa1c39b4033b80e0...
# 2    (ecoinvent 3.9.1, 023e6028b4678d7c617385a4696c...
# 3    (ecoinvent 3.9.1, 02eaf3b9902c51b09fb4264f1557...
# 4    (ecoinvent 3.9.1, 055532213ec16a8039040f61becc...
# ..                                                 ...
# 196  (ecoinvent 3.9.1, f5fa91b7523f1b58d71801842fa0...
# 197  (ecoinvent 3.9.1, fab72229ea8cb205676567685913...
# 198  (ecoinvent 3.9.1, fb5fc7ed373e16fef137f9bb92de...
# 199  (ecoinvent 3.9.1, fbc36664f672cf718c7425f58976...
# 200  (ecoinvent 3.9.1, fd3ccc1990eb4e583a1785a2a872...
#
#      (IPCC 2021, climate change, GWP 100a, incl. H and bio CO2)  \
# 0                                             4.981426
# 1                                            18.557733
# 2                                            15.029473
# 3                                            -0.719369
# 4                                             9.168543
# ..                                                 ...
# 196                                           0.550995
# 197                                           0.013858
# 198                                          -1.726566
# 199                                          -0.088549
# 200                                          -1.033730
#
#      (Climate Change prospective GWP100, SSP119, 2030, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.571632
# 1                                            17.143174
# 2                                            13.883854
# 3                                            -0.967078
# 4                                             9.537250
# ..                                                 ...
# 196                                           0.611205
# 197                                           0.015311
# 198                                          -2.137513
# 199                                          -0.152111
# 200                                          -1.231104
#
#      (Climate Change prospective GWP100, SSP119, 2040, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.745854
# 1                                            17.679483
# 2                                            14.318199
# 3                                            -0.961920
# 4                                             9.422280
# ..                                                 ...
# 196                                           0.606703
# 197                                           0.015300
# 198                                          -2.119918
# 199                                          -0.149335
# 200                                          -1.218326
#
#      (Climate Change prospective GWP100, SSP119, 2050, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.799297
# 1                                            17.836573
# 2                                            14.445422
# 3                                            -0.978341
# 4                                             9.407595
# ..                                                 ...
# 196                                           0.609641
# 197                                           0.015414
# 198                                          -2.143704
# 199                                          -0.152808
# 200                                          -1.228042
#
#      (Climate Change prospective GWP100, SSP245, 2030, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.357298
# 1                                            16.410655
# 2                                            13.290605
# 3                                            -0.936644
# 4                                             9.363260
# ..                                                 ...
# 196                                           0.596892
# 197                                           0.014891
# 198                                          -2.079925
# 199                                          -0.147427
# 200                                          -1.201257
#
#      (Climate Change prospective GWP100, SSP245, 2040, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.416002
# 1                                            16.511818
# 2                                            13.372534
# 3                                            -0.868467
# 4                                             8.915968
# ..                                                 ...
# 196                                           0.566021
# 197                                           0.014218
# 198                                          -1.942439
# 199                                          -0.131429
# 200                                          -1.125083
#
#      (Climate Change prospective GWP100, SSP245, 2050, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.402627
# 1                                            16.381029
# 2                                            13.266611
# 3                                            -0.810769
# 4                                             8.505163
# ..                                                 ...
# 196                                           0.538182
# 197                                           0.013590
# 198                                          -1.824279
# 199                                          -0.118639
# 200                                          -1.059180
#
#      (Climate Change prospective GWP100, SSP585, 2030, pGWP100 with fixed AGWPCO2)  \
# 0                                             4.093649
# 1                                            15.515580
# 2                                            12.565705
# 3                                            -0.917894
# 4                                             9.213176
# ..                                                 ...
# 196                                           0.585486
# 197                                           0.014526
# 198                                          -2.042433
# 199                                          -0.146039
# 200                                          -1.181454
#
#      (Climate Change prospective GWP100, SSP585, 2040, pGWP100 with fixed AGWPCO2)  \
# 0                                             3.861186
# 1                                            14.619945
# 2                                            11.840350
# 3                                            -0.815280
# 4                                             8.541016
# ..                                                 ...
# 196                                           0.536972
# 197                                           0.013330
# 198                                          -1.838168
# 199                                          -0.125327
# 200                                          -1.070197
#
#      (Climate Change prospective GWP100, SSP585, 2050, pGWP100 with fixed AGWPCO2)
# 0                                             3.834920
# 1                                            14.406930
# 2                                            11.667835
# 3                                            -0.707230
# 4                                             7.883342
# ..                                                 ...
# 196                                           0.489334
# 197                                           0.012233
# 198                                          -1.624911
# 199                                          -0.101088
# 200                                          -0.954026
#
# [201 rows x 13 columns]

# %% [markdown]
# ### analysis & plot

# %%
def create_correlation_matrix(scores_array, method_names):
    num_methods = scores_array.shape[1]
    correlations = np.eye(num_methods)  # Start with identity matrix (diagonal = 1)

    for row in range(num_methods):
        for col in range(row + 1, num_methods):  # Only upper triangle
            dataset_1 = scores_array[:, row]
            dataset_2 = scores_array[:, col]
            mask = (dataset_1 != 0) & (dataset_2 != 0)  # Exclude zero scores
            tau, _ = stats.kendalltau(dataset_1[mask], dataset_2[mask])
            corr = 0 if np.isnan(tau) else tau
            correlations[row, col] = correlations[col, row] = corr  # Symmetric

    return correlations, method_names

# %%
correlation_matrix, method_labels = create_correlation_matrix(lca_scores, gwp_fixedCO2_all)
# mask upper triangle only (keep diagonal = 1.0)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool), k=1)
masked_corr = np.ma.array(correlation_matrix, mask=mask)

fig, ax = plt.subplots(figsize=(12, 12))
cmap = plt.cm.coolwarm_r  # Reversed so RED = LOW, BLUE = HIGH

c = ax.imshow(masked_corr, cmap=cmap, vmin=masked_corr.min(), vmax=1.0)  #vmin dynamically change 

# labels
tick_labels = [str(m) for m in method_labels]
ax.set_xticks(np.arange(len(tick_labels)))
ax.set_yticks(np.arange(len(tick_labels)))
ax.set_xticklabels(tick_labels, rotation=90, fontsize=10)
ax.set_yticklabels(tick_labels, fontsize=10)

cb = fig.colorbar(c, ax=ax, shrink=0.85)
cb.ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.3f'))

plt.tight_layout()
plt.savefig("correlation_matrix_pGWP_whfixedCO2_vsGWP_onN201_eidb-agri.png", dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ### top impacted activities

# %%
def rank_activity_gwp_variation(df, top_n=10, method='perc'):
    """
    Get variation across GWP methods for each activity and return:
    1. DataFrame with added variation column
    2. Top N activities with highest variation
    Parameters:
    - df: DataFrame with metadata + GWP method columns
    - top_n: number of top varying activities to return
    - method: 'range', 'std', or 'perc'
    Returns:
    - df_with_variation: full DataFrame with new variation column
    - df_top_variation: top N activities sorted by variation
    """
    gwp_columns = df.columns[3:]  # assuming first 3 columns are metadata
    variation_col = f"variation_{method}"  # dynamically name the column


    if method == 'range':
        df[variation_col] = df[gwp_columns].max(axis=1) - df[gwp_columns].min(axis=1)
    elif method == 'std':
        df[variation_col] = df[gwp_columns].std(axis=1)
    elif method == 'perc': 
        #df['variation'] = (df[gwp_columns].max(axis=1) - df[gwp_columns].min(axis=1)) / df[gwp_columns].max(axis=1)
        max_val = df[gwp_columns].max(axis=1)
        min_val = df[gwp_columns].min(axis=1)
        raw_perc = (max_val - min_val) / max_val * 100
        df[variation_col] = raw_perc.round().astype('Int64')  # preserves NaN + int formatting 
        
    else:
        raise ValueError("method must be 'range' or 'std' or 'perc' ")

    df_top = df.sort_values(by=variation_col, ascending=False).head(top_n)
    
    return df, df_top

# %%
df = pd.DataFrame(lca_scores, columns=gwp_fixedCO2_all)
df['name'] = [act[1] for act in activities]
df['reference product'] = [act[2] for act in activities]
df['activity key'] = [act[0] for act in activities]
df = df[[ 'name', 'reference product', 'activity key' ] + list(df.columns[:-3])]

df2, df_top = rank_activity_gwp_variation (df, top_n=20, method = 'perc')

# %%
df_top
# Out:
#                                                   name  \
# 48          maize seed production, organic, for sowing
# 164                   rice seed production, for sowing
# 117                   aubergine production, open field
# 40          grass seed production, organic, for sowing
# 127                       rice production, non-basmati
# 6                         rice production, non-basmati
# 129                          milk production, from cow
# 95                           milk production, from cow
# 69        potato seed production, organic, for setting
# 115                                   peach production
# 29                  peanut seed production, for sowing
# 184                cocoon production, silkworm rearing
# 53                  carrot seed production, for sowing
# 61                     peanut seed production, at farm
# 17     tomato production, processing grade, open field
# 26                                    onion production
# 191                           rice production, basmati
# 122      beef cattle production on pasture and feedlot
# 93   fattening of heifers for beef production, feedlot
# 130                         sheep production, for wool
#
#                         reference product  \
# 48        maize seed, organic, for sowing
# 164                 rice seed, for sowing
# 117                             aubergine
# 40        grass seed, organic, for sowing
# 127                     rice, non-basmati
# 6                                   straw
# 129  cattle for slaughtering, live weight
# 95                               cow milk
# 69      potato seed, organic, for setting
# 115                                 peach
# 29                peanut seed, for sowing
# 184                               cocoons
# 53                carrot seed, for sowing
# 61                   peanut seed, at farm
# 17               tomato, processing grade
# 26                                  onion
# 191                         rice, basmati
# 122  cattle for slaughtering, live weight
# 93   cattle for slaughtering, live weight
# 130            sheep fleece in the grease
#
#                                           activity key  \
# 48   (ecoinvent 3.9.1, 35a4bc24ee7d1d5b1c5f368e13d7...
# 164  (ecoinvent 3.9.1, c0e4d9479e0e88ac442c1db54720...
# 117  (ecoinvent 3.9.1, 8adaa0ef50d1d821ccfacbb2ceae...
# 40   (ecoinvent 3.9.1, 2da12f3e810e0e181b78ac17396a...
# 127  (ecoinvent 3.9.1, 92386c6d580849768ba0ae1df128...
# 6    (ecoinvent 3.9.1, 059f36dd739f9cec0d710c2fcdb7...
# 129  (ecoinvent 3.9.1, 936da08864a9a3db33f7a6c8b16e...
# 95   (ecoinvent 3.9.1, 65e92c1f24b04bb24bbb720b3b85...
# 69   (ecoinvent 3.9.1, 49f9d038ba35053208a503d7e5c2...
# 115  (ecoinvent 3.9.1, 872fe5c22a503f242edf79002621...
# 29   (ecoinvent 3.9.1, 1a629e2502a5508fdf33bb760999...
# 184  (ecoinvent 3.9.1, e4ef6613a8b8fe5634e88c771367...
# 53   (ecoinvent 3.9.1, 3cd38c31393165c7c8e04715c496...
# 61   (ecoinvent 3.9.1, 4507f39d78be43c8db32978becf3...
# 17   (ecoinvent 3.9.1, 0da92b5bba6ca87ae0478d366a5c...
# 26   (ecoinvent 3.9.1, 17d12cf7217894036c18fe6d22b0...
# 191  (ecoinvent 3.9.1, ee15c2e24a8f400c2bd9a567c856...
# 122  (ecoinvent 3.9.1, 8eca02f173c6568d2aa5787d0d82...
# 93   (ecoinvent 3.9.1, 63f650628df96e51d148b46d5e6c...
# 130  (ecoinvent 3.9.1, 937896397065a0d549619a38b327...
#
#      (IPCC 2021, climate change, GWP 100a, incl. H and bio CO2)  \
# 48                                            0.026763
# 164                                           0.075815
# 117                                           0.024973
# 40                                            0.261702
# 127                                           0.412956
# 6                                             0.013393
# 129                                           1.618518
# 95                                            0.278945
# 69                                            0.053529
# 115                                           0.046656
# 29                                            0.425279
# 184                                           3.516412
# 53                                            0.293740
# 61                                            0.541098
# 17                                            0.013993
# 26                                            0.060957
# 191                                           1.985086
# 122                                          16.935055
# 93                                           16.808189
# 130                                          37.010051
#
#      (Climate Change prospective GWP100, SSP119, 2030, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.187107
# 164                                          -0.127394
# 117                                          -0.011239
# 40                                            0.054840
# 127                                           0.176686
# 6                                             0.005730
# 129                                           0.703729
# 95                                            0.121285
# 69                                            0.027982
# 115                                           0.024799
# 29                                            0.251666
# 184                                           2.501374
# 53                                            0.194834
# 61                                            0.383459
# 17                                            0.010139
# 26                                            0.045945
# 191                                           1.786892
# 122                                          15.342463
# 93                                           15.480259
# 130                                          33.965440
#
#      (Climate Change prospective GWP100, SSP119, 2040, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.190293
# 164                                          -0.072127
# 117                                          -0.012989
# 40                                            0.047665
# 127                                           0.252268
# 6                                             0.008182
# 129                                           0.892706
# 95                                            0.153854
# 69                                            0.027827
# 115                                           0.024979
# 29                                            0.244675
# 184                                           2.647724
# 53                                            0.195598
# 61                                            0.374430
# 17                                            0.010070
# 26                                            0.045287
# 191                                           1.883157
# 122                                          15.891504
# 93                                           15.991943
# 130                                          35.259847
#
#      (Climate Change prospective GWP100, SSP119, 2050, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.207185
# 164                                          -0.062105
# 117                                          -0.016364
# 40                                            0.029754
# 127                                           0.269328
# 6                                             0.008735
# 129                                           0.912435
# 95                                            0.157254
# 69                                            0.025959
# 115                                           0.023504
# 29                                            0.229429
# 184                                           2.642767
# 53                                            0.189073
# 61                                            0.359559
# 17                                            0.009774
# 26                                            0.043970
# 191                                           1.913906
# 122                                          16.039600
# 93                                           16.142297
# 130                                          35.656903
#
#      (Climate Change prospective GWP100, SSP245, 2030, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.171650
# 164                                          -0.153291
# 117                                          -0.008373
# 40                                            0.066741
# 127                                           0.130834
# 6                                             0.004243
# 129                                           0.596759
# 95                                            0.102849
# 69                                            0.028520
# 115                                           0.025070
# 29                                            0.257262
# 184                                           2.387769
# 53                                            0.193736
# 61                                            0.386492
# 17                                            0.010110
# 26                                            0.045892
# 191                                           1.685670
# 122                                          14.653514
# 93                                           14.804763
# 130                                          32.373023
#
#      (Climate Change prospective GWP100, SSP245, 2040, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.139512
# 164                                          -0.075105
# 117                                          -0.004674
# 40                                            0.086992
# 127                                           0.221022
# 6                                             0.007168
# 129                                           0.859211
# 95                                            0.148081
# 69                                            0.031083
# 115                                           0.027575
# 29                                            0.267038
# 184                                           2.577975
# 53                                            0.201944
# 61                                            0.388207
# 17                                            0.010279
# 26                                            0.045964
# 191                                           1.737573
# 122                                          14.846570
# 93                                           14.929161
# 130                                          32.809173
#
#      (Climate Change prospective GWP100, SSP245, 2050, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.115014
# 164                                          -0.020889
# 117                                          -0.001951
# 40                                            0.100742
# 127                                           0.279713
# 6                                             0.009072
# 129                                           1.029329
# 95                                            0.177400
# 69                                            0.032612
# 115                                           0.029097
# 29                                            0.271388
# 184                                           2.681858
# 53                                            0.205649
# 61                                            0.385575
# 17                                            0.010297
# 26                                            0.045555
# 191                                           1.751699
# 122                                          14.798907
# 93                                           14.834316
# 130                                          32.709800
#
#      (Climate Change prospective GWP100, SSP585, 2030, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.165887
# 164                                          -0.196691
# 117                                          -0.007001
# 40                                            0.069593
# 127                                           0.062684
# 6                                             0.002033
# 129                                           0.418105
# 95                                            0.072059
# 69                                            0.027818
# 115                                           0.024225
# 29                                            0.255183
# 184                                           2.201799
# 53                                            0.187545
# 61                                            0.382769
# 17                                            0.009894
# 26                                            0.045157
# 191                                           1.559357
# 122                                          13.793524
# 93                                           13.976257
# 130                                          30.414212
#
#      (Climate Change prospective GWP100, SSP585, 2040, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.118581
# 164                                          -0.156712
# 117                                          -0.000430
# 40                                            0.100367
# 127                                           0.087779
# 6                                             0.002847
# 129                                           0.519947
# 95                                            0.089611
# 69                                            0.030458
# 115                                           0.026546
# 29                                            0.267927
# 184                                           2.219019
# 53                                            0.191851
# 61                                            0.384394
# 17                                            0.009926
# 26                                            0.044771
# 191                                           1.473961
# 122                                          13.043588
# 93                                           13.181261
# 130                                          28.687102
#
#      (Climate Change prospective GWP100, SSP585, 2050, pGWP100 with fixed AGWPCO2)  \
# 48                                           -0.064144
# 164                                          -0.066885
# 117                                           0.006750
# 40                                            0.137967
# 127                                           0.183131
# 6                                             0.005939
# 129                                           0.818060
# 95                                            0.140989
# 69                                            0.034693
# 115                                           0.030467
# 29                                            0.288222
# 184                                           2.426992
# 53                                            0.204463
# 61                                            0.392853
# 17                                            0.010236
# 26                                            0.045286
# 191                                           1.491751
# 122                                          12.972846
# 93                                           13.024211
# 130                                          28.491959
#
#      variation_perc
# 48              874
# 164             359
# 117             166
# 40               89
# 127              85
# 6                85
# 129              74
# 95               74
# 69               52
# 115              50
# 29               46
# 184              37
# 53               36
# 61               34
# 17               30
# 26               28
# 191              26
# 122              23
# 93               23
# 130              23

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_top_variation_profiles(df_top, gwp_columns, title, filename, font_family="Times New Roman"):
    """
    Plot top activities with highest GWP method variation in subplots.

    Parameters:
    - df_top: DataFrame with top N activities (e.g., from rank_activity_gwp_variation)
    - gwp_columns: List of GWP method columns (as-is, even if they're tuples)
    - title: Suptitle for the entire figure
    - filename: Path to save the figure (e.g., 'plot.png')
    - font_family: Optional global font (default: Times New Roman)
    """
    #  global font
    plt.rcParams["font.family"] = font_family
    # layout setup
    top_n = df_top.shape[0]
    ncols = 4
    nrows = int(np.ceil(top_n / ncols))
    
    fig, axs = plt.subplots(nrows, ncols, figsize=(5 * ncols, 4 * nrows), sharex=True)
    axs = axs.flatten()

    # GWP method names to string for plotting
    x_labels = [str(col) for col in gwp_columns]

    for i, (idx, row) in enumerate(df_top.iterrows()):
        ax = axs[i]
        y = row[gwp_columns].astype(float)  # ensure numeric

        # Plot line
        ax.plot(x_labels, y, marker='o', linestyle='-', color='orange')

        # Highlight min and max
        min_idx = y.idxmin()
        max_idx = y.idxmax()
        ax.plot(str(min_idx), y[min_idx], marker='v', color='blue', markersize=10)
        ax.plot(str(max_idx), y[max_idx], marker='^', color='red', markersize=10)

        # Annotate largest % change from first point
        percent_changes = ((y - y.iloc[0]) / abs(y.iloc[0])) * 100
        largest_change_idx = percent_changes.abs().idxmax()
        percent_value = percent_changes[largest_change_idx]

        ax.annotate(f"{percent_value:.1f}%", 
                    xy=(str(largest_change_idx), y[largest_change_idx]),
                    xytext=(0, 10), textcoords='offset points',
                    ha='center', fontsize=9, color='black', fontweight='bold')

        #  title per panel
        name = row['name']
        ref_prod = row['reference product']
        label = f"{name}\n{ref_prod}"
        ax.set_title(label, fontsize=11)
        ax.set_xticks(range(len(x_labels)))
        ax.set_xticklabels(x_labels, rotation=90, fontsize=10)

        ax.grid(True, axis='y', linestyle='--', alpha=0.5)
        ax.set_ylabel(r"(p)GWP100 [kg CO$_2$-eq]")

    # hide any unused subplots
    for j in range(i + 1, len(axs)):
        fig.delaxes(axs[j])

    plt.suptitle(title, fontsize=16)
    plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to accommodate title
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()

# %%
df = pd.DataFrame(lca_scores, columns=gwp_fixedCO2_all)
df['name'] = [act[1] for act in activities]
df['reference product'] = [act[2] for act in activities]
df['activity key'] = [act[0] for act in activities]
df = df[[ 'name', 'reference product', 'activity key' ] + list(df.columns[:-3])]

df2, df_top = rank_activity_gwp_variation (df, top_n=12, method = 'perc')

plot_top_variation_profiles(
    df_top=df_top, 
    gwp_columns=df.columns[3:-1],  # exclude metadata and new col 'variation'
    title="Top 12 agricultural activities (ecoinvent cutoff v3.9.1) with highest (p)GWP100 method variation",
    filename="top12_gwp_whfixedCO2_variation_lineplot_fromN201_eidb-agri.png"
)
