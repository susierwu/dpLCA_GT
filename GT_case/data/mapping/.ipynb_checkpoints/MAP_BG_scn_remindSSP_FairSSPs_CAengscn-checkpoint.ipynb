# %% [markdown]
# # A. mapping premise remind vs. fair IPCC SSP119/126/245/585

# %% [markdown]
# ### A. premise <-> fair

# %% [markdown]
# Premise / :: name@remind:
#
# https://premise.readthedocs.io/en/latest/introduction.html#default-iam-scenarios
#
# - ssp119 -> ~1.3 °C :: SSP1-PkBudg500
# - ssp126 -> ~1.7 °C :: SSP1-PkBudg1150
#
# - ssp245 -> ~3.5 °C :: consistently,  remind SSP2-baseline -> RCP6.0, however, Fair model doesn't have SSP260, it only has one SSP245, so we used it as the only available SSP2
#
# - ssp585 -> ~4.5 °C :: SSP5-Base

# %% [markdown]
# ![image.png](attachment:e20b7a64-52ea-45ce-8889-2fd6d95e1224.png)

# %% [markdown]
# ![image.png](attachment:b39d7250-0f99-4fcf-81c6-c03badf73ac9.png) ![image.png](attachment:7e91ad78-9f15-4e63-a0a4-6cc7e9068f67.png)

# %% [markdown]
# https://www.carbonbrief.org/explainer-how-shared-socioeconomic-pathways-explore-future-climate-change/
#
# ![image.png](attachment:238ef89e-d677-4013-a5b8-b9e376dc6d10.png)

# %% [markdown]
# ### SSP2-baseline is a scenario where emissions continue to grow at the same rate as in the past. and we consider it as a BAU scenario. though, historically the "worst-case" scenario i.e., SSP585 is considered as BAU

# %% [markdown]
# https://www.ipcc.ch/site/assets/uploads/sites/3/2019/11/SROCC_Ch01-SM_FINAL.pdf
#
# ![image.png](attachment:897d2637-c4d9-4911-b952-9445bf77137d.png)

# %% [markdown]
# # B. mapping SSP vs. CA energy scenario

# %% [markdown]
# ### mapping CA CEF scns vs. SSP
#
# ssp119 (~1.3 °C) :: Global Net-zero (1.5 °C)
#
# <b>ssp126 :: Canada Net-zero (NZ50 in https://pathways-trajectoires.ca/) </b>
#
# <b>ssp245 :: The Current Measures Scenario (BAU in https://pathways-trajectoires.ca/) </b> (more reasoning in the "more detailed evidence" section below)
#
#     1. " assumes limited action to reduce GHG emissions beyond measures in place today."
#     2. in the CEF full report, Table A.1, current climate policies are the basis of the Current Measures Scenario,  incl: e.g.,
#         - Investment tax credit for carbon capture, utilization, and storage
#         - Clean fuel regulations
#         - Coal phase-out
#         - Renewable fuels
#     all of the above policies do not implicate a SSP5 "fossil fueled development"
#
# ssp585 :: SSP5-Base

# %% [markdown]
# ### the new report (2024): NZ50 -> Global Net-zero  (not CA NZ)
# - in two weeks (the new explorer will be available as well)

# %% [markdown]
# ## canada-energy-futures reports
#
#
# - method paper: https://apps2.cer-rec.gc.ca/energy-future/pdf/energy-future-visualization-methodology-2023.pdf
#
# - full report: https://www.cer-rec.gc.ca/en/data-analysis/canada-energy-future/2023/canada-energy-futures-2023.pdf
#
#     - A. global Net zero <->  IEA's Net-zero scenario
#     - B.  <b> The Canada Net-zero Scenario uses the IEA’s Announced Pledges Scenario for its international assumptions </b>
#         (@Anne  it's not how Marguerite (or is it Penelope's slides? below) mapped during the metal workshop several weeks ago in CIRAIG)
#     - C. The Current Measures Scenario uses other sources for international assumptions The international assumptions of the Current Measures Scenario are not from the WEO2022. Instead, we review global scenario analysis produced by institutions, academia, industry, private forecasters, and other relevant energy analysis, to develop our own assumptions.

# %% [markdown]
# #### from full report:
# "The third scenario, the Current Measures Scenario, assumes limited action to reduce GHG emissions beyond measures in place today. In this scenario, we do not require our modeling results achieve net-zero GHG emissions in Canada by 2050. We also assume limited future global climate action."
#
# ![image.png](attachment:ee47d64e-f9a4-4507-aeed-884128256ac2.png)

# %% [markdown]
# ![image.png](attachment:ef2ae4ab-f470-43fa-b63f-77cb3db3fde9.png)

# %% [markdown]
# ![image.png](attachment:8a590e3d-c0a9-4b19-b182-2426ac8aae85.png)

# %% [markdown]
# ![image.png](attachment:e19f3c0f-a512-4f13-8e86-b69cf660cfb5.png)

# %% [markdown]
# - we don't know what sub-sector (road vs. aviation ) that different fuels are being used

# %% [markdown]
# ![image.png](attachment:ec5042d6-232b-431d-9b66-dab8ecab77aa.png)

# %% [markdown]
# ## more detailed evidence why SSP2-baseline <-> mapped to CA Current Measures Scenario BAU
#
# using premise -> image (CAN) SSP2-base  & plots from CEF2023 report

# %% [markdown]
# ### premise SSP2-base vs. CA electricity 2050
#
# hydro / wind dominate, then gas and solar,  though nuclear differ
#
# ![image.png](attachment:dcf59ffa-00ab-432a-ada8-e0ebe0774530.png)
#
# ![image.png](attachment:1f2b1444-97ee-43d2-aba2-57e4a5f6f6a7.png)

# %% [markdown]
# ### CO2 from premise  vs. CO2e from CEF report
#
# ![image.png](attachment:bada2779-d7e7-4e18-bf4c-c789bbab54dc.png)
#
# ![image.png](attachment:3c9a59bf-9bb9-4101-9a53-453551472ad3.png)

# %% [markdown]
# ### crude oil production decreased slightly even for  Current Measures Scenario, not consistent with SSP5 - fossil fuel focused
#
# ![image.png](attachment:c29dc0b7-316c-472f-9bae-80271c2c0154.png)
#
# ![image.png](attachment:f9e0971c-146c-41a9-98da-4eab67414821.png)
#
# ![image.png](attachment:ce8e6edb-bb49-479e-b3e6-f4efa5f5e8c7.png)
